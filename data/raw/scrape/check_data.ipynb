# %%
import pandas as pd

# %%
df1 = pd.read_csv('realestates_kh_1.csv')
df2 = pd.read_csv('century21.csv')
df3 = pd.read_csv('../../processed/land_dataset_final_v3_1_keep_1.csv')

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (6190, 19)
# (1095, 9)
# (5493, 240)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6190 entries, 0 to 6189
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   6190 non-null   int64
#  1   headline             6190 non-null   object
#  2   price_display        6177 non-null   object
#  3   rent_display         674 non-null    object
#  4   bedrooms             3971 non-null   float64
#  5   bathrooms            3928 non-null   float64
#  6   land_area            3092 non-null   float64
#  7   thumbnail_url        6190 non-null   object
#  8   thumbnail_urls       6190 non-null   object
#  9   garages              1346 non-null   float64
#  10  location             6190 non-null   object
#  11  address_subdivision  6190 non-null   object
#  12  address_locality     6190 non-null   object
#  13  address_line_2       6180 non-null   object
#  14  address_line_1       5986 non-null   object
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           1095 non-null   object
#  1   information  1093 non-null   object
#  2   type         1095 non-null   object
#  3   province     1095 non-null   object
#  4   price        1016 non-null   float64
#  5   land_size    919 non-null    float64
#  6   price/m2     842 non-null    float64
#  7   lat          1064 non-null   float64
#  8   long         1064 non-null   float64
# dtypes: float64(5), object(4)
# memory usage: 77.1+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5493 entries, 0 to 5492
# Columns: 240 entries, address_subdivision to h_id
# dtypes: float64(9), int64(226), object(5)
# memory usage: 10.1+ MB
