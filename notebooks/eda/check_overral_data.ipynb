# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('../../data/raw/scrape/realestates_kh_1.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

missing_pct = df.isnull().mean().sort_values(ascending=False) * 100
missing_pct = missing_pct[missing_pct > 0]

plt.figure(figsize=(10,6))
sns.barplot(x=missing_pct.values, y=missing_pct.index)
plt.title('Missing Value Percentage by Column')
plt.xlabel('% Missing')
plt.ylabel('Columns')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           1095 non-null   object
#  1   information  1093 non-null   object
#  2   type         1095 non-null   object
#  3   province     1095 non-null   object
#  4   price        1016 non-null   float64
#  5   land_size    919 non-null    float64
#  6   price/m2     842 non-null    float64
#  7   lat          1064 non-null   float64
#  8   long         1064 non-null   float64
# dtypes: float64(5), object(4)
# memory usage: 77.1+ KB

# %%
pd.set_option('display.max_colwidth', None)
for info in df1['price_display']:
    print(info)
    print('-' * 80)
# Out:
# $150,000
# --------------------------------------------------------------------------------
# $269,000
# --------------------------------------------------------------------------------
# $85,000
# --------------------------------------------------------------------------------
# $450,000
# --------------------------------------------------------------------------------
# $85,000
# --------------------------------------------------------------------------------
# $215,000
# --------------------------------------------------------------------------------
# $370,000
# --------------------------------------------------------------------------------
# $65,000
# --------------------------------------------------------------------------------
# $3,950,000
# --------------------------------------------------------------------------------
# $248,172
# --------------------------------------------------------------------------------
# $249,000
# ...

# %%
df2 = pd.read_csv('../../data/raw/scrape/century21.csv')

# %%
df1.shape
# Out:
# (6190, 19)

# %%
import math

# Duplicate df1 to approximately 12,000 rows

n_rows = df1.shape[0]
n_repeat = math.ceil(12230 / n_rows)
df1_large = pd.concat([df1] * n_repeat, ignore_index=True).iloc[:12230]
df1_large.shape
# Out:
# (12230, 19)

# %%
df1 = df1_large

# %%
df1.columns
# Out:
# Index(['id', 'headline', 'price_display', 'rent_display', 'bedrooms',
#        'bathrooms', 'land_area', 'thumbnail_url', 'thumbnail_urls', 'garages',
#        'location', 'address_subdivision', 'address_locality', 'address_line_2',
#        'address_line_1', 'category_name', 'is_parent', 'type', 'information'],
#       dtype='object')

# %%
df1
# Out:
#            id  \
# 0      204942
# 1      211997
# 2      212595
# 3      211987
# 4      212653
# ...       ...
# 12225  209949
# 12226  227601
# 12227  236420
# 12228  235868
# 12229  139728
#
#                                                                                   headline  \
# 0      A flat (2 floors) near Hengly market and near Monk hospital. Need to sell urgently.
# 1                             Twin Villa (Twin Villa) in Borey Highland 2005 Khan Sen Sok
# 2                                                                           house for sale
# 3                                                          House for sale in Meanchey Area
# 4            House for Sale Urgently | Extra Space and Stair next to the House| Negotiable
# ...                                                                                    ...
# 12225                                                     Condo for sale at Sihanouk Ville
# ...

# %%
print("Shape of df1:", df1.shape)
display(df1.head())
df1.info()
# Out:
# Shape of df1: (12230, 19)
#        id  \
# 0  204942
# 1  211997
# 2  212595
# 3  211987
# 4  212653
#
#                                                                               headline  \
# 0  A flat (2 floors) near Hengly market and near Monk hospital. Need to sell urgently.
# 1                         Twin Villa (Twin Villa) in Borey Highland 2005 Khan Sen Sok
# 2                                                                       house for sale
# 3                                                      House for sale in Meanchey Area
# 4        House for Sale Urgently | Extra Space and Stair next to the House| Negotiable
#
#   price_display rent_display  bedrooms  bathrooms  land_area  \
# 0      $150,000          NaN       6.0        4.0        NaN
# 1      $269,000          NaN       4.0        7.0        NaN
# 2       $85,000          NaN       2.0        2.0        NaN
# 3      $450,000          NaN       8.0        6.0        0.0
# ...

# %%
df2.shape
# Out:
# (1095, 9)
