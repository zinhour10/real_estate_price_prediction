# %%
import pandas as pd
import simplekml
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 import pandas as pd
# ----> 2 import simplekml
#
# ModuleNotFoundError: No module named 'simplekml'

# %%
df = pd.read_csv('../../data/processed/mockup_dataset_road_v2.csv')

# %%
df.head()
# Out:
#   address_subdivision address_locality    address_line_2             h_id  \
# 0          Phnom Penh      Chbar Ampov        Preaek Pra  8865846a59fffff
# 1          Phnom Penh      Chamkar Mon       Tonle Basak  8865846ae1fffff
# 2          Phnom Penh        Mean Chey  Stueng Mean Chey  8865846ad1fffff
# 3          Phnom Penh      Pur SenChey        Chaom Chau  88658461a1fffff
# 4          Phnom Penh        Mean Chey      Boeng Tumpun  8865846ad5fffff
#
#    price_per_m2  land_area      price   longitude   latitude  \
# 0        365.99         66  163119.66  104.967388  11.513522
# 1       6573.84         80  178789.60  104.927932  11.557310
# 2       3170.62         44  104971.68  104.901617  11.530884
# 3       2138.94         32   64163.20  104.877972  11.529098
# 4       2665.02         40   41927.60  104.905288  11.536313
#
#    near_Koh_Pich_in_km  ...  f_steps  f_tertiary  f_track  f_trunk  \
# 0                    5  ...        1           1        1        1
# ...
