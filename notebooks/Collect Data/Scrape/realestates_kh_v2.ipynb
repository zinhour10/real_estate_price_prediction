# %%
import requests
import time
import pandas as pd
from collections import deque
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor, as_completed
import langid
import re

# %%
# List of Cambodian provinces to iterate through
cambodia_provinces = [
    "Phnom Penh",           # Capital (Autonomous Municipality)
    "Banteay Meanchey",
    "Battambang",
    "Kampong Cham",
    "Kampong Chhnang",
    "Kampong Speu",
    "Kampong Thom",
    "Kampot",
    "Kandal",
    "Kep",
    "Koh Kong",
    "Kratié",
    "Mondulkiri",
    "Oddar Meanchey",
    "Pailin",
    "Preah Vihear",
    "Prey Veng",
    "Pursat",
    "Ratanakiri",
    "Siem Reap",
    "Sihanoukville",
    "Stung Treng",
    "Svay Rieng",
    "Takeo",
    "Tboung Khmum"
]

# %%
# ——— CONFIGURATION SETTINGS ———
PAGE_SIZE   = 1000    # Number of listings returned per API call
MIN_STEP    = 0.005   # Minimum geographical step for splitting tiles (prevents infinite loops on tiny areas)
EXPECTED    = None    # Set to an int to stop early (e.g., 5000), or None to exhaustively crawl
USER_AGENT  = ("Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
               "AppleWebKit/537.36 (KHTML, like Gecko) "
               "Chrome/117.0.0.0 Safari/537.36 Edg/117.0.2045.60")

# Geographic bounds for Cambodia (used for initial grid crawl)
TOP_LAT     = 14.704581
BOTTOM_LAT  = 9.913701
LEFT_LON    = 102.313423
RIGHT_LON   = 107.627449

headers = {"User-Agent": USER_AGENT}

# %%
def fetch_tile(tl_lat, tl_lon, br_lat, br_lon, property_type, province_name):
    """
    Fetches map points (listings) for a given geographical tile and property type from the API.

    Args:
        tl_lat (float): Top-left latitude of the bounding box.
        tl_lon (float): Top-left longitude of the bounding box.
        br_lat (float): Bottom-right latitude of the bounding box.
        br_lon (float): Bottom-right longitude of the bounding box.
        property_type (str): Type of property (e.g., 'residential', 'commercial', 'borey', 'project').
        province_name (str): Name of the province for the location query (URL encoded).

    Returns:
        list: A list of sample points (listings) found within the tile. Returns an empty list on error.
    """
    # Construct the URL for the API request with dynamic parameters
    url = (
        "https://www.realestate.com.kh/api/listing/map-points/"
        f"?active_tab=popularLocations"
        f"&order_by=relevance"
        f"&property_type={property_type}"
        f"&q=location:{province_name}" # Use the specific province name in the query
        f"&search_type=sale"
        f"&bottom_right_lat={br_lat}&bottom_right_lon={br_lon}"
        f"&top_left_lat={tl_lat}&top_left_lon={tl_lon}"
        f"&show_all=true&page_size={PAGE_SIZE}"
    )
    try:
        # Make the GET request with a timeout
        resp = requests.get(url, headers=headers, timeout=15)
        resp.raise_for_status() # Raise HTTPError for bad responses (4xx or 5xx)

        # Parse the JSON response and extract 'points' and 'samples'
        pts = resp.json().get("points", [])
        if not pts:
            return []
        return pts[0].get("samples", [])
    except requests.exceptions.RequestException as e:
        print(f"⚠️ HTTP Request Error for tile {tl_lat,tl_lon,br_lat,br_lon}: {e}")
        return []
    except Exception as e:
        print(f"⚠️ An unexpected error occurred in fetch_tile: {e}")
        return []

# %%
request_province_list = [] # Stores counts per province and property type
request_all = []

# %%
url_base_part1 = "https://www.realestate.com.kh/api/listing/map-points/?active_tab=popularLocations&order_by=relevance&property_type="
url_base_part2 = '&q=location:'
url_base_part3 = '&search_type=sale&bottom_right_lat=9.039849866109236&bottom_right_lon=108.07048795635677&top_left_lat=15.785344977938763&top_left_lon=100.34079574208647&order_by=relevance&show_all=true&page_size=1000'

# %%
seen_ids = set()

# %%
for i in range(len(cambodia_provinces)):
    for j in ['residential', 'commercial', 'borey', 'project']:
        province = cambodia_provinces[i]
        # Construct the initial URL for the province and property type, URL encoding the province name
        url_initial_query = url_base_part1 + j + url_base_part2 + province.replace(" ", "%20") + url_base_part3

        # Make the initial request for the current province and property type
        try:
            response = requests.get(url_initial_query, headers=headers, timeout=15)
            response.raise_for_status() # Raise HTTPError for bad responses
            data = response.json().get("points", [])
            count = data[0]['count'] if data else 0
            samples = data[0].get('samples', []) if data else []
        except requests.exceptions.RequestException as e:
            print(f"⚠️ Initial Request Error for {province} ({j}): {e}")
            count = 0
            samples = []
        except Exception as e:
            print(f"⚠️ An unexpected error occurred during initial request for {province} ({j}): {e}")
            count = 0
            samples = []

        # Record the count for the current province and property type
        request_province_list.append({
            "Province": province,
            "Property_Type": j, # Added property type for better tracking
            "Count":    count
        })

        # If the count is less than the PAGE_SIZE, all listings for this query are returned
        if count < PAGE_SIZE:
            # Add these samples to the main list, ensuring no duplicates
            for item in samples:
                _id = item.get("id")
                if _id and _id not in seen_ids:
                    seen_ids.add(_id)
                    item['type'] = j
                    request_all.append(item)
        else:
            # If the count is at or above PAGE_SIZE, it means there are more listings.
            # Include the initial 1000 samples before performing a detailed grid crawl.
            for item in samples:
                _id = item.get("id")
                if _id and _id not in seen_ids:
                    seen_ids.add(_id)
                    item['type'] = j
                    request_all.append(item)

            # Perform a grid crawl over the entire Cambodia bounds to capture all listings
            print(f"🔍 {province} ({j}) has {count} listings → drilling down…")
            queue = deque([(TOP_LAT, LEFT_LON, BOTTOM_LAT, RIGHT_LON)]) # Initialize queue with full Cambodia bounds
            tiles_processed = 0

            while queue:
                tl_lat, tl_lon, br_lat, br_lon = queue.popleft()
                tiles_processed += 1

                # Fetch listings for the current tile, passing property_type and province_name
                results = fetch_tile(tl_lat, tl_lon, br_lat, br_lon, j, province.replace(" ", "%20"))
                n = len(results)

                # Print progress for the current tile
                print(f"[{province}][{j}][Tile {tiles_processed}] Fetched {n} | "
                      f"Queue: {len(queue)} | Collected: {len(request_all)}")

                lat_span = tl_lat - br_lat
                lon_span = br_lon - tl_lon

                # If the current tile still returns PAGE_SIZE listings and is larger than MIN_STEP,
                # split it into 4 sub-tiles and add them to the queue for further drilling down.
                if n == PAGE_SIZE and lat_span > MIN_STEP and lon_span > MIN_STEP:
                    mid_lat = (tl_lat + br_lat) / 2
                    mid_lon = (tl_lon + br_lon) / 2
                    queue.extend([
                        (tl_lat,    tl_lon,    mid_lat, mid_lon),   # North-West tile
                        (tl_lat,    mid_lon,   mid_lat, br_lon),   # North-East tile
                        (mid_lat,   tl_lon,    br_lat,  mid_lon),   # South-West tile
                        (mid_lat,   mid_lon,   br_lat,  br_lon),    # South-East tile
                    ])
                else:
                    # If the tile is no longer capped or is too small to split, accept its results.
                    # Add unique listings to the main list.
                    for item in results:
                        _id = item.get("id")
                        if _id and _id not in seen_ids:
                            seen_ids.add(_id)
                            item['type'] = j
                            request_all.append(item)

                # If EXPECTED count is set and reached, break the loop early
                if EXPECTED and len(request_all) >= EXPECTED:
                    break

                time.sleep(0.4) # Add a small delay to avoid overwhelming the server

        print(f"✅ After {province} ({j}): total unique = {len(request_all)}\n")
# Out:
# 🔍 Phnom Penh (residential) has 3894 listings → drilling down…
# [Phnom Penh][residential][Tile 1] Fetched 1000 | Queue: 0 | Collected: 1000
# [Phnom Penh][residential][Tile 2] Fetched 2 | Queue: 3 | Collected: 1000
# [Phnom Penh][residential][Tile 3] Fetched 0 | Queue: 2 | Collected: 1001
# [Phnom Penh][residential][Tile 4] Fetched 1000 | Queue: 1 | Collected: 1001
# [Phnom Penh][residential][Tile 5] Fetched 30 | Queue: 4 | Collected: 1001
# [Phnom Penh][residential][Tile 6] Fetched 0 | Queue: 3 | Collected: 1029
# [Phnom Penh][residential][Tile 7] Fetched 1000 | Queue: 2 | Collected: 1029
# [Phnom Penh][residential][Tile 8] Fetched 0 | Queue: 5 | Collected: 1029
# [Phnom Penh][residential][Tile 9] Fetched 0 | Queue: 4 | Collected: 1029
# [Phnom Penh][residential][Tile 10] Fetched 0 | Queue: 3 | Collected: 1029
# [Phnom Penh][residential][Tile 11] Fetched 4 | Queue: 2 | Collected: 1029
# [Phnom Penh][residential][Tile 12] Fetched 0 | Queue: 1 | Collected: 1031
# [Phnom Penh][residential][Tile 13] Fetched 1000 | Queue: 0 | Collected: 1031
# [Phnom Penh][residential][Tile 14] Fetched 0 | Queue: 3 | Collected: 1031
# [Phnom Penh][residential][Tile 15] Fetched 1000 | Queue: 2 | Collected: 1031
# [Phnom Penh][residential][Tile 16] Fetched 0 | Queue: 5 | Collected: 1031
# [Phnom Penh][residential][Tile 17] Fetched 3 | Queue: 4 | Collected: 1031
# [Phnom Penh][residential][Tile 18] Fetched 11 | Queue: 3 | Collected: 1034
# [Phnom Penh][residential][Tile 19] Fetched 1000 | Queue: 2 | Collected: 1043
# [Phnom Penh][residential][Tile 20] Fetched 16 | Queue: 5 | Collected: 1043
# [Phnom Penh][residential][Tile 21] Fetched 1000 | Queue: 4 | Collected: 1056
# [Phnom Penh][residential][Tile 22] Fetched 11 | Queue: 7 | Collected: 1056
# [Phnom Penh][residential][Tile 23] Fetched 141 | Queue: 6 | Collected: 1066
# [Phnom Penh][residential][Tile 24] Fetched 186 | Queue: 5 | Collected: 1204
# [Phnom Penh][residential][Tile 25] Fetched 1000 | Queue: 4 | Collected: 1365
# [Phnom Penh][residential][Tile 26] Fetched 219 | Queue: 7 | Collected: 1365
# [Phnom Penh][residential][Tile 27] Fetched 1000 | Queue: 6 | Collected: 1527
# [Phnom Penh][residential][Tile 28] Fetched 20 | Queue: 9 | Collected: 1527
# [Phnom Penh][residential][Tile 29] Fetched 128 | Queue: 8 | Collected: 1544
# [Phnom Penh][residential][Tile 30] Fetched 48 | Queue: 7 | Collected: 1631
# [Phnom Penh][residential][Tile 31] Fetched 0 | Queue: 6 | Collected: 1678
# [Phnom Penh][residential][Tile 32] Fetched 906 | Queue: 5 | Collected: 1678
# [Phnom Penh][residential][Tile 33] Fetched 106 | Queue: 4 | Collected: 2301
# [Phnom Penh][residential][Tile 34] Fetched 1000 | Queue: 3 | Collected: 2368
# [Phnom Penh][residential][Tile 35] Fetched 638 | Queue: 6 | Collected: 2368
# [Phnom Penh][residential][Tile 36] Fetched 96 | Queue: 5 | Collected: 2805
# [Phnom Penh][residential][Tile 37] Fetched 290 | Queue: 4 | Collected: 2898
# [Phnom Penh][residential][Tile 38] Fetched 192 | Queue: 3 | Collected: 3120
# [Phnom Penh][residential][Tile 39] Fetched 496 | Queue: 2 | Collected: 3241
# [Phnom Penh][residential][Tile 40] Fetched 44 | Queue: 1 | Collected: 3604
# [Phnom Penh][residential][Tile 41] Fetched 307 | Queue: 0 | Collected: 3634
# ✅ After Phnom Penh (residential): total unique = 3894
#
# ✅ After Phnom Penh (commercial): total unique = 4211
#
# ✅ After Phnom Penh (borey): total unique = 4211
#
# ✅ After Phnom Penh (project): total unique = 4211
#
# ✅ After Banteay Meanchey (residential): total unique = 4220
#
# ✅ After Banteay Meanchey (commercial): total unique = 4221
#
# ✅ After Banteay Meanchey (borey): total unique = 4221
#
# ✅ After Banteay Meanchey (project): total unique = 4221
#
# ✅ After Battambang (residential): total unique = 4239
#
# ✅ After Battambang (commercial): total unique = 4240
#
# ✅ After Battambang (borey): total unique = 4240
#
# ✅ After Battambang (project): total unique = 4240
#
# ✅ After Kampong Cham (residential): total unique = 4252
#
# ✅ After Kampong Cham (commercial): total unique = 4254
#
# ✅ After Kampong Cham (borey): total unique = 4254
#
# ✅ After Kampong Cham (project): total unique = 4254
#
# ✅ After Kampong Chhnang (residential): total unique = 4261
#
# ✅ After Kampong Chhnang (commercial): total unique = 4261
#
# ✅ After Kampong Chhnang (borey): total unique = 4261
#
# ✅ After Kampong Chhnang (project): total unique = 4261
#
# ✅ After Kampong Speu (residential): total unique = 4312
#
# ✅ After Kampong Speu (commercial): total unique = 4317
#
# ✅ After Kampong Speu (borey): total unique = 4317
#
# ✅ After Kampong Speu (project): total unique = 4317
#
# ✅ After Kampong Thom (residential): total unique = 4322
#
# ✅ After Kampong Thom (commercial): total unique = 4325
#
# ✅ After Kampong Thom (borey): total unique = 4325
#
# ✅ After Kampong Thom (project): total unique = 4325
#
# ✅ After Kampot (residential): total unique = 4410
#
# ✅ After Kampot (commercial): total unique = 4425
#
# ✅ After Kampot (borey): total unique = 4425
#
# ✅ After Kampot (project): total unique = 4425
#
# ✅ After Kandal (residential): total unique = 4625
#
# ✅ After Kandal (commercial): total unique = 4650
#
# ✅ After Kandal (borey): total unique = 4650
#
# ✅ After Kandal (project): total unique = 4650
#
# ✅ After Kep (residential): total unique = 4678
#
# ✅ After Kep (commercial): total unique = 4684
#
# ✅ After Kep (borey): total unique = 4684
#
# ✅ After Kep (project): total unique = 4684
#
# ✅ After Koh Kong (residential): total unique = 4701
#
# ✅ After Koh Kong (commercial): total unique = 4705
#
# ✅ After Koh Kong (borey): total unique = 4705
#
# ✅ After Koh Kong (project): total unique = 4705
#
# ✅ After Kratié (residential): total unique = 4706
#
# ✅ After Kratié (commercial): total unique = 4707
#
# ✅ After Kratié (borey): total unique = 4707
#
# ✅ After Kratié (project): total unique = 4707
#
# ✅ After Mondulkiri (residential): total unique = 4708
#
# ✅ After Mondulkiri (commercial): total unique = 4708
#
# ✅ After Mondulkiri (borey): total unique = 4708
#
# ✅ After Mondulkiri (project): total unique = 4708
#
# ✅ After Oddar Meanchey (residential): total unique = 4710
#
# ✅ After Oddar Meanchey (commercial): total unique = 4710
#
# ✅ After Oddar Meanchey (borey): total unique = 4710
#
# ✅ After Oddar Meanchey (project): total unique = 4710
#
# ✅ After Pailin (residential): total unique = 4712
#
# ✅ After Pailin (commercial): total unique = 4713
#
# ✅ After Pailin (borey): total unique = 4713
#
# ✅ After Pailin (project): total unique = 4713
#
# ✅ After Preah Vihear (residential): total unique = 4716
#
# ✅ After Preah Vihear (commercial): total unique = 4716
#
# ✅ After Preah Vihear (borey): total unique = 4716
#
# ✅ After Preah Vihear (project): total unique = 4716
#
# ✅ After Prey Veng (residential): total unique = 4720
#
# ✅ After Prey Veng (commercial): total unique = 4720
#
# ✅ After Prey Veng (borey): total unique = 4720
#
# ✅ After Prey Veng (project): total unique = 4720
#
# ✅ After Pursat (residential): total unique = 4723
#
# ✅ After Pursat (commercial): total unique = 4727
#
# ✅ After Pursat (borey): total unique = 4727
#
# ✅ After Pursat (project): total unique = 4727
#
# ✅ After Ratanakiri (residential): total unique = 4730
#
# ✅ After Ratanakiri (commercial): total unique = 4730
#
# ✅ After Ratanakiri (borey): total unique = 4730
#
# ✅ After Ratanakiri (project): total unique = 4730
#
# 🔍 Siem Reap (residential) has 1185 listings → drilling down…
# [Siem Reap][residential][Tile 1] Fetched 1000 | Queue: 0 | Collected: 5729
# [Siem Reap][residential][Tile 2] Fetched 1000 | Queue: 3 | Collected: 5729
# [Siem Reap][residential][Tile 3] Fetched 0 | Queue: 6 | Collected: 5729
# [Siem Reap][residential][Tile 4] Fetched 1 | Queue: 5 | Collected: 5729
# [Siem Reap][residential][Tile 5] Fetched 0 | Queue: 4 | Collected: 5730
# [Siem Reap][residential][Tile 6] Fetched 0 | Queue: 3 | Collected: 5730
# [Siem Reap][residential][Tile 7] Fetched 10 | Queue: 2 | Collected: 5730
# [Siem Reap][residential][Tile 8] Fetched 2 | Queue: 1 | Collected: 5734
# [Siem Reap][residential][Tile 9] Fetched 1000 | Queue: 0 | Collected: 5734
# [Siem Reap][residential][Tile 10] Fetched 1000 | Queue: 3 | Collected: 5734
# [Siem Reap][residential][Tile 11] Fetched 0 | Queue: 6 | Collected: 5734
# [Siem Reap][residential][Tile 12] Fetched 0 | Queue: 5 | Collected: 5734
# [Siem Reap][residential][Tile 13] Fetched 0 | Queue: 4 | Collected: 5734
# [Siem Reap][residential][Tile 14] Fetched 1000 | Queue: 3 | Collected: 5734
# [Siem Reap][residential][Tile 15] Fetched 12 | Queue: 6 | Collected: 5734
# [Siem Reap][residential][Tile 16] Fetched 0 | Queue: 5 | Collected: 5738
# [Siem Reap][residential][Tile 17] Fetched 0 | Queue: 4 | Collected: 5738
# [Siem Reap][residential][Tile 18] Fetched 5 | Queue: 3 | Collected: 5738
# [Siem Reap][residential][Tile 19] Fetched 503 | Queue: 2 | Collected: 5739
# [Siem Reap][residential][Tile 20] Fetched 25 | Queue: 1 | Collected: 5765
# [Siem Reap][residential][Tile 21] Fetched 627 | Queue: 0 | Collected: 5766
# ✅ After Siem Reap (residential): total unique = 5914
#
# ✅ After Siem Reap (commercial): total unique = 6183
#
# ✅ After Siem Reap (borey): total unique = 6183
#
# ✅ After Siem Reap (project): total unique = 6183
#
# ✅ After Sihanoukville (residential): total unique = 6321
#
# ✅ After Sihanoukville (commercial): total unique = 6344
#
# ✅ After Sihanoukville (borey): total unique = 6344
#
# ✅ After Sihanoukville (project): total unique = 6344
#
# ✅ After Stung Treng (residential): total unique = 6346
#
# ✅ After Stung Treng (commercial): total unique = 6347
#
# ✅ After Stung Treng (borey): total unique = 6347
#
# ✅ After Stung Treng (project): total unique = 6347
#
# ✅ After Svay Rieng (residential): total unique = 6350
#
# ✅ After Svay Rieng (commercial): total unique = 6350
#
# ✅ After Svay Rieng (borey): total unique = 6350
#
# ✅ After Svay Rieng (project): total unique = 6350
#
# ✅ After Takeo (residential): total unique = 6364
#
# ✅ After Takeo (commercial): total unique = 6365
#
# ✅ After Takeo (borey): total unique = 6365
#
# ✅ After Takeo (project): total unique = 6365
#
# ✅ After Tboung Khmum (residential): total unique = 6368
#
# ✅ After Tboung Khmum (commercial): total unique = 6369
#
# ✅ After Tboung Khmum (borey): total unique = 6369
#
# ✅ After Tboung Khmum (project): total unique = 6369

# %%
df_province_list = pd.DataFrame(request_province_list)
df_all = pd.DataFrame(request_all)

# %%
# ——— FINAL DEDUPLICATION AND SUMMARY ———
if 'id' in df_all.columns:
    before = len(df_all)
    df_all = df_all.drop_duplicates(subset='id') # Remove duplicate listings based on 'id'
    after = len(df_all)
    print(f"🔄 Final dedupe: {before} → {after} unique listings")
# Out:
# 🔄 Final dedupe: 6369 → 6369 unique listings

# %%
# Convert 'Count' column to integer type and sum for overall province counts
df_province_list['Count'] = df_province_list['Count'].astype(int)
print(f"Total listings counted across all initial API queries: {df_province_list['Count'].sum()}")
df_province_summary = df_province_list.groupby('Province')['Count'].sum().reset_index()
print("Summary of listings per province (initial query counts):")
print(df_province_summary)
# Out:
# Total listings counted across all initial API queries: 6496
# Summary of listings per province (initial query counts):
#             Province  Count
# 0   Banteay Meanchey     11
# 1         Battambang     20
# 2       Kampong Cham     15
# 3    Kampong Chhnang      7
# 4       Kampong Speu     56
# 5       Kampong Thom     10
# 6             Kampot    100
# 7             Kandal    229
# 8                Kep     35
# 9           Koh Kong     21
# 10            Kratié      2
# 11        Mondulkiri      1
# 12    Oddar Meanchey      2
# 13            Pailin      3
# 14        Phnom Penh   4316
# 15      Preah Vihear      3
# 16         Prey Veng      4
# 17            Pursat      7
# 18        Ratanakiri      3
# 19         Siem Reap   1460
# 20     Sihanoukville    166
# 21       Stung Treng      3
# 22        Svay Rieng      3
# 23             Takeo     15
# 24      Tboung Khmum      4

# %%
# Base URL for individual property listings
base_listing_url = "https://www.realestate.com.kh/"

# Create new columns if they don't already exist in df_all
if 'information' not in df_all.columns:
    df_all['information'] = None
if 'source_url' not in df_all.columns: # New column to store the URL of the scraped page
    df_all['source_url'] = None

# Define the scraping function for individual listing pages
def fetch_info(index, id_value):
    """
    Fetches detailed information and the source URL for a single property listing.

    Args:
        index (int): The index of the row in the DataFrame being processed.
        id_value (str/int): The unique ID of the property listing.

    Returns:
        tuple: (index, raw_text, temp_url) if successful, or (index, None, temp_url) if an error occurs
               or the target span is not found. The URL is always returned.
    """
    # Construct the full URL for the specific listing page
    temp_url = base_listing_url + str(id_value) + '/'
    try:
        # Make the GET request with a timeout
        response = requests.get(temp_url, timeout=10)
        response.raise_for_status() # Raise HTTPError for bad responses (4xx or 5xx)

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.content, "html.parser")

        # Find the specific <span> element containing the desired information
        span = soup.find("span", class_="css-zrj3zm")
        if span:
            # Extract text from the span, cleaning up whitespace
            raw_text = span.get_text(separator=" ", strip=True)
            print(f"[{index}] ✔ Success: {temp_url}")
            return index, raw_text, temp_url # Return the URL along with text
        else:
            print(f"[{index}] ✘ No span found: {temp_url}")
            return index, None, temp_url # Return the URL even if span not found
    except requests.exceptions.RequestException as e:
        print(f"[{index}] ⚠ HTTP Request Error for {temp_url}: {e}")
        return index, None, temp_url # Return the URL on error
    except Exception as e:
        print(f"[{index}] ⚠ Unexpected Error for {temp_url}: {e}")
        return index, None, temp_url # Return the URL on error

# Use ThreadPoolExecutor for parallel execution to speed up scraping
with ThreadPoolExecutor(max_workers=25) as executor:
    # Submit scraping tasks for each listing in df_all
    futures = [
        executor.submit(fetch_info, i, df_all.iloc[i]['id']) for i in range(len(df_all))
    ]

    # Process results as they complete
    for future in as_completed(futures):
        index, result_text, result_url = future.result() # Unpack the returned values
        df_all.at[index, 'information'] = result_text
        df_all.at[index, 'source_url'] = result_url # Assign the URL to the new column
# Out:
# [2] ✔ Success: https://www.realestate.com.kh/212595/
# [4] ✔ Success: https://www.realestate.com.kh/212653/
# [12] ✔ Success: https://www.realestate.com.kh/141245/
# [10] ✔ Success: https://www.realestate.com.kh/229653/
# [13] ✔ Success: https://www.realestate.com.kh/145091/
# [9] ✔ Success: https://www.realestate.com.kh/127135/
# [18] ✔ Success: https://www.realestate.com.kh/233750/
# [15] ✔ Success: https://www.realestate.com.kh/156169/
# [7] ✔ Success: https://www.realestate.com.kh/218563/
# [1] ✔ Success: https://www.realestate.com.kh/211997/
# [22] ✔ Success: https://www.realestate.com.kh/235065/
# [11] ✔ Success: https://www.realestate.com.kh/142378/
# [6] ✔ Success: https://www.realestate.com.kh/218884/
# [8] ✔ Success: https://www.realestate.com.kh/218736/
# [21] ✔ Success: https://www.realestate.com.kh/235048/
# [14] ✔ Success: https://www.realestate.com.kh/153997/
# [5] ✔ Success: https://www.realestate.com.kh/217976/
# [20] ✔ Success: https://www.realestate.com.kh/231183/
# [24] ✔ Success: https://www.realestate.com.kh/232502/
# [0] ✔ Success: https://www.realestate.com.kh/204942/
# [16] ✔ Success: https://www.realestate.com.kh/183911/
# [23] ✔ Success: https://www.realestate.com.kh/228347/
# [17] ✔ Success: https://www.realestate.com.kh/232920/
# [19] ✔ Success: https://www.realestate.com.kh/230541/
# [3] ✔ Success: https://www.realestate.com.kh/211987/
# [26] ✔ Success: https://www.realestate.com.kh/212923/
# [28] ✔ Success: https://www.realestate.com.kh/212812/
# [33] ✔ Success: https://www.realestate.com.kh/200584/
# [25] ✔ Success: https://www.realestate.com.kh/165365/
# [27] ✔ Success: https://www.realestate.com.kh/212922/
# [29] ✔ Success: https://www.realestate.com.kh/213353/
# [35] ✔ Success: https://www.realestate.com.kh/225961/
# [30] ✔ Success: https://www.realestate.com.kh/214685/
# [31] ✔ Success: https://www.realestate.com.kh/214912/
# [34] ✔ Success: https://www.realestate.com.kh/200464/
# [36] ✔ Success: https://www.realestate.com.kh/226481/
# [37] ✔ Success: https://www.realestate.com.kh/226992/
# [40] ✔ Success: https://www.realestate.com.kh/233086/
# [41] ✔ Success: https://www.realestate.com.kh/232278/
# [39] ✔ Success: https://www.realestate.com.kh/232361/
# [38] ✔ Success: https://www.realestate.com.kh/157841/
# [32] ✔ Success: https://www.realestate.com.kh/218436/
# [42] ✔ Success: https://www.realestate.com.kh/233665/
# [44] ✔ Success: https://www.realestate.com.kh/231195/
# [45] ✔ Success: https://www.realestate.com.kh/234738/
# [46] ✔ Success: https://www.realestate.com.kh/232394/
# [47] ✔ Success: https://www.realestate.com.kh/213024/
# [43] ✔ Success: https://www.realestate.com.kh/231205/
# [51] ✔ Success: https://www.realestate.com.kh/213371/
# [49] ✔ Success: https://www.realestate.com.kh/212002/
# [48] ✔ Success: https://www.realestate.com.kh/212330/
# [53] ✔ Success: https://www.realestate.com.kh/211962/
# [50] ✔ Success: https://www.realestate.com.kh/214058/
# [52] ✔ Success: https://www.realestate.com.kh/212633/
# [54] ✔ Success: https://www.realestate.com.kh/158295/
# [57] ✔ Success: https://www.realestate.com.kh/186047/
# [56] ✔ Success: https://www.realestate.com.kh/195046/
# [58] ✔ Success: https://www.realestate.com.kh/185727/
# [55] ✔ Success: https://www.realestate.com.kh/127130/
# [60] ✔ Success: https://www.realestate.com.kh/232918/
# [59] ✔ Success: https://www.realestate.com.kh/185734/
# [61] ✔ Success: https://www.realestate.com.kh/233710/
# [65] ✔ Success: https://www.realestate.com.kh/234128/
# [62] ✔ Success: https://www.realestate.com.kh/233675/
# [63] ✔ Success: https://www.realestate.com.kh/231559/
# [64] ✔ Success: https://www.realestate.com.kh/231232/
# [66] ✔ Success: https://www.realestate.com.kh/231186/
# [70] ✔ Success: https://www.realestate.com.kh/212001/
# [67] ✔ Success: https://www.realestate.com.kh/203057/
# [68] ✔ Success: https://www.realestate.com.kh/148344/
# [71] ✔ Success: https://www.realestate.com.kh/212816/
# [69] ✔ Success: https://www.realestate.com.kh/150011/
# [72] ✔ Success: https://www.realestate.com.kh/212711/
# [78] ✔ Success: https://www.realestate.com.kh/201783/
# [74] ✔ Success: https://www.realestate.com.kh/181716/
# [73] ✔ Success: https://www.realestate.com.kh/214071/
# [77] ✔ Success: https://www.realestate.com.kh/218900/
# [75] ✔ Success: https://www.realestate.com.kh/157098/
# [76] ✔ Success: https://www.realestate.com.kh/218322/
# [79] ✔ Success: https://www.realestate.com.kh/185973/
# [82] ✔ Success: https://www.realestate.com.kh/230768/
# [81] ✔ Success: https://www.realestate.com.kh/235284/
# [80] ✔ Success: https://www.realestate.com.kh/231222/
# [85] ✔ Success: https://www.realestate.com.kh/213638/
# [84] ✔ Success: https://www.realestate.com.kh/212704/
# [86] ✔ Success: https://www.realestate.com.kh/212324/
# [83] ✔ Success: https://www.realestate.com.kh/232852/
# [87] ✔ Success: https://www.realestate.com.kh/218258/
# [89] ✔ Success: https://www.realestate.com.kh/198790/
# [93] ✔ Success: https://www.realestate.com.kh/232200/
# [88] ✔ Success: https://www.realestate.com.kh/216623/
# [91] ✔ Success: https://www.realestate.com.kh/227969/
# [90] ✔ Success: https://www.realestate.com.kh/227764/
# [92] ✔ Success: https://www.realestate.com.kh/184909/
# [95] ✔ Success: https://www.realestate.com.kh/233768/
# [94] ✔ Success: https://www.realestate.com.kh/233442/
# [96] ✔ Success: https://www.realestate.com.kh/235498/
# [97] ✔ Success: https://www.realestate.com.kh/235518/
# [98] ✔ Success: https://www.realestate.com.kh/234204/
# [99] ✔ Success: https://www.realestate.com.kh/231230/
# [102] ✔ Success: https://www.realestate.com.kh/231355/
# [100] ✔ Success: https://www.realestate.com.kh/231197/
# [101] ✔ Success: https://www.realestate.com.kh/234990/
# [103] ✔ Success: https://www.realestate.com.kh/212322/
# [106] ✔ Success: https://www.realestate.com.kh/171403/
# [107] ✔ Success: https://www.realestate.com.kh/181700/
# [109] ✔ Success: https://www.realestate.com.kh/201436/
# [104] ✔ Success: https://www.realestate.com.kh/213519/
# [108] ✔ Success: https://www.realestate.com.kh/218359/
# [105] ✔ Success: https://www.realestate.com.kh/214181/
# [110] ✔ Success: https://www.realestate.com.kh/201439/
# [111] ✔ Success: https://www.realestate.com.kh/200507/
# [113] ✔ Success: https://www.realestate.com.kh/223608/
# [112] ✔ Success: https://www.realestate.com.kh/229058/
# [117] ✔ Success: https://www.realestate.com.kh/235656/
# [114] ✔ Success: https://www.realestate.com.kh/186060/
# [116] ✔ Success: https://www.realestate.com.kh/235560/
# [115] ✔ Success: https://www.realestate.com.kh/233956/
# [118] ✔ Success: https://www.realestate.com.kh/235191/
# [119] ✔ Success: https://www.realestate.com.kh/212070/
# [122] ✔ Success: https://www.realestate.com.kh/211249/
# [121] ✔ Success: https://www.realestate.com.kh/212692/
# [123] ✔ Success: https://www.realestate.com.kh/218194/
# [124] ✔ Success: https://www.realestate.com.kh/216620/
# [120] ✔ Success: https://www.realestate.com.kh/212808/
# [127] ✔ Success: https://www.realestate.com.kh/212457/
# [128] ✔ Success: https://www.realestate.com.kh/214617/
# [126] ✔ Success: https://www.realestate.com.kh/218675/
# [125] ✔ Success: https://www.realestate.com.kh/218778/
# [129] ✔ Success: https://www.realestate.com.kh/95244/
# [136] ✔ Success: https://www.realestate.com.kh/231220/
# [130] ✔ Success: https://www.realestate.com.kh/184908/
# [132] ✔ Success: https://www.realestate.com.kh/185858/
# [133] ✔ Success: https://www.realestate.com.kh/185859/
# [131] ✔ Success: https://www.realestate.com.kh/229346/
# [134] ✔ Success: https://www.realestate.com.kh/185857/
# [138] ✔ Success: https://www.realestate.com.kh/204008/
# [137] ✔ Success: https://www.realestate.com.kh/231189/
# [135] ✔ Success: https://www.realestate.com.kh/231236/
# [139] ✔ Success: https://www.realestate.com.kh/149854/
# [140] ✔ Success: https://www.realestate.com.kh/149866/
# [141] ✔ Success: https://www.realestate.com.kh/214707/
# [142] ✔ Success: https://www.realestate.com.kh/214287/
# [147] ✔ Success: https://www.realestate.com.kh/218769/
# [146] ✔ Success: https://www.realestate.com.kh/218775/
# [145] ✔ Success: https://www.realestate.com.kh/217555/
# [143] ✔ Success: https://www.realestate.com.kh/212811/
# [144] ✔ Success: https://www.realestate.com.kh/178619/
# [149] ✔ Success: https://www.realestate.com.kh/197352/
# [148] ✔ Success: https://www.realestate.com.kh/197360/
# [151] ✔ Success: https://www.realestate.com.kh/232907/
# [150] ✔ Success: https://www.realestate.com.kh/225810/
# [152] ✔ Success: https://www.realestate.com.kh/233717/
# [156] ✔ Success: https://www.realestate.com.kh/235235/
# [154] ✔ Success: https://www.realestate.com.kh/230534/
# [157] ✔ Success: https://www.realestate.com.kh/148966/
# [155] ✔ Success: https://www.realestate.com.kh/235230/
# [159] ✔ Success: https://www.realestate.com.kh/212283/
# [158] ✔ Success: https://www.realestate.com.kh/213195/
# [153] ✔ Success: https://www.realestate.com.kh/233638/
# [160] ✔ Success: https://www.realestate.com.kh/214082/
# [162] ✔ Success: https://www.realestate.com.kh/219239/
# [164] ✔ Success: https://www.realestate.com.kh/218748/
# [163] ✔ Success: https://www.realestate.com.kh/218562/
# [166] ✔ Success: https://www.realestate.com.kh/200481/
# [161] ✔ Success: https://www.realestate.com.kh/181070/
# [168] ✔ Success: https://www.realestate.com.kh/199825/
# [165] ✔ Success: https://www.realestate.com.kh/201835/
# [167] ✔ Success: https://www.realestate.com.kh/199740/
# [169] ✔ Success: https://www.realestate.com.kh/229187/
# [170] ✔ Success: https://www.realestate.com.kh/141243/
# [173] ✔ Success: https://www.realestate.com.kh/229837/
# [171] ✔ Success: https://www.realestate.com.kh/145093/
# [174] ✔ Success: https://www.realestate.com.kh/232251/
# [172] ✔ Success: https://www.realestate.com.kh/185527/
# [176] ✔ Success: https://www.realestate.com.kh/231185/
# [175] ✔ Success: https://www.realestate.com.kh/233616/
# [179] ✔ Success: https://www.realestate.com.kh/207618/
# [182] ✔ Success: https://www.realestate.com.kh/152270/
# [177] ✔ Success: https://www.realestate.com.kh/232778/
# [178] ✔ Success: https://www.realestate.com.kh/207610/
# [183] ✔ Success: https://www.realestate.com.kh/222925/
# [180] ✔ Success: https://www.realestate.com.kh/207617/
# [184] ✔ Success: https://www.realestate.com.kh/210826/
# [190] ✔ Success: https://www.realestate.com.kh/235904/
# [185] ✔ Success: https://www.realestate.com.kh/209786/
# [181] ✔ Success: https://www.realestate.com.kh/203714/
# [188] ✔ Success: https://www.realestate.com.kh/208300/
# [189] ✔ Success: https://www.realestate.com.kh/235522/
# [187] ✔ Success: https://www.realestate.com.kh/208701/
# [186] ✔ Success: https://www.realestate.com.kh/211664/
# [192] ✔ Success: https://www.realestate.com.kh/235343/
# [191] ✔ Success: https://www.realestate.com.kh/235202/
# [193] ✔ Success: https://www.realestate.com.kh/235345/
# [197] ✔ Success: https://www.realestate.com.kh/208133/
# [198] ✔ Success: https://www.realestate.com.kh/209706/
# [194] ✔ Success: https://www.realestate.com.kh/216151/
# [200] ✔ Success: https://www.realestate.com.kh/223500/
# [195] ✔ Success: https://www.realestate.com.kh/216159/
# [196] ✔ Success: https://www.realestate.com.kh/207267/
# [199] ✔ Success: https://www.realestate.com.kh/209734/
# [201] ✔ Success: https://www.realestate.com.kh/221815/
# [204] ✔ Success: https://www.realestate.com.kh/224195/
# [202] ✔ Success: https://www.realestate.com.kh/221816/
# [203] ✔ Success: https://www.realestate.com.kh/224218/
# [208] ✔ Success: https://www.realestate.com.kh/201874/
# [207] ✔ Success: https://www.realestate.com.kh/200261/
# [205] ✔ Success: https://www.realestate.com.kh/220220/
# [206] ✔ Success: https://www.realestate.com.kh/220276/
# [212] ✔ Success: https://www.realestate.com.kh/208534/
# [210] ✔ Success: https://www.realestate.com.kh/201663/
# [211] ✔ Success: https://www.realestate.com.kh/150317/
# [209] ✔ Success: https://www.realestate.com.kh/127134/
# [213] ✔ Success: https://www.realestate.com.kh/235420/
# [217] ✔ Success: https://www.realestate.com.kh/217506/
# [218] ✔ Success: https://www.realestate.com.kh/194175/
# [219] ✔ Success: https://www.realestate.com.kh/195153/
# [220] ✔ Success: https://www.realestate.com.kh/142204/
# [216] ✔ Success: https://www.realestate.com.kh/217507/
# [221] ✔ Success: https://www.realestate.com.kh/127136/
# [224] ✔ Success: https://www.realestate.com.kh/221119/
# [214] ✔ Success: https://www.realestate.com.kh/214070/
# [215] ✔ Success: https://www.realestate.com.kh/217099/
# [226] ✔ Success: https://www.realestate.com.kh/223781/
# [222] ✔ Success: https://www.realestate.com.kh/207158/
# [223] ✔ Success: https://www.realestate.com.kh/207141/
# [225] ✔ Success: https://www.realestate.com.kh/224155/
# [228] ✔ Success: https://www.realestate.com.kh/220289/
# [232] ✔ Success: https://www.realestate.com.kh/200519/
# [229] ✔ Success: https://www.realestate.com.kh/220287/
# [233] ✔ Success: https://www.realestate.com.kh/201944/
# [230] ✔ Success: https://www.realestate.com.kh/223986/
# [227] ✔ Success: https://www.realestate.com.kh/224156/
# [231] ✔ Success: https://www.realestate.com.kh/199742/
# [236] ✔ Success: https://www.realestate.com.kh/235761/
# [237] ✔ Success: https://www.realestate.com.kh/235937/
# [234] ✔ Success: https://www.realestate.com.kh/200034/
# [235] ✔ Success: https://www.realestate.com.kh/208106/
# [238] ✔ Success: https://www.realestate.com.kh/235022/
# [240] ✔ Success: https://www.realestate.com.kh/234719/
# [244] ✔ Success: https://www.realestate.com.kh/234724/
# [242] ✔ Success: https://www.realestate.com.kh/233082/
# [247] ✔ Success: https://www.realestate.com.kh/235652/
# [241] ✔ Success: https://www.realestate.com.kh/235502/
# [246] ✔ Success: https://www.realestate.com.kh/236195/
# [245] ✔ Success: https://www.realestate.com.kh/235555/
# [243] ✔ Success: https://www.realestate.com.kh/235631/
# [239] ✔ Success: https://www.realestate.com.kh/235654/
# [248] ✔ Success: https://www.realestate.com.kh/235894/
# [249] ✔ Success: https://www.realestate.com.kh/235896/
# [251] ✔ Success: https://www.realestate.com.kh/234299/
# [250] ✔ Success: https://www.realestate.com.kh/235273/
# [252] ✔ Success: https://www.realestate.com.kh/163525/
# [253] ✔ Success: https://www.realestate.com.kh/215235/
# [259] ✔ Success: https://www.realestate.com.kh/207094/
# [255] ✔ Success: https://www.realestate.com.kh/207061/
# [256] ✔ Success: https://www.realestate.com.kh/207033/
# [258] ✔ Success: https://www.realestate.com.kh/207085/
# [260] ✔ Success: https://www.realestate.com.kh/207915/
# [261] ✔ Success: https://www.realestate.com.kh/208724/
# [257] ✔ Success: https://www.realestate.com.kh/207036/
# [263] ✔ Success: https://www.realestate.com.kh/222653/
# [254] ✔ Success: https://www.realestate.com.kh/214785/
# [262] ✔ Success: https://www.realestate.com.kh/209519/
# [264] ✔ Success: https://www.realestate.com.kh/224152/
# [265] ✔ Success: https://www.realestate.com.kh/223209/
# [266] ✔ Success: https://www.realestate.com.kh/223444/
# [267] ✔ Success: https://www.realestate.com.kh/209746/
# [268] ✔ Success: https://www.realestate.com.kh/210735/
# [272] ✔ Success: https://www.realestate.com.kh/235950/
# [270] ✔ Success: https://www.realestate.com.kh/210167/
# [271] ✔ Success: https://www.realestate.com.kh/235421/
# [269] ✔ Success: https://www.realestate.com.kh/208731/
# [276] ✔ Success: https://www.realestate.com.kh/207009/
# [273] ✔ Success: https://www.realestate.com.kh/73333/
# [274] ✔ Success: https://www.realestate.com.kh/190214/
# [275] ✔ Success: https://www.realestate.com.kh/207016/
# [277] ✔ Success: https://www.realestate.com.kh/207010/
# [280] ✔ Success: https://www.realestate.com.kh/207910/
# [278] ✔ Success: https://www.realestate.com.kh/207891/
# [279] ✔ Success: https://www.realestate.com.kh/207900/
# [282] ✔ Success: https://www.realestate.com.kh/219247/
# [284] ✔ Success: https://www.realestate.com.kh/223699/
# [287] ✔ Success: https://www.realestate.com.kh/201715/
# [285] ✔ Success: https://www.realestate.com.kh/220756/
# [283] ✔ Success: https://www.realestate.com.kh/223724/
# [281] ✔ Success: https://www.realestate.com.kh/210087/
# [288] ✔ Success: https://www.realestate.com.kh/152262/
# [286] ✔ Success: https://www.realestate.com.kh/199788/
# [291] ✔ Success: https://www.realestate.com.kh/207754/
# [289] ✔ Success: https://www.realestate.com.kh/209707/
# [290] ✔ Success: https://www.realestate.com.kh/210234/
# [292] ✔ Success: https://www.realestate.com.kh/208621/
# [296] ✔ Success: https://www.realestate.com.kh/207775/
# [297] ✔ Success: https://www.realestate.com.kh/211030/
# [294] ✔ Success: https://www.realestate.com.kh/208053/
# [295] ✔ Success: https://www.realestate.com.kh/208361/
# [299] ✔ Success: https://www.realestate.com.kh/207897/
# [298] ✔ Success: https://www.realestate.com.kh/208730/
# [293] ✔ Success: https://www.realestate.com.kh/210324/
# [300] ✔ Success: https://www.realestate.com.kh/235645/
# [301] ✔ Success: https://www.realestate.com.kh/170964/
# [303] ✔ Success: https://www.realestate.com.kh/214080/
# [302] ✔ Success: https://www.realestate.com.kh/217965/
# [304] ✔ Success: https://www.realestate.com.kh/214067/
# [305] ✔ Success: https://www.realestate.com.kh/213022/
# [307] ✔ Success: https://www.realestate.com.kh/163235/
# [308] ✔ Success: https://www.realestate.com.kh/206958/
# [310] ✔ Success: https://www.realestate.com.kh/207324/
# [306] ✔ Success: https://www.realestate.com.kh/213414/
# [309] ✔ Success: https://www.realestate.com.kh/206941/
# [311] ✔ Success: https://www.realestate.com.kh/207328/
# [313] ✔ Success: https://www.realestate.com.kh/220210/
# [312] ✔ Success: https://www.realestate.com.kh/220212/
# [314] ✔ Success: https://www.realestate.com.kh/220211/
# [316] ✔ Success: https://www.realestate.com.kh/223815/
# [315] ✔ Success: https://www.realestate.com.kh/224085/
# [317] ✔ Success: https://www.realestate.com.kh/223362/
# [320] ✔ Success: https://www.realestate.com.kh/223775/
# [319] ✔ Success: https://www.realestate.com.kh/223774/
# [318] ✔ Success: https://www.realestate.com.kh/223783/
# [321] ✔ Success: https://www.realestate.com.kh/223752/
# [322] ✔ Success: https://www.realestate.com.kh/221467/
# [323] ✔ Success: https://www.realestate.com.kh/220661/
# [324] ✔ Success: https://www.realestate.com.kh/223751/
# [325] ✔ Success: https://www.realestate.com.kh/200134/
# [326] ✔ Success: https://www.realestate.com.kh/199799/
# [328] ✔ Success: https://www.realestate.com.kh/201947/
# [329] ✔ Success: https://www.realestate.com.kh/151859/
# [327] ✔ Success: https://www.realestate.com.kh/201180/
# [331] ✔ Success: https://www.realestate.com.kh/208363/
# [330] ✔ Success: https://www.realestate.com.kh/208630/
# [332] ✔ Success: https://www.realestate.com.kh/210919/
# [334] ✔ Success: https://www.realestate.com.kh/207785/
# [333] ✔ Success: https://www.realestate.com.kh/208351/
# [335] ✔ Success: https://www.realestate.com.kh/211088/
# [336] ✔ Success: https://www.realestate.com.kh/234327/
# [337] ✔ Success: https://www.realestate.com.kh/235347/
# [338] ✔ Success: https://www.realestate.com.kh/148079/
# [339] ✔ Success: https://www.realestate.com.kh/168427/
# [340] ✔ Success: https://www.realestate.com.kh/171017/
# [341] ✔ Success: https://www.realestate.com.kh/217494/
# [342] ✔ Success: https://www.realestate.com.kh/216161/
# [347] ✔ Success: https://www.realestate.com.kh/216028/
# [344] ✔ Success: https://www.realestate.com.kh/217115/
# [348] ✔ Success: https://www.realestate.com.kh/209873/
# [343] ✔ Success: https://www.realestate.com.kh/217970/
# [346] ✔ Success: https://www.realestate.com.kh/214705/
# [345] ✔ Success: https://www.realestate.com.kh/213409/
# [351] ✔ Success: https://www.realestate.com.kh/199822/
# [349] ✔ Success: https://www.realestate.com.kh/224178/
# [350] ✔ Success: https://www.realestate.com.kh/221701/
# [352] ✔ Success: https://www.realestate.com.kh/150293/
# [354] ✔ Success: https://www.realestate.com.kh/207683/
# [353] ✔ Success: https://www.realestate.com.kh/208042/
# [355] ✔ Success: https://www.realestate.com.kh/235368/
# [363] ✔ Success: https://www.realestate.com.kh/217752/
# [357] ✔ Success: https://www.realestate.com.kh/216035/
# [358] ✔ Success: https://www.realestate.com.kh/215153/
# [356] ✔ Success: https://www.realestate.com.kh/235637/
# [361] ✔ Success: https://www.realestate.com.kh/215538/
# [362] ✔ Success: https://www.realestate.com.kh/215696/
# [360] ✔ Success: https://www.realestate.com.kh/213823/
# [359] ✔ Success: https://www.realestate.com.kh/213905/
# [365] ✔ Success: https://www.realestate.com.kh/215546/
# [366] ✔ Success: https://www.realestate.com.kh/213102/
# [364] ✔ Success: https://www.realestate.com.kh/217751/
# [367] ✔ Success: https://www.realestate.com.kh/215441/
# [373] ✔ Success: https://www.realestate.com.kh/214416/
# [368] ✔ Success: https://www.realestate.com.kh/215547/
# [370] ✔ Success: https://www.realestate.com.kh/215483/
# [369] ✔ Success: https://www.realestate.com.kh/216072/
# [372] ✔ Success: https://www.realestate.com.kh/217907/
# [371] ✔ Success: https://www.realestate.com.kh/217637/
# [379] ✔ Success: https://www.realestate.com.kh/208638/
# [375] ✔ Success: https://www.realestate.com.kh/217550/
# [377] ✔ Success: https://www.realestate.com.kh/207183/
# [376] ✔ Success: https://www.realestate.com.kh/163233/
# [374] ✔ Success: https://www.realestate.com.kh/216995/
# [378] ✔ Success: https://www.realestate.com.kh/207177/
# [380] ✔ Success: https://www.realestate.com.kh/208641/
# [381] ✔ Success: https://www.realestate.com.kh/209784/
# [387] ✔ Success: https://www.realestate.com.kh/224210/
# [383] ✔ Success: https://www.realestate.com.kh/209742/
# [388] ✔ Success: https://www.realestate.com.kh/220215/
# [384] ✔ Success: https://www.realestate.com.kh/209744/
# [385] ✔ Success: https://www.realestate.com.kh/209758/
# [386] ✔ Success: https://www.realestate.com.kh/223492/
# [382] ✔ Success: https://www.realestate.com.kh/209739/
# [390] ✔ Success: https://www.realestate.com.kh/201952/
# [389] ✔ Success: https://www.realestate.com.kh/224055/
# [395] ✔ Success: https://www.realestate.com.kh/235073/
# [398] ✔ Success: https://www.realestate.com.kh/197395/
# [392] ✔ Success: https://www.realestate.com.kh/210732/
# [397] ✔ Success: https://www.realestate.com.kh/216630/
# [391] ✔ Success: https://www.realestate.com.kh/209752/
# [393] ✔ Success: https://www.realestate.com.kh/235093/
# [400] ✔ Success: https://www.realestate.com.kh/209750/
# [394] ✔ Success: https://www.realestate.com.kh/235092/
# [401] ✔ Success: https://www.realestate.com.kh/235988/
# [396] ✔ Success: https://www.realestate.com.kh/168638/
# [402] ✔ Success: https://www.realestate.com.kh/158296/
# [399] ✔ Success: https://www.realestate.com.kh/152691/
# [403] ✔ Success: https://www.realestate.com.kh/158299/
# [408] ✔ Success: https://www.realestate.com.kh/191449/
# [407] ✔ Success: https://www.realestate.com.kh/211993/
# [404] ✔ Success: https://www.realestate.com.kh/213511/
# [406] ✔ Success: https://www.realestate.com.kh/188144/
# [405] ✔ Success: https://www.realestate.com.kh/224984/
# [411] ✔ Success: https://www.realestate.com.kh/231417/
# [412] ✔ Success: https://www.realestate.com.kh/211915/
# [410] ✔ Success: https://www.realestate.com.kh/227750/
# [409] ✔ Success: https://www.realestate.com.kh/148130/
# [413] ✔ Success: https://www.realestate.com.kh/234387/
# [414] ✔ Success: https://www.realestate.com.kh/142364/
# [416] ✔ Success: https://www.realestate.com.kh/227038/
# [418] ✔ Success: https://www.realestate.com.kh/230379/
# [419] ✔ Success: https://www.realestate.com.kh/234082/
# [415] ✔ Success: https://www.realestate.com.kh/142374/
# [420] ✔ Success: https://www.realestate.com.kh/230128/
# [423] ✔ Success: https://www.realestate.com.kh/145784/
# [417] ✔ Success: https://www.realestate.com.kh/227743/
# [421] ✔ Success: https://www.realestate.com.kh/142375/
# [425] ✔ Success: https://www.realestate.com.kh/146883/
# [422] ✔ Success: https://www.realestate.com.kh/148115/
# [424] ✔ Success: https://www.realestate.com.kh/150446/
# [428] ✔ Success: https://www.realestate.com.kh/227040/
# [430] ✔ Success: https://www.realestate.com.kh/231468/
# [426] ✔ Success: https://www.realestate.com.kh/184968/
# [433] ✔ Success: https://www.realestate.com.kh/229620/
# [432] ✔ Success: https://www.realestate.com.kh/230020/
# [427] ✔ Success: https://www.realestate.com.kh/226480/
# [429] ✔ Success: https://www.realestate.com.kh/142199/
# [435] ✔ Success: https://www.realestate.com.kh/157856/
# [434] ✔ Success: https://www.realestate.com.kh/232148/
# [431] ✔ Success: https://www.realestate.com.kh/229989/
# [437] ✔ Success: https://www.realestate.com.kh/204651/
# [438] ✔ Success: https://www.realestate.com.kh/203009/
# [439] ✔ Success: https://www.realestate.com.kh/202901/
# [436] ✔ Success: https://www.realestate.com.kh/203793/
# [442] ✔ Success: https://www.realestate.com.kh/204914/
# [443] ✔ Success: https://www.realestate.com.kh/218870/
# [444] ✔ Success: https://www.realestate.com.kh/219790/
# [441] ✔ Success: https://www.realestate.com.kh/204397/
# [440] ✔ Success: https://www.realestate.com.kh/204957/
# [446] ✔ Success: https://www.realestate.com.kh/221215/
# [449] ✔ Success: https://www.realestate.com.kh/228345/
# [447] ✔ Success: https://www.realestate.com.kh/224386/
# [450] ✔ Success: https://www.realestate.com.kh/224466/
# [448] ✔ Success: https://www.realestate.com.kh/224450/
# [445] ✔ Success: https://www.realestate.com.kh/219672/
# [451] ✔ Success: https://www.realestate.com.kh/228255/
# [452] ✔ Success: https://www.realestate.com.kh/224838/
# [455] ✔ Success: https://www.realestate.com.kh/224800/
# [453] ✔ Success: https://www.realestate.com.kh/224837/
# [457] ✔ Success: https://www.realestate.com.kh/199456/
# [454] ✔ Success: https://www.realestate.com.kh/224527/
# [459] ✔ Success: https://www.realestate.com.kh/230223/
# [460] ✔ Success: https://www.realestate.com.kh/143666/
# [458] ✔ Success: https://www.realestate.com.kh/207423/
# [456] ✔ Success: https://www.realestate.com.kh/228551/
# [461] ✔ Success: https://www.realestate.com.kh/145781/
# [467] ✔ Success: https://www.realestate.com.kh/229683/
# [463] ✔ Success: https://www.realestate.com.kh/229963/
# [462] ✔ Success: https://www.realestate.com.kh/231403/
# [468] ✔ Success: https://www.realestate.com.kh/229666/
# [465] ✔ Success: https://www.realestate.com.kh/231461/
# [466] ✔ Success: https://www.realestate.com.kh/231460/
# [464] ✔ Success: https://www.realestate.com.kh/229744/
# [475] ✔ Success: https://www.realestate.com.kh/232726/
# [474] ✔ Success: https://www.realestate.com.kh/232285/
# [473] ✔ Success: https://www.realestate.com.kh/232462/
# [469] ✔ Success: https://www.realestate.com.kh/229980/
# [471] ✔ Success: https://www.realestate.com.kh/229818/
# [472] ✔ Success: https://www.realestate.com.kh/229780/
# [470] ✔ Success: https://www.realestate.com.kh/230149/
# [479] ✔ Success: https://www.realestate.com.kh/220767/
# [478] ✔ Success: https://www.realestate.com.kh/219767/
# [480] ✔ Success: https://www.realestate.com.kh/228485/
# [481] ✔ Success: https://www.realestate.com.kh/223801/
# [477] ✔ Success: https://www.realestate.com.kh/157846/
# [476] ✔ Success: https://www.realestate.com.kh/233476/
# [482] ✔ Success: https://www.realestate.com.kh/226624/
# [483] ✔ Success: https://www.realestate.com.kh/207031/
# [486] ✔ Success: https://www.realestate.com.kh/178624/
# [485] ✔ Success: https://www.realestate.com.kh/145782/
# [484] ✔ Success: https://www.realestate.com.kh/189835/
# [491] ✔ Success: https://www.realestate.com.kh/229692/
# [487] ✔ Success: https://www.realestate.com.kh/231453/
# [492] ✔ Success: https://www.realestate.com.kh/232970/[488] ✔ Success: https://www.realestate.com.kh/232948/
#
# [494] ✔ Success: https://www.realestate.com.kh/229976/
# [490] ✔ Success: https://www.realestate.com.kh/231578/
# [495] ✔ Success: https://www.realestate.com.kh/229853/
# [496] ✔ Success: https://www.realestate.com.kh/230600/
# [493] ✔ Success: https://www.realestate.com.kh/229917/
# [498] ✔ Success: https://www.realestate.com.kh/231377/
# [497] ✔ Success: https://www.realestate.com.kh/230593/
# [489] ✔ Success: https://www.realestate.com.kh/230990/
# [502] ✔ Success: https://www.realestate.com.kh/231385/
# [500] ✔ Success: https://www.realestate.com.kh/233157/
# [499] ✔ Success: https://www.realestate.com.kh/229929/
# [506] ✔ Success: https://www.realestate.com.kh/219459/
# [501] ✔ Success: https://www.realestate.com.kh/232191/
# [503] ✔ Success: https://www.realestate.com.kh/230132/
# [504] ✔ Success: https://www.realestate.com.kh/220634/
# [505] ✔ Success: https://www.realestate.com.kh/219656/
# [508] ✔ Success: https://www.realestate.com.kh/228474/
# [507] ✔ Success: https://www.realestate.com.kh/224373/
# [509] ✔ Success: https://www.realestate.com.kh/224413/
# [514] ✔ Success: https://www.realestate.com.kh/156343/
# [512] ✔ Success: https://www.realestate.com.kh/224850/
# [516] ✔ Success: https://www.realestate.com.kh/182945/
# [511] ✔ Success: https://www.realestate.com.kh/228323/
# [510] ✔ Success: https://www.realestate.com.kh/224455/
# [517] ✔ Success: https://www.realestate.com.kh/162489/
# [513] ✔ Success: https://www.realestate.com.kh/224833/
# [515] ✔ Success: https://www.realestate.com.kh/143405/
# [520] ✔ Success: https://www.realestate.com.kh/181595/
# [519] ✔ Success: https://www.realestate.com.kh/181709/
# [518] ✔ Success: https://www.realestate.com.kh/181707/
# [521] ✔ Success: https://www.realestate.com.kh/230952/
# [523] ✔ Success: https://www.realestate.com.kh/230220/
# [522] ✔ Success: https://www.realestate.com.kh/231416/
# [526] ✔ Success: https://www.realestate.com.kh/231443/
# [524] ✔ Success: https://www.realestate.com.kh/231138/
# [525] ✔ Success: https://www.realestate.com.kh/231136/
# [528] ✔ Success: https://www.realestate.com.kh/229825/
# [527] ✔ Success: https://www.realestate.com.kh/232607/
# [529] ✔ Success: https://www.realestate.com.kh/229686/
# [530] ✔ Success: https://www.realestate.com.kh/231634/
# [531] ✔ Success: https://www.realestate.com.kh/229836/
# [532] ✔ Success: https://www.realestate.com.kh/232288/
# [533] ✔ Success: https://www.realestate.com.kh/231371/
# [534] ✔ Success: https://www.realestate.com.kh/155457/
# [536] ✔ Success: https://www.realestate.com.kh/219937/
# [535] ✔ Success: https://www.realestate.com.kh/223146/
# [539] ✔ Success: https://www.realestate.com.kh/221810/
# [538] ✔ Success: https://www.realestate.com.kh/219675/
# [540] ✔ Success: https://www.realestate.com.kh/227938/
# [537] ✔ Success: https://www.realestate.com.kh/223339/
# [541] ✔ Success: https://www.realestate.com.kh/224456/
# [542] ✔ Success: https://www.realestate.com.kh/224471/
# [545] ✔ Success: https://www.realestate.com.kh/224534/
# [544] ✔ Success: https://www.realestate.com.kh/224516/
# [543] ✔ Success: https://www.realestate.com.kh/224842/
# [548] ✔ Success: https://www.realestate.com.kh/224713/
# [550] ✔ Success: https://www.realestate.com.kh/198139/
# [546] ✔ Success: https://www.realestate.com.kh/224788/
# [547] ✔ Success: https://www.realestate.com.kh/224729/
# [551] ✔ Success: https://www.realestate.com.kh/219270/
# [549] ✔ Success: https://www.realestate.com.kh/198159/
# [553] ✔ Success: https://www.realestate.com.kh/231526/
# [552] ✔ Success: https://www.realestate.com.kh/232656/
# [554] ✔ Success: https://www.realestate.com.kh/232421/
# [555] ✔ Success: https://www.realestate.com.kh/178564/
# [557] ✔ Success: https://www.realestate.com.kh/233324/
# [558] ✔ Success: https://www.realestate.com.kh/231563/
# [556] ✔ Success: https://www.realestate.com.kh/160280/
# [559] ✔ Success: https://www.realestate.com.kh/229905/
# [563] ✔ Success: https://www.realestate.com.kh/221595/
# [562] ✔ Success: https://www.realestate.com.kh/188311/
# [560] ✔ Success: https://www.realestate.com.kh/229834/
# [564] ✔ Success: https://www.realestate.com.kh/219944/
# [566] ✔ Success: https://www.realestate.com.kh/219461/
# [561] ✔ Success: https://www.realestate.com.kh/229687/
# [565] ✔ Success: https://www.realestate.com.kh/219927/
# [567] ✔ Success: https://www.realestate.com.kh/227967/
# [570] ✔ Success: https://www.realestate.com.kh/224479/
# [568] ✔ Success: https://www.realestate.com.kh/228483/
# [573] ✔ Success: https://www.realestate.com.kh/224590/
# [571] ✔ Success: https://www.realestate.com.kh/224519/
# [569] ✔ Success: https://www.realestate.com.kh/224412/
# [575] ✔ Success: https://www.realestate.com.kh/224626/
# [574] ✔ Success: https://www.realestate.com.kh/224725/
# [576] ✔ Success: https://www.realestate.com.kh/153278/
# [572] ✔ Success: https://www.realestate.com.kh/224544/
# [579] ✔ Success: https://www.realestate.com.kh/231606/
# [578] ✔ Success: https://www.realestate.com.kh/230023/
# [577] ✔ Success: https://www.realestate.com.kh/140569/
# [582] ✔ Success: https://www.realestate.com.kh/155907/
# [581] ✔ Success: https://www.realestate.com.kh/155908/
# [580] ✔ Success: https://www.realestate.com.kh/230095/
# [583] ✔ Success: https://www.realestate.com.kh/204337/
# [584] ✔ Success: https://www.realestate.com.kh/203966/
# [588] ✔ Success: https://www.realestate.com.kh/219349/
# [587] ✔ Success: https://www.realestate.com.kh/220768/
# [589] ✔ Success: https://www.realestate.com.kh/226207/
# [586] ✔ Success: https://www.realestate.com.kh/222689/
# [585] ✔ Success: https://www.realestate.com.kh/203784/
# [590] ✔ Success: https://www.realestate.com.kh/226472/
# [591] ✔ Success: https://www.realestate.com.kh/228477/
# [593] ✔ Success: https://www.realestate.com.kh/224395/
# [598] ✔ Success: https://www.realestate.com.kh/226905/
# [599] ✔ Success: https://www.realestate.com.kh/224812/
# [594] ✔ Success: https://www.realestate.com.kh/224484/
# [595] ✔ Success: https://www.realestate.com.kh/224495/
# [597] ✔ Success: https://www.realestate.com.kh/224498/
# [592] ✔ Success: https://www.realestate.com.kh/210166/
# [596] ✔ Success: https://www.realestate.com.kh/224860/
# [600] ✔ Success: https://www.realestate.com.kh/224806/
# [601] ✔ Success: https://www.realestate.com.kh/224565/
# [603] ✔ Success: https://www.realestate.com.kh/224739/
# [604] ✔ Success: https://www.realestate.com.kh/224744/
# [602] ✔ Success: https://www.realestate.com.kh/224745/
# [605] ✔ Success: https://www.realestate.com.kh/145173/
# [606] ✔ Success: https://www.realestate.com.kh/141866/
# [607] ✔ Success: https://www.realestate.com.kh/231452/
# [608] ✔ Success: https://www.realestate.com.kh/229875/
# [611] ✔ Success: https://www.realestate.com.kh/231361/
# [610] ✔ Success: https://www.realestate.com.kh/229858/
# [609] ✔ Success: https://www.realestate.com.kh/229759/
# [613] ✔ Success: https://www.realestate.com.kh/230106/
# [612] ✔ Success: https://www.realestate.com.kh/232459/
# [614] ✔ Success: https://www.realestate.com.kh/233536/
# [618] ✔ Success: https://www.realestate.com.kh/224370/
# [617] ✔ Success: https://www.realestate.com.kh/219463/
# [621] ✔ Success: https://www.realestate.com.kh/224420/
# [620] ✔ Success: https://www.realestate.com.kh/224409/
# [619] ✔ Success: https://www.realestate.com.kh/224407/
# [616] ✔ Success: https://www.realestate.com.kh/223147/
# [623] ✔ Success: https://www.realestate.com.kh/224475/
# [624] ✔ Success: https://www.realestate.com.kh/224530/
# [625] ✔ Success: https://www.realestate.com.kh/224786/
# [615] ✔ Success: https://www.realestate.com.kh/160146/
# [622] ✔ Success: https://www.realestate.com.kh/224458/
# [626] ✔ Success: https://www.realestate.com.kh/223542/
# [627] ✔ Success: https://www.realestate.com.kh/228120/
# [631] ✔ Success: https://www.realestate.com.kh/219277/
# [629] ✔ Success: https://www.realestate.com.kh/232289/
# [630] ✔ Success: https://www.realestate.com.kh/219857/
# [628] ✔ Success: https://www.realestate.com.kh/207318/
# [632] ✔ Success: https://www.realestate.com.kh/223165/
# [633] ✔ Success: https://www.realestate.com.kh/230332/
# [636] ✔ Success: https://www.realestate.com.kh/186977/
# [635] ✔ Success: https://www.realestate.com.kh/200362/
# [637] ✔ Success: https://www.realestate.com.kh/230793/
# [639] ✔ Success: https://www.realestate.com.kh/230124/
# [634] ✔ Success: https://www.realestate.com.kh/142504/
# [638] ✔ Success: https://www.realestate.com.kh/234421/
# [640] ✔ Success: https://www.realestate.com.kh/212281/
# [644] ✔ Success: https://www.realestate.com.kh/146234/
# [641] ✔ Success: https://www.realestate.com.kh/218906/[643] ✔ Success: https://www.realestate.com.kh/218674/
#
# [645] ✔ Success: https://www.realestate.com.kh/231080/
# [642] ✔ Success: https://www.realestate.com.kh/222668/
# [649] ✔ Success: https://www.realestate.com.kh/230122/
# [648] ✔ Success: https://www.realestate.com.kh/147934/
# [647] ✔ Success: https://www.realestate.com.kh/199865/
# [646] ✔ Success: https://www.realestate.com.kh/200069/
# [652] ✔ Success: https://www.realestate.com.kh/218672/
# [651] ✔ Success: https://www.realestate.com.kh/230146/
# [650] ✔ Success: https://www.realestate.com.kh/148864/
# [654] ✔ Success: https://www.realestate.com.kh/230574/
# [653] ✔ Success: https://www.realestate.com.kh/152486/
# [656] ✔ Success: https://www.realestate.com.kh/190229/
# [657] ✔ Success: https://www.realestate.com.kh/231087/
# [658] ✔ Success: https://www.realestate.com.kh/203812/
# [655] ✔ Success: https://www.realestate.com.kh/228148/
# [660] ✔ Success: https://www.realestate.com.kh/203062/
# [663] ✔ Success: https://www.realestate.com.kh/224548/
# [662] ✔ Success: https://www.realestate.com.kh/228549/
# [659] ✔ Success: https://www.realestate.com.kh/224790/
# [661] ✔ Success: https://www.realestate.com.kh/218198/
# [664] ✔ Success: https://www.realestate.com.kh/224736/
# [666] ✔ Success: https://www.realestate.com.kh/190222/
# [668] ✔ Success: https://www.realestate.com.kh/227976/
# [669] ✔ Success: https://www.realestate.com.kh/224388/
# [670] ✔ Success: https://www.realestate.com.kh/158848/
# [665] ✔ Success: https://www.realestate.com.kh/221212/
# [667] ✔ Success: https://www.realestate.com.kh/228384/
# [673] ✔ Success: https://www.realestate.com.kh/231386/
# [671] ✔ Success: https://www.realestate.com.kh/182953/
# [675] ✔ Success: https://www.realestate.com.kh/231550/
# [672] ✔ Success: https://www.realestate.com.kh/220437/
# [676] ✔ Success: https://www.realestate.com.kh/229930/
# [674] ✔ Success: https://www.realestate.com.kh/231388/
# [677] ✔ Success: https://www.realestate.com.kh/224820/
# [678] ✔ Success: https://www.realestate.com.kh/228544/
# [681] ✔ Success: https://www.realestate.com.kh/207764/
# [679] ✔ Success: https://www.realestate.com.kh/186910/
# [680] ✔ Success: https://www.realestate.com.kh/188617/
# [685] ✔ Success: https://www.realestate.com.kh/206544/
# [687] ✔ Success: https://www.realestate.com.kh/123429/
# [682] ✔ Success: https://www.realestate.com.kh/207779/
# [688] ✔ Success: https://www.realestate.com.kh/234539/
# [683] ✔ Success: https://www.realestate.com.kh/157918/
# [684] ✔ Success: https://www.realestate.com.kh/215482/
# [686] ✔ Success: https://www.realestate.com.kh/208704/
# [689] ✔ Success: https://www.realestate.com.kh/234383/
# [690] ✔ Success: https://www.realestate.com.kh/219512/
# [695] ✔ Success: https://www.realestate.com.kh/215142/
# [696] ✔ Success: https://www.realestate.com.kh/215990/
# [693] ✔ Success: https://www.realestate.com.kh/188145/
# [692] ✔ Success: https://www.realestate.com.kh/193716/
# [691] ✔ Success: https://www.realestate.com.kh/219254/
# [697] ✔ Success: https://www.realestate.com.kh/157961/
# [699] ✔ Success: https://www.realestate.com.kh/188300/
# [698] ✔ Success: https://www.realestate.com.kh/155905/
# [694] ✔ Success: https://www.realestate.com.kh/212986/
# [700] ✔ Success: https://www.realestate.com.kh/234307/
# [703] ✔ Success: https://www.realestate.com.kh/234720/
# [706] ✔ Success: https://www.realestate.com.kh/207940/
# [702] ✔ Success: https://www.realestate.com.kh/234301/
# [710] ✔ Success: https://www.realestate.com.kh/215436/
# [701] ✔ Success: https://www.realestate.com.kh/235565/
# [704] ✔ Success: https://www.realestate.com.kh/234540/
# [705] ✔ Success: https://www.realestate.com.kh/217947/
# [707] ✔ Success: https://www.realestate.com.kh/210024/
# [708] ✔ Success: https://www.realestate.com.kh/235035/
# [711] ✔ Success: https://www.realestate.com.kh/210557/
# [709] ✔ Success: https://www.realestate.com.kh/235346/
# [713] ✔ Success: https://www.realestate.com.kh/223157/
# [712] ✔ Success: https://www.realestate.com.kh/223150/
# [714] ✔ Success: https://www.realestate.com.kh/188147/
# [720] ✔ Success: https://www.realestate.com.kh/219753/
# [719] ✔ Success: https://www.realestate.com.kh/226464/
# [716] ✔ Success: https://www.realestate.com.kh/208362/
# [718] ✔ Success: https://www.realestate.com.kh/226477/
# [715] ✔ Success: https://www.realestate.com.kh/151856/
# [722] ✔ Success: https://www.realestate.com.kh/229027/
# [721] ✔ Success: https://www.realestate.com.kh/185620/
# [724] ✔ Success: https://www.realestate.com.kh/220945/
# [723] ✔ Success: https://www.realestate.com.kh/202801/
# [725] ✔ Success: https://www.realestate.com.kh/228903/
# [726] ✔ Success: https://www.realestate.com.kh/179537/
# [728] ✔ Success: https://www.realestate.com.kh/202794/
# [730] ✔ Success: https://www.realestate.com.kh/223759/
# [727] ✔ Success: https://www.realestate.com.kh/160087/
# [729] ✔ Success: https://www.realestate.com.kh/223812/
# [737] ✔ Success: https://www.realestate.com.kh/206715/
# [735] ✔ Success: https://www.realestate.com.kh/212326/
# [733] ✔ Success: https://www.realestate.com.kh/206576/
# [734] ✔ Success: https://www.realestate.com.kh/152440/
# [732] ✔ Success: https://www.realestate.com.kh/158303/
# [731] ✔ Success: https://www.realestate.com.kh/212387/
# [736] ✔ Success: https://www.realestate.com.kh/197513/
# [738] ✔ Success: https://www.realestate.com.kh/205824/
# [739] ✔ Success: https://www.realestate.com.kh/206552/
# [740] ✔ Success: https://www.realestate.com.kh/235820/
# [741] ✔ Success: https://www.realestate.com.kh/222842/
# [743] ✔ Success: https://www.realestate.com.kh/215624/
# [742] ✔ Success: https://www.realestate.com.kh/216362/
# [745] ✔ Success: https://www.realestate.com.kh/217001/
# [717] ✘ No span found: https://www.realestate.com.kh/134063/
# [744] ✔ Success: https://www.realestate.com.kh/215893/
# [746] ✔ Success: https://www.realestate.com.kh/150510/
# [749] ✔ Success: https://www.realestate.com.kh/212951/
# [748] ✔ Success: https://www.realestate.com.kh/199540/
# [747] ✔ Success: https://www.realestate.com.kh/149429/
# [750] ✔ Success: https://www.realestate.com.kh/212820/
# [752] ✔ Success: https://www.realestate.com.kh/210602/
# [751] ✔ Success: https://www.realestate.com.kh/149861/
# [754] ✔ Success: https://www.realestate.com.kh/216631/
# [753] ✔ Success: https://www.realestate.com.kh/217009/
# [755] ✔ Success: https://www.realestate.com.kh/219052/
# [756] ✔ Success: https://www.realestate.com.kh/218780/
# [757] ✔ Success: https://www.realestate.com.kh/217405/
# [761] ✔ Success: https://www.realestate.com.kh/219058/
# [758] ✔ Success: https://www.realestate.com.kh/212909/
# [762] ✔ Success: https://www.realestate.com.kh/223143/
# [765] ✔ Success: https://www.realestate.com.kh/215905/
# [760] ✔ Success: https://www.realestate.com.kh/212803/
# [764] ✔ Success: https://www.realestate.com.kh/222502/
# [763] ✔ Success: https://www.realestate.com.kh/218596/
# [759] ✔ Success: https://www.realestate.com.kh/212260/
# [767] ✔ Success: https://www.realestate.com.kh/213343/
# [768] ✔ Success: https://www.realestate.com.kh/218681/
# [771] ✔ Success: https://www.realestate.com.kh/212800/
# [766] ✔ Success: https://www.realestate.com.kh/148077/
# [769] ✔ Success: https://www.realestate.com.kh/218676/
# [770] ✔ Success: https://www.realestate.com.kh/146462/
# [772] ✔ Success: https://www.realestate.com.kh/212818/
# [773] ✔ Success: https://www.realestate.com.kh/199404/
# [774] ✔ Success: https://www.realestate.com.kh/198842/
# [775] ✔ Success: https://www.realestate.com.kh/197859/
# [777] ✔ Success: https://www.realestate.com.kh/229095/
# [778] ✔ Success: https://www.realestate.com.kh/229623/
# [779] ✔ Success: https://www.realestate.com.kh/229622/
# [776] ✔ Success: https://www.realestate.com.kh/224925/
# [780] ✔ Success: https://www.realestate.com.kh/144405/
# [782] ✔ Success: https://www.realestate.com.kh/232706/
# [781] ✔ Success: https://www.realestate.com.kh/147292/
# [788] ✔ Success: https://www.realestate.com.kh/229099/
# [784] ✔ Success: https://www.realestate.com.kh/234324/
# [786] ✔ Success: https://www.realestate.com.kh/200238/
# [785] ✔ Success: https://www.realestate.com.kh/224905/
# [783] ✔ Success: https://www.realestate.com.kh/235266/
# [790] ✔ Success: https://www.realestate.com.kh/229266/
# [787] ✔ Success: https://www.realestate.com.kh/229107/
# [789] ✔ Success: https://www.realestate.com.kh/229189/
# [795] ✔ Success: https://www.realestate.com.kh/201857/
# [796] ✔ Success: https://www.realestate.com.kh/228704/
# [794] ✔ Success: https://www.realestate.com.kh/231208/
# [791] ✔ Success: https://www.realestate.com.kh/229527/
# [793] ✔ Success: https://www.realestate.com.kh/141247/
# [792] ✔ Success: https://www.realestate.com.kh/141246/
# [798] ✔ Success: https://www.realestate.com.kh/228779/
# [800] ✔ Success: https://www.realestate.com.kh/228942/
# [799] ✔ Success: https://www.realestate.com.kh/228853/
# [797] ✔ Success: https://www.realestate.com.kh/228776/
# [801] ✔ Success: https://www.realestate.com.kh/229080/
# [803] ✔ Success: https://www.realestate.com.kh/230550/
# [802] ✔ Success: https://www.realestate.com.kh/235113/
# [805] ✔ Success: https://www.realestate.com.kh/235231/
# [804] ✔ Success: https://www.realestate.com.kh/231245/
# [807] ✔ Success: https://www.realestate.com.kh/208615/
# [809] ✔ Success: https://www.realestate.com.kh/208845/[806] ✔ Success: https://www.realestate.com.kh/164236/
#
# [815] ✔ Success: https://www.realestate.com.kh/234411/
# [813] ✔ Success: https://www.realestate.com.kh/187229/
# [811] ✔ Success: https://www.realestate.com.kh/235340/
# [810] ✔ Success: https://www.realestate.com.kh/235239/
# [808] ✔ Success: https://www.realestate.com.kh/208359/[812] ✔ Success: https://www.realestate.com.kh/233615/
#
# [814] ✔ Success: https://www.realestate.com.kh/207620/
# [817] ✔ Success: https://www.realestate.com.kh/157963/
# [818] ✔ Success: https://www.realestate.com.kh/207621/
# [816] ✔ Success: https://www.realestate.com.kh/233611/
# [820] ✔ Success: https://www.realestate.com.kh/185465/
# [825] ✔ Success: https://www.realestate.com.kh/207011/
# [819] ✔ Success: https://www.realestate.com.kh/207096/
# [821] ✔ Success: https://www.realestate.com.kh/182040/
# [826] ✔ Success: https://www.realestate.com.kh/210022/
# [827] ✔ Success: https://www.realestate.com.kh/208609/
# [824] ✔ Success: https://www.realestate.com.kh/182068/
# [823] ✔ Success: https://www.realestate.com.kh/182067/
# [828] ✔ Success: https://www.realestate.com.kh/184575/
# [822] ✔ Success: https://www.realestate.com.kh/228206/
# [830] ✔ Success: https://www.realestate.com.kh/223151/
# [829] ✔ Success: https://www.realestate.com.kh/224049/
# [838] ✔ Success: https://www.realestate.com.kh/202335/
# [831] ✔ Success: https://www.realestate.com.kh/224212/
# [832] ✔ Success: https://www.realestate.com.kh/223792/
# [834] ✔ Success: https://www.realestate.com.kh/207155/
# [836] ✔ Success: https://www.realestate.com.kh/210020/
# [835] ✔ Success: https://www.realestate.com.kh/206922/
# [833] ✔ Success: https://www.realestate.com.kh/210090/
# [837] ✔ Success: https://www.realestate.com.kh/224202/
# [839] ✔ Success: https://www.realestate.com.kh/202853/
# [840] ✔ Success: https://www.realestate.com.kh/215503/
# [845] ✔ Success: https://www.realestate.com.kh/236022/
# [841] ✔ Success: https://www.realestate.com.kh/215942/
# [847] ✔ Success: https://www.realestate.com.kh/236030/
# [846] ✔ Success: https://www.realestate.com.kh/236004/
# [849] ✔ Success: https://www.realestate.com.kh/235999/
# [842] ✔ Success: https://www.realestate.com.kh/216360/
# [848] ✔ Success: https://www.realestate.com.kh/236003/
# [843] ✔ Success: https://www.realestate.com.kh/223771/
# [850] ✔ Success: https://www.realestate.com.kh/235989/
# [844] ✔ Success: https://www.realestate.com.kh/135722/
# [853] ✔ Success: https://www.realestate.com.kh/206580/
# [852] ✔ Success: https://www.realestate.com.kh/207790/
# [851] ✔ Success: https://www.realestate.com.kh/205243/
# [859] ✔ Success: https://www.realestate.com.kh/199284/
# [857] ✔ Success: https://www.realestate.com.kh/207164/
# [855] ✔ Success: https://www.realestate.com.kh/207635/
# [858] ✔ Success: https://www.realestate.com.kh/206722/
# [856] ✔ Success: https://www.realestate.com.kh/206962/
# [854] ✔ Success: https://www.realestate.com.kh/207636/
# [860] ✔ Success: https://www.realestate.com.kh/152715/
# [863] ✔ Success: https://www.realestate.com.kh/217121/
# [861] ✔ Success: https://www.realestate.com.kh/162344/
# [862] ✔ Success: https://www.realestate.com.kh/213820/
# [866] ✔ Success: https://www.realestate.com.kh/207624/
# [869] ✔ Success: https://www.realestate.com.kh/206760/
# [864] ✔ Success: https://www.realestate.com.kh/219257/
# [868] ✔ Success: https://www.realestate.com.kh/207131/
# [865] ✔ Success: https://www.realestate.com.kh/207242/
# [872] ✔ Success: https://www.realestate.com.kh/218572/
# [871] ✔ Success: https://www.realestate.com.kh/219451/
# [867] ✔ Success: https://www.realestate.com.kh/206925/
# [870] ✔ Success: https://www.realestate.com.kh/210636/
# [874] ✔ Success: https://www.realestate.com.kh/207614/
# ...
# [6084] ✔ Success: https://www.realestate.com.kh/237561/
# [6085] ✔ Success: https://www.realestate.com.kh/237657/
# [6087] ✔ Success: https://www.realestate.com.kh/237924/[6082] ✔ Success: https://www.realestate.com.kh/237451/
#
# [6083] ✔ Success: https://www.realestate.com.kh/237450/
# [6089] ✔ Success: https://www.realestate.com.kh/237917/
# [6094] ✔ Success: https://www.realestate.com.kh/149265/
# [6096] ✔ Success: https://www.realestate.com.kh/238047/
# [6090] ✔ Success: https://www.realestate.com.kh/238048/
# [6095] ✔ Success: https://www.realestate.com.kh/238095/
# [6092] ✔ Success: https://www.realestate.com.kh/145991/
# [6091] ✔ Success: https://www.realestate.com.kh/238046/
# [6093] ✔ Success: https://www.realestate.com.kh/147381/
# [6100] ✔ Success: https://www.realestate.com.kh/239128/
# [6102] ✔ Success: https://www.realestate.com.kh/192318/
# [6097] ✔ Success: https://www.realestate.com.kh/238422/
# [6098] ✔ Success: https://www.realestate.com.kh/239569/
# [6104] ✔ Success: https://www.realestate.com.kh/223826/
# [6099] ✔ Success: https://www.realestate.com.kh/239650/
# [6103] ✔ Success: https://www.realestate.com.kh/192190/
# [6106] ✔ Success: https://www.realestate.com.kh/165096/
# [6101] ✔ Success: https://www.realestate.com.kh/229959/
# [6105] ✔ Success: https://www.realestate.com.kh/234228/
# [6108] ✔ Success: https://www.realestate.com.kh/188939/
# [6107] ✔ Success: https://www.realestate.com.kh/188941/
# [6110] ✔ Success: https://www.realestate.com.kh/122689/
# [6111] ✔ Success: https://www.realestate.com.kh/223098/
# [6109] ✔ Success: https://www.realestate.com.kh/122540/
# [6113] ✔ Success: https://www.realestate.com.kh/122410/
# [6112] ✔ Success: https://www.realestate.com.kh/220537/
# [6115] ✔ Success: https://www.realestate.com.kh/199000/
# [6116] ✔ Success: https://www.realestate.com.kh/124750/
# [6114] ✔ Success: https://www.realestate.com.kh/145921/
# [6117] ✔ Success: https://www.realestate.com.kh/221373/
# [6119] ✔ Success: https://www.realestate.com.kh/202527/
# [6118] ✔ Success: https://www.realestate.com.kh/202261/
# [6120] ✔ Success: https://www.realestate.com.kh/192167/
# [6121] ✔ Success: https://www.realestate.com.kh/217614/
# [6122] ✔ Success: https://www.realestate.com.kh/228956/
# [6127] ✔ Success: https://www.realestate.com.kh/215015/
# [6126] ✔ Success: https://www.realestate.com.kh/229618/
# [6124] ✔ Success: https://www.realestate.com.kh/201578/
# [6125] ✔ Success: https://www.realestate.com.kh/103473/
# [6123] ✔ Success: https://www.realestate.com.kh/229001/
# [6128] ✔ Success: https://www.realestate.com.kh/201539/
# [6133] ✔ Success: https://www.realestate.com.kh/215254/
# [6130] ✔ Success: https://www.realestate.com.kh/121196/
# [6129] ✔ Success: https://www.realestate.com.kh/200308/
# [6131] ✔ Success: https://www.realestate.com.kh/120993/
# [6138] ✔ Success: https://www.realestate.com.kh/146921/
# [6135] ✔ Success: https://www.realestate.com.kh/121198/[6136] ✔ Success: https://www.realestate.com.kh/121197/
#
# [6132] ✔ Success: https://www.realestate.com.kh/226976/
# [6137] ✔ Success: https://www.realestate.com.kh/178490/
# [6134] ✔ Success: https://www.realestate.com.kh/121200/
# [6143] ✔ Success: https://www.realestate.com.kh/243297/
# [6144] ✔ Success: https://www.realestate.com.kh/243299/
# [6140] ✔ Success: https://www.realestate.com.kh/242418/
# [6141] ✔ Success: https://www.realestate.com.kh/227926/
# [6142] ✔ Success: https://www.realestate.com.kh/243301/
# [6145] ✔ Success: https://www.realestate.com.kh/243505/[6146] ✔ Success: https://www.realestate.com.kh/243502/
#
# [6139] ✔ Success: https://www.realestate.com.kh/197036/
# [6147] ✔ Success: https://www.realestate.com.kh/243378/
# [6149] ✔ Success: https://www.realestate.com.kh/243277/
# [6151] ✔ Success: https://www.realestate.com.kh/243302/
# [6150] ✔ Success: https://www.realestate.com.kh/138611/
# [6148] ✔ Success: https://www.realestate.com.kh/228187/
# [6155] ✔ Success: https://www.realestate.com.kh/246159/
# [6156] ✔ Success: https://www.realestate.com.kh/246146/
# [6153] ✔ Success: https://www.realestate.com.kh/245608/
# [6152] ✔ Success: https://www.realestate.com.kh/243554/
# [6157] ✔ Success: https://www.realestate.com.kh/246709/
# [6154] ✔ Success: https://www.realestate.com.kh/172111/
# [6158] ✔ Success: https://www.realestate.com.kh/246708/
# [6162] ✔ Success: https://www.realestate.com.kh/243278/
# [6160] ✔ Success: https://www.realestate.com.kh/246990/
# [6159] ✔ Success: https://www.realestate.com.kh/232352/
# [6163] ✔ Success: https://www.realestate.com.kh/249740/
# [6161] ✔ Success: https://www.realestate.com.kh/236264/
# [6164] ✔ Success: https://www.realestate.com.kh/248765/
# [6165] ✔ Success: https://www.realestate.com.kh/192205/
# [6167] ✔ Success: https://www.realestate.com.kh/249384/
# [6166] ✔ Success: https://www.realestate.com.kh/230048/
# [6168] ✔ Success: https://www.realestate.com.kh/249386/
# [6170] ✔ Success: https://www.realestate.com.kh/246123/
# [6172] ✔ Success: https://www.realestate.com.kh/249486/
# [6169] ✔ Success: https://www.realestate.com.kh/249392/
# [6171] ✔ Success: https://www.realestate.com.kh/249570/
# [6173] ✔ Success: https://www.realestate.com.kh/249482/
# [6176] ✔ Success: https://www.realestate.com.kh/249736/
# [6175] ✔ Success: https://www.realestate.com.kh/249516/
# [6174] ✔ Success: https://www.realestate.com.kh/249455/
# [6177] ✔ Success: https://www.realestate.com.kh/229643/
# [6178] ✔ Success: https://www.realestate.com.kh/245453/
# [6180] ✔ Success: https://www.realestate.com.kh/220923/
# [6179] ✔ Success: https://www.realestate.com.kh/120718/
# [6184] ✔ Success: https://www.realestate.com.kh/235526/
# [6182] ✔ Success: https://www.realestate.com.kh/252011/
# [6183] ✔ Success: https://www.realestate.com.kh/233154/
# [6185] ✔ Success: https://www.realestate.com.kh/234777/
# [6181] ✔ Success: https://www.realestate.com.kh/222258/
# [6187] ✔ Success: https://www.realestate.com.kh/234896/
# [6188] ✔ Success: https://www.realestate.com.kh/223422/
# [6186] ✔ Success: https://www.realestate.com.kh/235659/
# [6192] ✔ Success: https://www.realestate.com.kh/227935/
# [6194] ✔ Success: https://www.realestate.com.kh/231404/
# [6189] ✔ Success: https://www.realestate.com.kh/234710/
# [6190] ✔ Success: https://www.realestate.com.kh/230396/
# [6191] ✔ Success: https://www.realestate.com.kh/231324/
# [6193] ✔ Success: https://www.realestate.com.kh/160073/
# [6195] ✔ Success: https://www.realestate.com.kh/222173/
# [6196] ✔ Success: https://www.realestate.com.kh/146497/
# [6197] ✔ Success: https://www.realestate.com.kh/229850/
# [6198] ✔ Success: https://www.realestate.com.kh/201845/
# [6200] ✔ Success: https://www.realestate.com.kh/232745/
# [6199] ✔ Success: https://www.realestate.com.kh/230393/
# [6201] ✔ Success: https://www.realestate.com.kh/233163/
# [6202] ✔ Success: https://www.realestate.com.kh/230213/
# [6204] ✔ Success: https://www.realestate.com.kh/222320/
# [6203] ✔ Success: https://www.realestate.com.kh/160074/
# [6205] ✔ Success: https://www.realestate.com.kh/229584/
# [6206] ✔ Success: https://www.realestate.com.kh/229583/
# [6208] ✔ Success: https://www.realestate.com.kh/231176/
# [6207] ✔ Success: https://www.realestate.com.kh/231117/
# [6209] ✔ Success: https://www.realestate.com.kh/231063/
# [6210] ✔ Success: https://www.realestate.com.kh/160077/
# [6212] ✔ Success: https://www.realestate.com.kh/102975/
# [6211] ✔ Success: https://www.realestate.com.kh/154974/
# [6213] ✔ Success: https://www.realestate.com.kh/209949/
# [6216] ✔ Success: https://www.realestate.com.kh/235868/
# [6217] ✔ Success: https://www.realestate.com.kh/139728/
# [6215] ✔ Success: https://www.realestate.com.kh/236420/
# [6214] ✔ Success: https://www.realestate.com.kh/227601/
# [6223] ✔ Success: https://www.realestate.com.kh/231227/
# [6218] ✔ Success: https://www.realestate.com.kh/228571/
# [6219] ✔ Success: https://www.realestate.com.kh/232326/
# [6220] ✔ Success: https://www.realestate.com.kh/230399/
# [6222] ✔ Success: https://www.realestate.com.kh/231536/
# [6224] ✔ Success: https://www.realestate.com.kh/231210/
# [6225] ✔ Success: https://www.realestate.com.kh/230944/
# [6221] ✔ Success: https://www.realestate.com.kh/231325/
# [6226] ✔ Success: https://www.realestate.com.kh/216741/
# [6229] ✔ Success: https://www.realestate.com.kh/229922/
# [6230] ✔ Success: https://www.realestate.com.kh/236295/
# [6228] ✔ Success: https://www.realestate.com.kh/232846/
# [6227] ✔ Success: https://www.realestate.com.kh/234542/
# [6232] ✔ Success: https://www.realestate.com.kh/237375/
# [6231] ✔ Success: https://www.realestate.com.kh/237048/
# [6233] ✔ Success: https://www.realestate.com.kh/237664/
# [6234] ✔ Success: https://www.realestate.com.kh/236672/
# [6236] ✔ Success: https://www.realestate.com.kh/237876/
# [6235] ✔ Success: https://www.realestate.com.kh/236342/
# [6241] ✔ Success: https://www.realestate.com.kh/239564/
# [6237] ✔ Success: https://www.realestate.com.kh/238104/
# [6239] ✔ Success: https://www.realestate.com.kh/239453/
# [6238] ✔ Success: https://www.realestate.com.kh/238595/
# [6242] ✔ Success: https://www.realestate.com.kh/238801/
# [6243] ✔ Success: https://www.realestate.com.kh/238159/
# [6240] ✔ Success: https://www.realestate.com.kh/239488/
# [6244] ✔ Success: https://www.realestate.com.kh/238764/
# [6245] ✔ Success: https://www.realestate.com.kh/238765/
# [6246] ✔ Success: https://www.realestate.com.kh/237304/
# [6249] ✔ Success: https://www.realestate.com.kh/240211/
# [6248] ✔ Success: https://www.realestate.com.kh/237295/
# [6250] ✔ Success: https://www.realestate.com.kh/240105/
# [6247] ✔ Success: https://www.realestate.com.kh/153134/
# [6252] ✔ Success: https://www.realestate.com.kh/240603/
# [6253] ✔ Success: https://www.realestate.com.kh/240601/
# [6251] ✔ Success: https://www.realestate.com.kh/237794/
# [6256] ✔ Success: https://www.realestate.com.kh/240796/
# [6255] ✔ Success: https://www.realestate.com.kh/240722/
# [6254] ✔ Success: https://www.realestate.com.kh/240674/
# [6257] ✔ Success: https://www.realestate.com.kh/240798/
# [6258] ✔ Success: https://www.realestate.com.kh/239868/
# [6261] ✔ Success: https://www.realestate.com.kh/240837/
# [6260] ✔ Success: https://www.realestate.com.kh/240324/
# [6265] ✔ Success: https://www.realestate.com.kh/241189/
# [6259] ✔ Success: https://www.realestate.com.kh/240104/
# [6263] ✔ Success: https://www.realestate.com.kh/240949/
# [6262] ✔ Success: https://www.realestate.com.kh/240940/
# [6266] ✔ Success: https://www.realestate.com.kh/241182/
# [6267] ✔ Success: https://www.realestate.com.kh/241183/
# [6264] ✔ Success: https://www.realestate.com.kh/241180/
# [6273] ✔ Success: https://www.realestate.com.kh/193841/
# [6276] ✔ Success: https://www.realestate.com.kh/229626/
# [6270] ✔ Success: https://www.realestate.com.kh/231328/
# [6271] ✔ Success: https://www.realestate.com.kh/231118/
# [6268] ✔ Success: https://www.realestate.com.kh/239881/
# [6272] ✔ Success: https://www.realestate.com.kh/232610/
# [6274] ✔ Success: https://www.realestate.com.kh/229296/
# [6275] ✔ Success: https://www.realestate.com.kh/226301/
# [6269] ✔ Success: https://www.realestate.com.kh/231081/
# [6279] ✔ Success: https://www.realestate.com.kh/233035/[6277] ✔ Success: https://www.realestate.com.kh/241385/
#
# [6280] ✔ Success: https://www.realestate.com.kh/241480/
# [6278] ✔ Success: https://www.realestate.com.kh/241419/
# [6281] ✔ Success: https://www.realestate.com.kh/241569/
# [6283] ✔ Success: https://www.realestate.com.kh/242132/
# [6282] ✔ Success: https://www.realestate.com.kh/241620/
# [6284] ✔ Success: https://www.realestate.com.kh/242131/
# [6286] ✔ Success: https://www.realestate.com.kh/242350/
# [6285] ✔ Success: https://www.realestate.com.kh/214850/
# [6292] ✔ Success: https://www.realestate.com.kh/243614/
# [6287] ✔ Success: https://www.realestate.com.kh/241731/
# [6288] ✔ Success: https://www.realestate.com.kh/242908/[6290] ✔ Success: https://www.realestate.com.kh/243567/
#
# [6291] ✔ Success: https://www.realestate.com.kh/243575/
# [6289] ✔ Success: https://www.realestate.com.kh/111478/
# [6300] ✔ Success: https://www.realestate.com.kh/195287/
# [6296] ✔ Success: https://www.realestate.com.kh/245923/
# [6294] ✔ Success: https://www.realestate.com.kh/246264/
# [6298] ✔ Success: https://www.realestate.com.kh/111238/
# [6295] ✔ Success: https://www.realestate.com.kh/246177/
# [6303] ✔ Success: https://www.realestate.com.kh/247474/
# [6304] ✔ Success: https://www.realestate.com.kh/247473/
# [6293] ✔ Success: https://www.realestate.com.kh/246114/
# [6297] ✔ Success: https://www.realestate.com.kh/162434/
# [6306] ✔ Success: https://www.realestate.com.kh/195289/
# [6307] ✔ Success: https://www.realestate.com.kh/235172/
# [6301] ✔ Success: https://www.realestate.com.kh/244355/
# [6308] ✔ Success: https://www.realestate.com.kh/249978/
# [6305] ✔ Success: https://www.realestate.com.kh/247472/
# [6299] ✔ Success: https://www.realestate.com.kh/246794/
# [6302] ✔ Success: https://www.realestate.com.kh/244090/
# [6309] ✔ Success: https://www.realestate.com.kh/108048/
# [6313] ✔ Success: https://www.realestate.com.kh/248890/
# [6311] ✔ Success: https://www.realestate.com.kh/249747/
# [6312] ✔ Success: https://www.realestate.com.kh/248681/
# [6310] ✔ Success: https://www.realestate.com.kh/53969/
# [6316] ✔ Success: https://www.realestate.com.kh/248061/
# [6314] ✔ Success: https://www.realestate.com.kh/247668/
# [6315] ✔ Success: https://www.realestate.com.kh/222294/
# [6317] ✔ Success: https://www.realestate.com.kh/51329/
# [6321] ✔ Success: https://www.realestate.com.kh/211192/
# [6319] ✔ Success: https://www.realestate.com.kh/248396/
# [6318] ✔ Success: https://www.realestate.com.kh/99158/
# [6320] ✔ Success: https://www.realestate.com.kh/252488/
# [6324] ✔ Success: https://www.realestate.com.kh/216163/
# [6323] ✔ Success: https://www.realestate.com.kh/223696/
# [6322] ✔ Success: https://www.realestate.com.kh/235842/
# [6326] ✔ Success: https://www.realestate.com.kh/231329/
# [6330] ✔ Success: https://www.realestate.com.kh/147236/
# [6325] ✔ Success: https://www.realestate.com.kh/212036/
# [6329] ✔ Success: https://www.realestate.com.kh/147234/
# [6332] ✔ Success: https://www.realestate.com.kh/238534/
# [6327] ✔ Success: https://www.realestate.com.kh/224394/
# [6328] ✔ Success: https://www.realestate.com.kh/231423/
# [6333] ✔ Success: https://www.realestate.com.kh/236107/
# [6331] ✔ Success: https://www.realestate.com.kh/224385/
# [6335] ✔ Success: https://www.realestate.com.kh/240869/
# [6336] ✔ Success: https://www.realestate.com.kh/229499/
# [6334] ✔ Success: https://www.realestate.com.kh/240699/
# [6337] ✔ Success: https://www.realestate.com.kh/226479/
# [6338] ✔ Success: https://www.realestate.com.kh/245623/
# [6339] ✔ Success: https://www.realestate.com.kh/229766/
# [6342] ✔ Success: https://www.realestate.com.kh/247669/
# [6341] ✔ Success: https://www.realestate.com.kh/247667/
# [6340] ✔ Success: https://www.realestate.com.kh/204108/
# [6343] ✔ Success: https://www.realestate.com.kh/229816/
# [6344] ✔ Success: https://www.realestate.com.kh/222866/
# [6345] ✔ Success: https://www.realestate.com.kh/250010/
# [6347] ✔ Success: https://www.realestate.com.kh/236033/
# [6348] ✔ Success: https://www.realestate.com.kh/224384/
# [6346] ✔ Success: https://www.realestate.com.kh/247284/
# [6349] ✔ Success: https://www.realestate.com.kh/223956/
# [6354] ✔ Success: https://www.realestate.com.kh/236032/
# [6355] ✔ Success: https://www.realestate.com.kh/206261/
# [6352] ✔ Success: https://www.realestate.com.kh/217653/
# [6351] ✔ Success: https://www.realestate.com.kh/235379/
# [6353] ✔ Success: https://www.realestate.com.kh/221010/
# [6350] ✔ Success: https://www.realestate.com.kh/232921/
# [6356] ✔ Success: https://www.realestate.com.kh/222493/
# [6358] ✔ Success: https://www.realestate.com.kh/209172/
# [6361] ✔ Success: https://www.realestate.com.kh/232292/
# [6359] ✔ Success: https://www.realestate.com.kh/209888/
# [6362] ✔ Success: https://www.realestate.com.kh/241358/
# [6357] ✔ Success: https://www.realestate.com.kh/224369/
# [6360] ✔ Success: https://www.realestate.com.kh/231472/
# [6363] ✔ Success: https://www.realestate.com.kh/245998/
# [6368] ✔ Success: https://www.realestate.com.kh/231160/
# [6365] ✔ Success: https://www.realestate.com.kh/217364/
# [6364] ✔ Success: https://www.realestate.com.kh/246364/
# [6366] ✔ Success: https://www.realestate.com.kh/231535/
# [6367] ✔ Success: https://www.realestate.com.kh/246457/

# %%
# Add a new column for language detection
df_all['language'] = None

# Iterate through the DataFrame to classify the language of the 'information' text
for i in range(len(df_all)):
    text = df_all.loc[i, 'information']
    if text: # Only classify if 'information' text is not None or empty
        lang, confidence = langid.classify(str(text))
        df_all.loc[i, 'language'] = lang
    else:
        df_all.loc[i, 'language'] = 'unknown' # Assign 'unknown' if no information was scraped

# %%
df_all.loc[~df_all['language'].isin(['en', 'km', 'ja', 'zh']), 'language'] = 'en' # Default to English for unrecognized languages
df_all.loc[df_all['language'].isin(['zh']), 'language'] = 'zh-CN' # Standardize Chinese to zh-CN

print("\nDataFrame after language detection and URL addition (first 5 rows):")
print(df_all.head()) # Print head to show new 'source_url' and 'language' columns
# Out:
# DataFrame after language detection and URL addition (first 5 rows):
#        id                                           headline price_display  \
# 0  204942  A flat (2 floors) near Hengly market and near ...      $150,000
# 1  211997  Twin Villa (Twin Villa) in Borey Highland 2005...      $269,000
# 2  212595                                     house for sale       $85,000
# 3  211987                    House for sale in Meanchey Area      $450,000
# 4  212653  House for Sale Urgently | Extra Space and Stai...       $85,000
#
#   rent_display  bedrooms  bathrooms  land_area  \
# 0                    6.0        4.0        NaN
# 1                    4.0        7.0        NaN
# 2                    2.0        2.0        NaN
# 3                    8.0        6.0        0.0
# 4                    2.0        2.0        NaN
#
#                                        thumbnail_url  \
# 0  https://images.realestate.com.kh/__sized__/lis...
# 1  https://images.realestate.com.kh/__sized__/lis...
# 2  https://images.realestate.com.kh/__sized__/lis...
# 3  https://images.realestate.com.kh/__sized__/lis...
# 4  https://images.realestate.com.kh/__sized__/lis...
#
#                                       thumbnail_urls  garages  ...  \
# 0  [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 1  [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 2  [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 3  [https://images.realestate.com.kh/__sized__/li...      3.0  ...
# 4  [https://images.realestate.com.kh/__sized__/li...      NaN  ...
#
#   address_subdivision address_locality      address_line_2  \
# 0          Phnom Penh         Meanchey    Stueng Mean chey
# 1          Phnom Penh          Sen Sok             Khmuonh
# 2          Phnom Penh       Chamkarmon               BKK 2
# 3          Phnom Penh         Meanchey  Stueng Mean chey 3
# 4          Phnom Penh         Meanchey       Boeung Tumpun
#
#                 address_line_1 category_name is_parent         type  \
# 0                                       Flat     False  residential
# 1                                 Twin Villa     False  residential
# 2                      117 117         House     False  residential
# 3          1 ផ្លូវលូប្រាំ(82c)          Flat     False  residential
# 4  ST. 45BT #4C, ST. 45BT #4C,          Flat     False  residential
#
#                                          information  \
# 0  A flat (2 floors) near Hengly market and near ...
# 1  Twin Villa (Twin Villa) in Borey Highland 2005...
# 2  មាន3ជាន់ 2បន្ទប់ទឹក បន្ទប់គេង2 អាចដាក់ម៉ូតូបាន...
# 3  I have a business house, I want to sell a hous...
# 4  ផ្ទះល្វែងលក់បន្ទាន់ 4m * 15.5m មានជណ្ដើរកៀន ចង...
#
#                               source_url language
# 0  https://www.realestate.com.kh/204942/       en
# 1  https://www.realestate.com.kh/211997/       en
# 2  https://www.realestate.com.kh/212595/       km
# 3  https://www.realestate.com.kh/211987/       en
# 4  https://www.realestate.com.kh/212653/       km
#
# [5 rows x 21 columns]

# %%
df_final_amount = df_all.groupby('address_subdivision').size().reset_index(name='Scraped_Count')

# %%
df_final_amount = pd.merge(
    df_province_summary,
    df_final_amount,
    left_on='Province',
    right_on='address_subdivision',
    how='left'
)
# Rename 'Count' from df_province_summary to 'API_Count' for clarity
df_final_amount = df_final_amount.rename(columns={'Count': 'API_Count'})
df_final_amount = df_final_amount.drop(columns=['address_subdivision']) # Drop duplicate column used for merging

print("\nFinal aggregated DataFrame (comparison of API counts vs. scraped counts):")
print(df_final_amount)
# Out:
# Final aggregated DataFrame (comparison of API counts vs. scraped counts):
#             Province  API_Count  Scraped_Count
# 0   Banteay Meanchey         11           10.0
# 1         Battambang         20           19.0
# 2       Kampong Cham         15           14.0
# 3    Kampong Chhnang          7            7.0
# 4       Kampong Speu         56           56.0
# 5       Kampong Thom         10            9.0
# 6             Kampot        100          100.0
# 7             Kandal        229          225.0
# 8                Kep         35           33.0
# 9           Koh Kong         21           21.0
# 10            Kratié          2            NaN
# 11        Mondulkiri          1            1.0
# 12    Oddar Meanchey          2            2.0
# 13            Pailin          3            3.0
# 14        Phnom Penh       4316         4210.0
# 15      Preah Vihear          3            3.0
# 16         Prey Veng          4            4.0
# 17            Pursat          7            7.0
# 18        Ratanakiri          3            3.0
# 19         Siem Reap       1460         1454.0
# 20     Sihanoukville        166          161.0
# 21       Stung Treng          3            3.0
# 22        Svay Rieng          3            3.0
# 23             Takeo         15           15.0
# 24      Tboung Khmum          4            4.0

# %%
df_all
# Out:
#           id                                           headline price_display  \
# 0     204942  A flat (2 floors) near Hengly market and near ...      $150,000
# 1     211997  Twin Villa (Twin Villa) in Borey Highland 2005...      $269,000
# 2     212595                                     house for sale       $85,000
# 3     211987                    House for sale in Meanchey Area      $450,000
# 4     212653  House for Sale Urgently | Extra Space and Stai...       $85,000
# ...      ...                                                ...           ...
# 6364  246364  Land in Phnom Tamao | Selling 60% below market...    $1,440,000
# 6365  217364                               ផ្ទះសំណាក់លក់បន្ទាន់           POA
# 6366  231535         ដី ចំការធូរ៉េន លក់ | Durian Farm For Sale    $100,000/m²
# 6367  246457                                      Land For Sale      $147,000
# 6368  231160  The land location is about 800 meters from Mem...      $100,000
#
#      rent_display  bedrooms  bathrooms  land_area  \
# 0                       6.0        4.0        NaN
# 1                       4.0        7.0        NaN
# 2                       2.0        2.0        NaN
# 3                       8.0        6.0        0.0
# 4                       2.0        2.0        NaN
# ...           ...       ...        ...        ...
# 6364                    NaN        NaN    80000.0
# 6365                   18.0       18.0        NaN
# 6366                    NaN        NaN        NaN
# 6367                    NaN        NaN    22317.0
# 6368                    NaN        NaN      530.0
#
#                                           thumbnail_url  \
# 0     https://images.realestate.com.kh/__sized__/lis...
# 1     https://images.realestate.com.kh/__sized__/lis...
# 2     https://images.realestate.com.kh/__sized__/lis...
# 3     https://images.realestate.com.kh/__sized__/lis...
# 4     https://images.realestate.com.kh/__sized__/lis...
# ...                                                 ...
# 6364  https://images.realestate.com.kh/__sized__/lis...
# 6365  https://images.realestate.com.kh/__sized__/lis...
# 6366  https://images.realestate.com.kh/__sized__/lis...
# 6367  https://images.realestate.com.kh/__sized__/lis...
# 6368  https://images.realestate.com.kh/__sized__/lis...
#
#                                          thumbnail_urls  garages  ...  \
# 0     [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 1     [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 2     [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 3     [https://images.realestate.com.kh/__sized__/li...      3.0  ...
# 4     [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# ...                                                 ...      ...  ...
# 6364  [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 6365  [https://images.realestate.com.kh/__sized__/li...      1.0  ...
# 6366  [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 6367  [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 6368  [https://images.realestate.com.kh/__sized__/li...      NaN  ...
#
#      address_subdivision address_locality      address_line_2  \
# 0             Phnom Penh         Meanchey    Stueng Mean chey
# 1             Phnom Penh          Sen Sok             Khmuonh
# 2             Phnom Penh       Chamkarmon               BKK 2
# 3             Phnom Penh         Meanchey  Stueng Mean chey 3
# 4             Phnom Penh         Meanchey       Boeung Tumpun
# ...                  ...              ...                 ...
# 6364               Takeo             Bati            Kandoeng
# 6365        Tboung Khmum     Ponhea Kraek               Kraek
# 6366        Tboung Khmum     Ponhea Kraek     Trapeang Phlong
# 6367        Tboung Khmum     Tboung Khmum        Roka Po Pram
# 6368        Tboung Khmum            Memot               Memot
#
#                    address_line_1     category_name is_parent         type  \
# 0                                              Flat     False  residential
# 1                                        Twin Villa     False  residential
# 2                         117 117             House     False  residential
# 3             1 ផ្លូវលូប្រាំ(82c)              Flat     False  residential
# 4     ST. 45BT #4C, ST. 45BT #4C,              Flat     False  residential
# ...                           ...               ...       ...          ...
# 6364                                           Land     False   commercial
# 6365                     72 St 72             House     False  residential
# 6366                               Land/Development     False  residential
# 6367              72 Pel 72C Phum  Land/Development     False  residential
# 6368             Memot 57 RGJ+MP,          Business     False   commercial
#
#                                             information  \
# 0     A flat (2 floors) near Hengly market and near ...
# 1     Twin Villa (Twin Villa) in Borey Highland 2005...
# 2     មាន3ជាន់ 2បន្ទប់ទឹក បន្ទប់គេង2 អាចដាក់ម៉ូតូបាន...
# 3     I have a business house, I want to sell a hous...
# 4     ផ្ទះល្វែងលក់បន្ទាន់ 4m * 15.5m មានជណ្ដើរកៀន ចង...
# ...                                                 ...
# 6364  Land in Phnom Tamao | Selling 60% below market...
# 6365  លក់ផ្ទះសំណាក់បន្ទាន់ តម្លៃសមរម្យដែលអាចចរចាបាន ...
# 6366  ដី ចំការធូរ៉េន លក់ | Durian Farm For Sale ទីតា...
# 6367  This Land area is located the middle of thaila...
# 6368  Lot near Memot market, big town, best for buil...
#
#                                  source_url language
# 0     https://www.realestate.com.kh/204942/       en
# 1     https://www.realestate.com.kh/211997/       en
# 2     https://www.realestate.com.kh/212595/       km
# 3     https://www.realestate.com.kh/211987/       en
# 4     https://www.realestate.com.kh/212653/       km
# ...                                     ...      ...
# 6364  https://www.realestate.com.kh/246364/       en
# 6365  https://www.realestate.com.kh/217364/       km
# 6366  https://www.realestate.com.kh/231535/       km
# 6367  https://www.realestate.com.kh/246457/       en
# 6368  https://www.realestate.com.kh/231160/       en
#
# [6369 rows x 21 columns]

# %%
df_all['language'].value_counts()
# Out:
# language
# en       5658
# km        425
# zh-CN     281
# ja          5
# Name: count, dtype: int64

# %%
from deep_translator import GoogleTranslator
for i in range(len(df_all)):
    if df_all.at[i, 'language'] != 'en':
        translated = GoogleTranslator(
            source=df_all.at[i, 'language'], 
            target='en'
        ).translate(df_all.at[i, 'information'])
        df_all.at[i, 'information'] = translated

# %%
df_all
# Out:
#           id                                           headline price_display  \
# 0     204942  A flat (2 floors) near Hengly market and near ...      $150,000
# 1     211997  Twin Villa (Twin Villa) in Borey Highland 2005...      $269,000
# 2     212595                                     house for sale       $85,000
# 3     211987                    House for sale in Meanchey Area      $450,000
# 4     212653  House for Sale Urgently | Extra Space and Stai...       $85,000
# ...      ...                                                ...           ...
# 6364  246364  Land in Phnom Tamao | Selling 60% below market...    $1,440,000
# 6365  217364                               ផ្ទះសំណាក់លក់បន្ទាន់           POA
# 6366  231535         ដី ចំការធូរ៉េន លក់ | Durian Farm For Sale    $100,000/m²
# 6367  246457                                      Land For Sale      $147,000
# 6368  231160  The land location is about 800 meters from Mem...      $100,000
#
#      rent_display  bedrooms  bathrooms  land_area  \
# 0                       6.0        4.0        NaN
# 1                       4.0        7.0        NaN
# 2                       2.0        2.0        NaN
# 3                       8.0        6.0        0.0
# 4                       2.0        2.0        NaN
# ...           ...       ...        ...        ...
# 6364                    NaN        NaN    80000.0
# 6365                   18.0       18.0        NaN
# 6366                    NaN        NaN        NaN
# 6367                    NaN        NaN    22317.0
# 6368                    NaN        NaN      530.0
#
#                                           thumbnail_url  \
# 0     https://images.realestate.com.kh/__sized__/lis...
# 1     https://images.realestate.com.kh/__sized__/lis...
# 2     https://images.realestate.com.kh/__sized__/lis...
# 3     https://images.realestate.com.kh/__sized__/lis...
# 4     https://images.realestate.com.kh/__sized__/lis...
# ...                                                 ...
# 6364  https://images.realestate.com.kh/__sized__/lis...
# 6365  https://images.realestate.com.kh/__sized__/lis...
# 6366  https://images.realestate.com.kh/__sized__/lis...
# 6367  https://images.realestate.com.kh/__sized__/lis...
# 6368  https://images.realestate.com.kh/__sized__/lis...
#
#                                          thumbnail_urls  garages  ...  \
# 0     [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 1     [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 2     [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 3     [https://images.realestate.com.kh/__sized__/li...      3.0  ...
# 4     [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# ...                                                 ...      ...  ...
# 6364  [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 6365  [https://images.realestate.com.kh/__sized__/li...      1.0  ...
# 6366  [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 6367  [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 6368  [https://images.realestate.com.kh/__sized__/li...      NaN  ...
#
#      address_subdivision address_locality      address_line_2  \
# 0             Phnom Penh         Meanchey    Stueng Mean chey
# 1             Phnom Penh          Sen Sok             Khmuonh
# 2             Phnom Penh       Chamkarmon               BKK 2
# 3             Phnom Penh         Meanchey  Stueng Mean chey 3
# 4             Phnom Penh         Meanchey       Boeung Tumpun
# ...                  ...              ...                 ...
# 6364               Takeo             Bati            Kandoeng
# 6365        Tboung Khmum     Ponhea Kraek               Kraek
# 6366        Tboung Khmum     Ponhea Kraek     Trapeang Phlong
# 6367        Tboung Khmum     Tboung Khmum        Roka Po Pram
# 6368        Tboung Khmum            Memot               Memot
#
#                    address_line_1     category_name is_parent         type  \
# 0                                              Flat     False  residential
# 1                                        Twin Villa     False  residential
# 2                         117 117             House     False  residential
# 3             1 ផ្លូវលូប្រាំ(82c)              Flat     False  residential
# 4     ST. 45BT #4C, ST. 45BT #4C,              Flat     False  residential
# ...                           ...               ...       ...          ...
# 6364                                           Land     False   commercial
# 6365                     72 St 72             House     False  residential
# 6366                               Land/Development     False  residential
# 6367              72 Pel 72C Phum  Land/Development     False  residential
# 6368             Memot 57 RGJ+MP,          Business     False   commercial
#
#                                             information  \
# 0     A flat (2 floors) near Hengly market and near ...
# 1     Twin Villa (Twin Villa) in Borey Highland 2005...
# 2     There are 3 floors 2 bedrooms, 2 bathrooms can...
# 3     I have a business house, I want to sell a hous...
# 4     Apartment Instast 4M * 15.5m There are 45M kit...
# ...                                                 ...
# 6364  Land in Phnom Tamao | Selling 60% below market...
# 6365  Selling negotiable emergency lodges, which are...
# 6366  Tucking Farm Sale | Durian Farm for Sale Locat...
# 6367  This Land area is located the middle of thaila...
# 6368  Lot near Memot market, big town, best for buil...
#
#                                  source_url language
# 0     https://www.realestate.com.kh/204942/       en
# 1     https://www.realestate.com.kh/211997/       en
# 2     https://www.realestate.com.kh/212595/       km
# 3     https://www.realestate.com.kh/211987/       en
# 4     https://www.realestate.com.kh/212653/       km
# ...                                     ...      ...
# 6364  https://www.realestate.com.kh/246364/       en
# 6365  https://www.realestate.com.kh/217364/       km
# 6366  https://www.realestate.com.kh/231535/       km
# 6367  https://www.realestate.com.kh/246457/       en
# 6368  https://www.realestate.com.kh/231160/       en
#
# [6369 rows x 21 columns]

# %%
# Ensure 'latitude' and 'longitude' columns exist
if 'latitude' not in df_all.columns:
    df_all['latitude'] = None
if 'longitude' not in df_all.columns:
    df_all['longitude'] = None

# Extract latitude and longitude from the 'location' column
# The 'location' column appears to be in the format [longitude, latitude]
for idx, row in df_all.iterrows():
    location_data = row.get('location') # Use .get() to safely access 'location'
    if isinstance(location_data, list) and len(location_data) == 2:
        df_all.at[idx, 'longitude'] = location_data[0]
        df_all.at[idx, 'latitude'] = location_data[1]
    else:
        # Handle cases where location data is missing or not in expected format
        df_all.at[idx, 'longitude'] = None
        df_all.at[idx, 'latitude'] = None

# %%
df_all
# Out:
#           id                                           headline price_display  \
# 0     204942  A flat (2 floors) near Hengly market and near ...      $150,000
# 1     211997  Twin Villa (Twin Villa) in Borey Highland 2005...      $269,000
# 2     212595                                     house for sale       $85,000
# 3     211987                    House for sale in Meanchey Area      $450,000
# 4     212653  House for Sale Urgently | Extra Space and Stai...       $85,000
# ...      ...                                                ...           ...
# 6364  246364  Land in Phnom Tamao | Selling 60% below market...    $1,440,000
# 6365  217364                               ផ្ទះសំណាក់លក់បន្ទាន់           POA
# 6366  231535         ដី ចំការធូរ៉េន លក់ | Durian Farm For Sale    $100,000/m²
# 6367  246457                                      Land For Sale      $147,000
# 6368  231160  The land location is about 800 meters from Mem...      $100,000
#
#      rent_display  bedrooms  bathrooms  land_area  \
# 0                       6.0        4.0        NaN
# 1                       4.0        7.0        NaN
# 2                       2.0        2.0        NaN
# 3                       8.0        6.0        0.0
# 4                       2.0        2.0        NaN
# ...           ...       ...        ...        ...
# 6364                    NaN        NaN    80000.0
# 6365                   18.0       18.0        NaN
# 6366                    NaN        NaN        NaN
# 6367                    NaN        NaN    22317.0
# 6368                    NaN        NaN      530.0
#
#                                           thumbnail_url  \
# 0     https://images.realestate.com.kh/__sized__/lis...
# 1     https://images.realestate.com.kh/__sized__/lis...
# 2     https://images.realestate.com.kh/__sized__/lis...
# 3     https://images.realestate.com.kh/__sized__/lis...
# 4     https://images.realestate.com.kh/__sized__/lis...
# ...                                                 ...
# 6364  https://images.realestate.com.kh/__sized__/lis...
# 6365  https://images.realestate.com.kh/__sized__/lis...
# 6366  https://images.realestate.com.kh/__sized__/lis...
# 6367  https://images.realestate.com.kh/__sized__/lis...
# 6368  https://images.realestate.com.kh/__sized__/lis...
#
#                                          thumbnail_urls  garages  ...  \
# 0     [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 1     [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 2     [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 3     [https://images.realestate.com.kh/__sized__/li...      3.0  ...
# 4     [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# ...                                                 ...      ...  ...
# 6364  [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 6365  [https://images.realestate.com.kh/__sized__/li...      1.0  ...
# 6366  [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 6367  [https://images.realestate.com.kh/__sized__/li...      NaN  ...
# 6368  [https://images.realestate.com.kh/__sized__/li...      NaN  ...
#
#           address_line_2               address_line_1     category_name  \
# 0       Stueng Mean chey                                           Flat
# 1                Khmuonh                                     Twin Villa
# 2                  BKK 2                      117 117             House
# 3     Stueng Mean chey 3          1 ផ្លូវលូប្រាំ(82c)              Flat
# 4          Boeung Tumpun  ST. 45BT #4C, ST. 45BT #4C,              Flat
# ...                  ...                          ...               ...
# 6364            Kandoeng                                           Land
# 6365               Kraek                     72 St 72             House
# 6366     Trapeang Phlong                               Land/Development
# 6367        Roka Po Pram              72 Pel 72C Phum  Land/Development
# 6368               Memot             Memot 57 RGJ+MP,          Business
#
#      is_parent         type  \
# 0        False  residential
# 1        False  residential
# 2        False  residential
# 3        False  residential
# 4        False  residential
# ...        ...          ...
# 6364     False   commercial
# 6365     False  residential
# 6366     False  residential
# 6367     False  residential
# 6368     False   commercial
#
#                                             information  \
# 0     A flat (2 floors) near Hengly market and near ...
# 1     Twin Villa (Twin Villa) in Borey Highland 2005...
# 2     There are 3 floors 2 bedrooms, 2 bathrooms can...
# 3     I have a business house, I want to sell a hous...
# 4     Apartment Instast 4M * 15.5m There are 45M kit...
# ...                                                 ...
# 6364  Land in Phnom Tamao | Selling 60% below market...
# 6365  Selling negotiable emergency lodges, which are...
# 6366  Tucking Farm Sale | Durian Farm for Sale Locat...
# 6367  This Land area is located the middle of thaila...
# 6368  Lot near Memot market, big town, best for buil...
#
#                                  source_url language   latitude   longitude
# 0     https://www.realestate.com.kh/204942/       en      11.53      104.91
# 1     https://www.realestate.com.kh/211997/       en      11.55      104.89
# 2     https://www.realestate.com.kh/212595/       km  11.554793  104.917136
# 3     https://www.realestate.com.kh/211987/       en  11.539648  104.886328
# 4     https://www.realestate.com.kh/212653/       km      11.55      104.93
# ...                                     ...      ...        ...         ...
# 6364  https://www.realestate.com.kh/246364/       en  11.297113  104.822738
# 6365  https://www.realestate.com.kh/217364/       km  11.761335   105.94432
# 6366  https://www.realestate.com.kh/231535/       km  11.709971  105.956464
# 6367  https://www.realestate.com.kh/246457/       en   12.04224  105.680894
# 6368  https://www.realestate.com.kh/231160/       en  11.824865  106.182672
#
# [6369 rows x 23 columns]

# %%
df_all.to_csv('../../../data/raw/realestates_kh_v2.csv')

# %%
df_all = pd.read_csv('../../../data/raw/realestates_kh_v2.csv')

# %%
df_all
# Out:
#       Unnamed: 0      id                                           headline  \
# 0              0  204942  A flat (2 floors) near Hengly market and near ...
# 1              1  211997  Twin Villa (Twin Villa) in Borey Highland 2005...
# 2              2  212595                                     house for sale
# 3              3  211987                    House for sale in Meanchey Area
# 4              4  212653  House for Sale Urgently | Extra Space and Stai...
# ...          ...     ...                                                ...
# 6364        6364  246364  Land in Phnom Tamao | Selling 60% below market...
# 6365        6365  217364                               ផ្ទះសំណាក់លក់បន្ទាន់
# 6366        6366  231535         ដី ចំការធូរ៉េន លក់ | Durian Farm For Sale
# 6367        6367  246457                                      Land For Sale
# 6368        6368  231160  The land location is about 800 meters from Mem...
#
#      price_display rent_display  bedrooms  bathrooms  land_area  \
# 0         $150,000          NaN       6.0        4.0        NaN
# 1         $269,000          NaN       4.0        7.0        NaN
# 2          $85,000          NaN       2.0        2.0        NaN
# 3         $450,000          NaN       8.0        6.0        0.0
# 4          $85,000          NaN       2.0        2.0        NaN
# ...            ...          ...       ...        ...        ...
# 6364    $1,440,000          NaN       NaN        NaN    80000.0
# 6365           POA          NaN      18.0       18.0        NaN
# 6366   $100,000/m²          NaN       NaN        NaN        NaN
# 6367      $147,000          NaN       NaN        NaN    22317.0
# 6368      $100,000          NaN       NaN        NaN      530.0
#
#                                           thumbnail_url  \
# 0     https://images.realestate.com.kh/__sized__/lis...
# 1     https://images.realestate.com.kh/__sized__/lis...
# 2     https://images.realestate.com.kh/__sized__/lis...
# 3     https://images.realestate.com.kh/__sized__/lis...
# 4     https://images.realestate.com.kh/__sized__/lis...
# ...                                                 ...
# 6364  https://images.realestate.com.kh/__sized__/lis...
# 6365  https://images.realestate.com.kh/__sized__/lis...
# 6366  https://images.realestate.com.kh/__sized__/lis...
# 6367  https://images.realestate.com.kh/__sized__/lis...
# 6368  https://images.realestate.com.kh/__sized__/lis...
#
#                                          thumbnail_urls  ...  \
# 0     ['https://images.realestate.com.kh/__sized__/l...  ...
# 1     ['https://images.realestate.com.kh/__sized__/l...  ...
# 2     ['https://images.realestate.com.kh/__sized__/l...  ...
# 3     ['https://images.realestate.com.kh/__sized__/l...  ...
# 4     ['https://images.realestate.com.kh/__sized__/l...  ...
# ...                                                 ...  ...
# 6364  ['https://images.realestate.com.kh/__sized__/l...  ...
# 6365  ['https://images.realestate.com.kh/__sized__/l...  ...
# 6366  ['https://images.realestate.com.kh/__sized__/l...  ...
# 6367  ['https://images.realestate.com.kh/__sized__/l...  ...
# 6368  ['https://images.realestate.com.kh/__sized__/l...  ...
#
#           address_line_2               address_line_1     category_name  \
# 0       Stueng Mean chey                                           Flat
# 1                Khmuonh                                     Twin Villa
# 2                  BKK 2                      117 117             House
# 3     Stueng Mean chey 3          1 ផ្លូវលូប្រាំ(82c)              Flat
# 4          Boeung Tumpun  ST. 45BT #4C, ST. 45BT #4C,              Flat
# ...                  ...                          ...               ...
# 6364            Kandoeng                                           Land
# 6365               Kraek                     72 St 72             House
# 6366     Trapeang Phlong                               Land/Development
# 6367        Roka Po Pram              72 Pel 72C Phum  Land/Development
# 6368               Memot             Memot 57 RGJ+MP,          Business
#
#      is_parent         type  \
# 0        False  residential
# 1        False  residential
# 2        False  residential
# 3        False  residential
# 4        False  residential
# ...        ...          ...
# 6364     False   commercial
# 6365     False  residential
# 6366     False  residential
# 6367     False  residential
# 6368     False   commercial
#
#                                             information  \
# 0     A flat (2 floors) near Hengly market and near ...
# 1     Twin Villa (Twin Villa) in Borey Highland 2005...
# 2     There are 3 floors 2 bedrooms, 2 bathrooms can...
# 3     I have a business house, I want to sell a hous...
# 4     Apartment Instast 4M * 15.5m There are 45M kit...
# ...                                                 ...
# 6364  Land in Phnom Tamao | Selling 60% below market...
# 6365  Selling negotiable emergency lodges, which are...
# 6366  Tucking Farm Sale | Durian Farm for Sale Locat...
# 6367  This Land area is located the middle of thaila...
# 6368  Lot near Memot market, big town, best for buil...
#
#                                  source_url  language   latitude   longitude
# 0     https://www.realestate.com.kh/204942/        en  11.530000  104.910000
# 1     https://www.realestate.com.kh/211997/        en  11.550000  104.890000
# 2     https://www.realestate.com.kh/212595/        km  11.554793  104.917136
# 3     https://www.realestate.com.kh/211987/        en  11.539648  104.886328
# 4     https://www.realestate.com.kh/212653/        km  11.550000  104.930000
# ...                                     ...       ...        ...         ...
# 6364  https://www.realestate.com.kh/246364/        en  11.297113  104.822738
# 6365  https://www.realestate.com.kh/217364/        km  11.761335  105.944320
# 6366  https://www.realestate.com.kh/231535/        km  11.709971  105.956464
# 6367  https://www.realestate.com.kh/246457/        en  12.042240  105.680894
# 6368  https://www.realestate.com.kh/231160/        en  11.824865  106.182672
#
# [6369 rows x 24 columns]

# %%
base_listing_url = "https://www.realestate.com.kh/"

# %%
# Create new columns if they don't already exist in df_all
if 'information' not in df_all.columns:
    df_all['information'] = None
if 'source_url' not in df_all.columns: # New column to store the URL of the scraped page
    df_all['source_url'] = None
if 'land_size' not in df_all.columns: # New column for land size
    df_all['land_size'] = None
if 'house_size' not in df_all.columns: # New column for house size
    df_all['house_size'] = None


# Helper function to extract land size from text
def extract_land_size(description_text):
    """
    Extracts land size from a given text description using regex.
    Looks for patterns like "Land size: 4m x 22.5m" or "Land area: 150 sqm".
    Returns the extracted string or None if not found.
    """
    if not description_text:
        return None

    # Pattern to capture dimensions (e.g., Xm x Ym) or single value with unit (e.g., X sqm)
    # The regex looks for keywords like "Land size", "Land area", "Land" followed by a colon or space,
    # then captures the actual size pattern.
    land_pattern = re.compile(
        r"(?:land\s*size|land\s*area|land)\s*[:\s]*"
        r"((?:\d+(?:\.\d+)?\s*m?\s*[xX]\s*\d+(?:\.\d+)?\s*m?)" # Dimensions like Xm x Ym
        r"|(?:\d+(?:\.\d+)?\s*(?:sqm|m2|m²|ha|hectare(?:s)?|sq\.\s*m|square\s*meter(?:s)?|square\s*metre(?:s)?)?))", # Single value with unit (optional unit if just a number)
        re.IGNORECASE
    )
    match = land_pattern.search(description_text)
    if match:
        return match.group(1).strip() # group(1) captures the actual size part
    return None

# Helper function to extract house size from text
def extract_house_size(description_text):
    """
    Extracts house/building size from a given text description using regex.
    Looks for patterns like "House size: 4m x 16m" or "Building size: 200 sqm".
    Returns the extracted string or None if not found.
    """
    if not description_text:
        return None

    # Pattern to capture dimensions or single value with unit for house/building size.
    # The regex looks for keywords like "House size", "House area", "Building size", "Building area", "House"
    # followed by a colon or space, then captures the actual size pattern.
    house_pattern = re.compile(
        r"(?:house\s*size|house\s*area|building\s*size|building\s*area|house)\s*[:\s]*"
        r"((?:\d+(?:\.\d+)?\s*m?\s*[xX]\s*\d+(?:\.\d+)?\s*m?)" # Dimensions like Xm x Ym
        r"|(?:\d+(?:\.\d+)?\s*(?:sqm|m2|m²|ha|hectare(?:s)?|sq\.\s*m|square\s*meter(?:s)?|square\s*metre(?:s)?)?))", # Single value with unit (optional unit if just a number)
        re.IGNORECASE
    )
    match = house_pattern.search(description_text)
    if match:
        return match.group(1).strip() # group(1) captures the actual size part
    return None


# Define the scraping function
def fetch_info(index, id_value):
    """
    Fetches detailed information, source URL, land size, and house size for a single property listing.

    Args:
        index (int): The index of the row in the DataFrame being processed.
        id_value (str/int): The unique ID of the property listing.

    Returns:
        tuple: (index, raw_text, temp_url, land_size, house_size) if successful, or
               (index, None, temp_url, None, None) if an error occurs or data not found.
    """
    temp_url = base_listing_url + str(id_value) + '/'
    raw_text = None
    land_size = None # Initialize land_size
    house_size = None # Initialize house_size
    try:
        response = requests.get(temp_url, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, "html.parser")
        span = soup.find("span", class_="css-zrj3zm")
        if span:
            raw_text = span.get_text(separator=" ", strip=True)
            land_size = extract_land_size(raw_text) # Extract land size
            house_size = extract_house_size(raw_text) # Extract house size
            print(f"[{index}] ✔ Success: {temp_url}")
            return index, raw_text, temp_url, land_size, house_size # Return both sizes
        else:
            print(f"[{index}] ✘ No span found: {temp_url}")
            return index, None, temp_url, None, None # Return None for both sizes
    except requests.exceptions.RequestException as e:
        print(f"[{index}] ⚠ HTTP Request Error for {temp_url}: {e}")
        return index, None, temp_url, None, None # Return None for both sizes on error
    except Exception as e:
        print(f"[{index}] ⚠ Unexpected Error for {temp_url}: {e}")
        return index, None, temp_url, None, None # Return None for both sizes on error

# Use ThreadPoolExecutor for parallel execution
with ThreadPoolExecutor(max_workers=25) as executor:
    futures = [
        executor.submit(fetch_info, i, df_all.iloc[i]['id']) for i in range(len(df_all))
    ]

    for future in as_completed(futures):
        index, result_text, result_url, extracted_land_size, extracted_house_size = future.result() # Unpack both sizes
        df_all.at[index, 'information'] = result_text
        df_all.at[index, 'source_url'] = result_url
        df_all.at[index, 'land_size'] = extracted_land_size # Assign land_size
        df_all.at[index, 'house_size'] = extracted_house_size # Assign house_size
# Out:
# [23] ✔ Success: https://www.realestate.com.kh/228347/
# [21] ✔ Success: https://www.realestate.com.kh/235048/
# [2] ✔ Success: https://www.realestate.com.kh/212595/
# [4] ✔ Success: https://www.realestate.com.kh/212653/
# [13] ✔ Success: https://www.realestate.com.kh/145091/
# [8] ✔ Success: https://www.realestate.com.kh/218736/
# [6] ✔ Success: https://www.realestate.com.kh/218884/
# [14] ✔ Success: https://www.realestate.com.kh/153997/
# [7] ✔ Success: https://www.realestate.com.kh/218563/
# [0] ✔ Success: https://www.realestate.com.kh/204942/
# [17] ✔ Success: https://www.realestate.com.kh/232920/
# [10] ✔ Success: https://www.realestate.com.kh/229653/
# [22] ✔ Success: https://www.realestate.com.kh/235065/
# [20] ✔ Success: https://www.realestate.com.kh/231183/
# [5] ✔ Success: https://www.realestate.com.kh/217976/
# [15] ✔ Success: https://www.realestate.com.kh/156169/
# [9] ✔ Success: https://www.realestate.com.kh/127135/
# [19] ✔ Success: https://www.realestate.com.kh/230541/
# [3] ✔ Success: https://www.realestate.com.kh/211987/
# [11] ✔ Success: https://www.realestate.com.kh/142378/
# [12] ✔ Success: https://www.realestate.com.kh/141245/
# [1] ✔ Success: https://www.realestate.com.kh/211997/
# [24] ✔ Success: https://www.realestate.com.kh/232502/
# [18] ✔ Success: https://www.realestate.com.kh/233750/
# [16] ✔ Success: https://www.realestate.com.kh/183911/
# [26] ✔ Success: https://www.realestate.com.kh/212923/
# [25] ✔ Success: https://www.realestate.com.kh/165365/
# [27] ✔ Success: https://www.realestate.com.kh/212922/
# [33] ✔ Success: https://www.realestate.com.kh/200584/
# [37] ✔ Success: https://www.realestate.com.kh/226992/
# [30] ✔ Success: https://www.realestate.com.kh/214685/
# [29] ✔ Success: https://www.realestate.com.kh/213353/
# [31] ✔ Success: https://www.realestate.com.kh/214912/
# [32] ✔ Success: https://www.realestate.com.kh/218436/
# [38] ✔ Success: https://www.realestate.com.kh/157841/
# [34] ✔ Success: https://www.realestate.com.kh/200464/
# [42] ✔ Success: https://www.realestate.com.kh/233665/
# [35] ✔ Success: https://www.realestate.com.kh/225961/
# [36] ✔ Success: https://www.realestate.com.kh/226481/
# [40] ✔ Success: https://www.realestate.com.kh/233086/
# [41] ✔ Success: https://www.realestate.com.kh/232278/
# [45] ✔ Success: https://www.realestate.com.kh/234738/
# [43] ✔ Success: https://www.realestate.com.kh/231205/
# [46] ✔ Success: https://www.realestate.com.kh/232394/
# [47] ✔ Success: https://www.realestate.com.kh/213024/
# [39] ✔ Success: https://www.realestate.com.kh/232361/
# [44] ✔ Success: https://www.realestate.com.kh/231195/
# [49] ✔ Success: https://www.realestate.com.kh/212002/
# [48] ✔ Success: https://www.realestate.com.kh/212330/
# [50] ✔ Success: https://www.realestate.com.kh/214058/
# [52] ✔ Success: https://www.realestate.com.kh/212633/
# [28] ✘ No span found: https://www.realestate.com.kh/212812/
# [51] ✔ Success: https://www.realestate.com.kh/213371/
# [54] ✔ Success: https://www.realestate.com.kh/158295/
# [53] ✔ Success: https://www.realestate.com.kh/211962/
# [58] ✔ Success: https://www.realestate.com.kh/185727/
# [56] ✔ Success: https://www.realestate.com.kh/195046/
# [55] ✔ Success: https://www.realestate.com.kh/127130/
# [59] ✔ Success: https://www.realestate.com.kh/185734/
# [62] ✔ Success: https://www.realestate.com.kh/233675/
# [65] ✔ Success: https://www.realestate.com.kh/234128/
# [68] ✔ Success: https://www.realestate.com.kh/148344/
# [63] ✔ Success: https://www.realestate.com.kh/231559/
# [60] ✔ Success: https://www.realestate.com.kh/232918/
# [64] ✔ Success: https://www.realestate.com.kh/231232/
# [57] ✔ Success: https://www.realestate.com.kh/186047/
# [67] ✔ Success: https://www.realestate.com.kh/203057/
# [66] ✔ Success: https://www.realestate.com.kh/231186/
# [61] ✔ Success: https://www.realestate.com.kh/233710/
# [72] ✔ Success: https://www.realestate.com.kh/212711/
# [70] ✔ Success: https://www.realestate.com.kh/212001/
# [69] ✔ Success: https://www.realestate.com.kh/150011/
# [73] ✔ Success: https://www.realestate.com.kh/214071/
# [71] ✔ Success: https://www.realestate.com.kh/212816/
# [74] ✔ Success: https://www.realestate.com.kh/181716/
# [78] ✔ Success: https://www.realestate.com.kh/201783/
# [79] ✔ Success: https://www.realestate.com.kh/185973/
# [75] ✔ Success: https://www.realestate.com.kh/157098/
# [76] ✔ Success: https://www.realestate.com.kh/218322/
# [77] ✔ Success: https://www.realestate.com.kh/218900/
# [81] ✔ Success: https://www.realestate.com.kh/235284/
# [80] ✔ Success: https://www.realestate.com.kh/231222/
# [82] ✔ Success: https://www.realestate.com.kh/230768/
# [87] ✔ Success: https://www.realestate.com.kh/218258/
# [86] ✔ Success: https://www.realestate.com.kh/212324/
# [83] ✔ Success: https://www.realestate.com.kh/232852/
# [85] ✔ Success: https://www.realestate.com.kh/213638/
# [88] ✔ Success: https://www.realestate.com.kh/216623/
# [92] ✔ Success: https://www.realestate.com.kh/184909/
# [84] ✔ Success: https://www.realestate.com.kh/212704/
# [90] ✔ Success: https://www.realestate.com.kh/227764/
# [89] ✔ Success: https://www.realestate.com.kh/198790/
# [93] ✔ Success: https://www.realestate.com.kh/232200/
# [91] ✔ Success: https://www.realestate.com.kh/227969/
# [97] ✔ Success: https://www.realestate.com.kh/235518/
# [94] ✔ Success: https://www.realestate.com.kh/233442/
# [96] ✔ Success: https://www.realestate.com.kh/235498/
# [95] ✔ Success: https://www.realestate.com.kh/233768/
# [98] ✔ Success: https://www.realestate.com.kh/234204/
# [99] ✔ Success: https://www.realestate.com.kh/231230/
# [103] ✔ Success: https://www.realestate.com.kh/212322/
# [102] ✔ Success: https://www.realestate.com.kh/231355/
# [101] ✔ Success: https://www.realestate.com.kh/234990/
# [100] ✔ Success: https://www.realestate.com.kh/231197/
# [104] ✔ Success: https://www.realestate.com.kh/213519/
# [106] ✔ Success: https://www.realestate.com.kh/171403/
# [109] ✔ Success: https://www.realestate.com.kh/201436/
# [110] ✔ Success: https://www.realestate.com.kh/201439/
# [105] ✔ Success: https://www.realestate.com.kh/214181/[108] ✔ Success: https://www.realestate.com.kh/218359/
#
# [107] ✔ Success: https://www.realestate.com.kh/181700/
# [111] ✔ Success: https://www.realestate.com.kh/200507/
# [113] ✔ Success: https://www.realestate.com.kh/223608/
# [112] ✔ Success: https://www.realestate.com.kh/229058/
# [117] ✔ Success: https://www.realestate.com.kh/235656/
# [114] ✔ Success: https://www.realestate.com.kh/186060/
# [116] ✔ Success: https://www.realestate.com.kh/235560/
# [115] ✔ Success: https://www.realestate.com.kh/233956/
# [118] ✔ Success: https://www.realestate.com.kh/235191/
# [122] ✔ Success: https://www.realestate.com.kh/211249/
# [120] ✔ Success: https://www.realestate.com.kh/212808/
# [121] ✔ Success: https://www.realestate.com.kh/212692/
# [119] ✔ Success: https://www.realestate.com.kh/212070/
# [123] ✔ Success: https://www.realestate.com.kh/218194/
# [124] ✔ Success: https://www.realestate.com.kh/216620/
# [125] ✔ Success: https://www.realestate.com.kh/218778/
# [128] ✔ Success: https://www.realestate.com.kh/214617/
# [126] ✔ Success: https://www.realestate.com.kh/218675/
# [127] ✔ Success: https://www.realestate.com.kh/212457/
# [130] ✔ Success: https://www.realestate.com.kh/184908/
# [129] ✔ Success: https://www.realestate.com.kh/95244/
# [131] ✔ Success: https://www.realestate.com.kh/229346/
# [132] ✔ Success: https://www.realestate.com.kh/185858/
# [133] ✔ Success: https://www.realestate.com.kh/185859/
# [134] ✔ Success: https://www.realestate.com.kh/185857/
# [136] ✔ Success: https://www.realestate.com.kh/231220/
# [138] ✔ Success: https://www.realestate.com.kh/204008/
# [135] ✔ Success: https://www.realestate.com.kh/231236/
# [139] ✔ Success: https://www.realestate.com.kh/149854/
# [142] ✔ Success: https://www.realestate.com.kh/214287/
# [137] ✔ Success: https://www.realestate.com.kh/231189/
# [140] ✔ Success: https://www.realestate.com.kh/149866/
# [141] ✔ Success: https://www.realestate.com.kh/214707/
# [143] ✔ Success: https://www.realestate.com.kh/212811/
# [148] ✔ Success: https://www.realestate.com.kh/197360/
# [145] ✔ Success: https://www.realestate.com.kh/217555/
# [144] ✔ Success: https://www.realestate.com.kh/178619/
# [146] ✔ Success: https://www.realestate.com.kh/218775/
# [147] ✔ Success: https://www.realestate.com.kh/218769/
# [150] ✔ Success: https://www.realestate.com.kh/225810/
# [152] ✔ Success: https://www.realestate.com.kh/233717/
# [151] ✔ Success: https://www.realestate.com.kh/232907/
# [149] ✔ Success: https://www.realestate.com.kh/197352/
# [154] ✔ Success: https://www.realestate.com.kh/230534/
# [153] ✔ Success: https://www.realestate.com.kh/233638/
# [156] ✔ Success: https://www.realestate.com.kh/235235/
# [155] ✔ Success: https://www.realestate.com.kh/235230/
# [157] ✔ Success: https://www.realestate.com.kh/148966/
# [159] ✔ Success: https://www.realestate.com.kh/212283/
# [158] ✔ Success: https://www.realestate.com.kh/213195/
# [164] ✔ Success: https://www.realestate.com.kh/218748/
# [166] ✔ Success: https://www.realestate.com.kh/200481/
# [162] ✔ Success: https://www.realestate.com.kh/219239/
# [163] ✔ Success: https://www.realestate.com.kh/218562/
# [165] ✔ Success: https://www.realestate.com.kh/201835/
# [167] ✔ Success: https://www.realestate.com.kh/199740/
# [161] ✔ Success: https://www.realestate.com.kh/181070/
# [160] ✔ Success: https://www.realestate.com.kh/214082/
# [169] ✔ Success: https://www.realestate.com.kh/229187/
# [168] ✔ Success: https://www.realestate.com.kh/199825/
# [173] ✔ Success: https://www.realestate.com.kh/229837/
# [172] ✔ Success: https://www.realestate.com.kh/185527/
# [175] ✔ Success: https://www.realestate.com.kh/233616/
# [170] ✔ Success: https://www.realestate.com.kh/141243/
# [171] ✔ Success: https://www.realestate.com.kh/145093/
# [174] ✔ Success: https://www.realestate.com.kh/232251/
# [176] ✔ Success: https://www.realestate.com.kh/231185/
# [177] ✔ Success: https://www.realestate.com.kh/232778/
# [179] ✔ Success: https://www.realestate.com.kh/207618/
# [178] ✔ Success: https://www.realestate.com.kh/207610/
# [183] ✔ Success: https://www.realestate.com.kh/222925/
# [182] ✔ Success: https://www.realestate.com.kh/152270/
# [181] ✔ Success: https://www.realestate.com.kh/203714/
# [180] ✔ Success: https://www.realestate.com.kh/207617/
# [190] ✔ Success: https://www.realestate.com.kh/235904/
# [186] ✔ Success: https://www.realestate.com.kh/211664/
# [188] ✔ Success: https://www.realestate.com.kh/208300/
# [187] ✔ Success: https://www.realestate.com.kh/208701/
# [189] ✔ Success: https://www.realestate.com.kh/235522/
# [185] ✔ Success: https://www.realestate.com.kh/209786/
# [184] ✔ Success: https://www.realestate.com.kh/210826/
# [192] ✔ Success: https://www.realestate.com.kh/235343/
# [194] ✔ Success: https://www.realestate.com.kh/216151/
# [191] ✔ Success: https://www.realestate.com.kh/235202/
# [193] ✔ Success: https://www.realestate.com.kh/235345/
# [195] ✔ Success: https://www.realestate.com.kh/216159/
# [200] ✔ Success: https://www.realestate.com.kh/223500/
# [201] ✔ Success: https://www.realestate.com.kh/221815/
# [198] ✔ Success: https://www.realestate.com.kh/209706/
# [196] ✔ Success: https://www.realestate.com.kh/207267/
# [197] ✔ Success: https://www.realestate.com.kh/208133/
# [199] ✔ Success: https://www.realestate.com.kh/209734/
# [203] ✔ Success: https://www.realestate.com.kh/224218/
# [205] ✔ Success: https://www.realestate.com.kh/220220/
# [202] ✔ Success: https://www.realestate.com.kh/221816/
# [206] ✔ Success: https://www.realestate.com.kh/220276/
# [204] ✔ Success: https://www.realestate.com.kh/224195/[208] ✔ Success: https://www.realestate.com.kh/201874/
#
# [211] ✔ Success: https://www.realestate.com.kh/150317/
# [207] ✔ Success: https://www.realestate.com.kh/200261/
# [213] ✔ Success: https://www.realestate.com.kh/235420/
# [210] ✔ Success: https://www.realestate.com.kh/201663/
# [209] ✔ Success: https://www.realestate.com.kh/127134/
# [212] ✔ Success: https://www.realestate.com.kh/208534/
# [214] ✔ Success: https://www.realestate.com.kh/214070/
# [215] ✔ Success: https://www.realestate.com.kh/217099/
# [216] ✔ Success: https://www.realestate.com.kh/217507/
# [217] ✔ Success: https://www.realestate.com.kh/217506/
# [219] ✔ Success: https://www.realestate.com.kh/195153/
# [218] ✔ Success: https://www.realestate.com.kh/194175/
# [222] ✔ Success: https://www.realestate.com.kh/207158/
# [221] ✔ Success: https://www.realestate.com.kh/127136/
# [226] ✔ Success: https://www.realestate.com.kh/223781/
# [224] ✔ Success: https://www.realestate.com.kh/221119/
# [225] ✔ Success: https://www.realestate.com.kh/224155/
# [220] ✔ Success: https://www.realestate.com.kh/142204/
# [223] ✔ Success: https://www.realestate.com.kh/207141/
# [229] ✔ Success: https://www.realestate.com.kh/220287/
# [230] ✔ Success: https://www.realestate.com.kh/223986/
# [228] ✔ Success: https://www.realestate.com.kh/220289/
# [227] ✔ Success: https://www.realestate.com.kh/224156/
# [232] ✔ Success: https://www.realestate.com.kh/200519/
# [238] ✔ Success: https://www.realestate.com.kh/235022/
# [239] ✔ Success: https://www.realestate.com.kh/235654/
# [240] ✔ Success: https://www.realestate.com.kh/234719/
# [231] ✔ Success: https://www.realestate.com.kh/199742/
# [234] ✔ Success: https://www.realestate.com.kh/200034/
# [233] ✔ Success: https://www.realestate.com.kh/201944/
# [236] ✔ Success: https://www.realestate.com.kh/235761/
# [235] ✔ Success: https://www.realestate.com.kh/208106/
# [237] ✔ Success: https://www.realestate.com.kh/235937/
# [241] ✔ Success: https://www.realestate.com.kh/235502/
# [242] ✔ Success: https://www.realestate.com.kh/233082/
# [244] ✔ Success: https://www.realestate.com.kh/234724/
# [243] ✔ Success: https://www.realestate.com.kh/235631/
# [246] ✔ Success: https://www.realestate.com.kh/236195/
# [249] ✔ Success: https://www.realestate.com.kh/235896/
# [245] ✔ Success: https://www.realestate.com.kh/235555/
# [251] ✔ Success: https://www.realestate.com.kh/234299/
# [250] ✔ Success: https://www.realestate.com.kh/235273/
# [248] ✔ Success: https://www.realestate.com.kh/235894/
# [247] ✔ Success: https://www.realestate.com.kh/235652/
# [253] ✔ Success: https://www.realestate.com.kh/215235/
# [252] ✔ Success: https://www.realestate.com.kh/163525/
# [254] ✔ Success: https://www.realestate.com.kh/214785/
# [255] ✔ Success: https://www.realestate.com.kh/207061/
# [256] ✔ Success: https://www.realestate.com.kh/207033/
# [257] ✔ Success: https://www.realestate.com.kh/207036/
# [258] ✔ Success: https://www.realestate.com.kh/207085/
# [262] ✔ Success: https://www.realestate.com.kh/209519/
# [260] ✔ Success: https://www.realestate.com.kh/207915/
# [259] ✔ Success: https://www.realestate.com.kh/207094/
# [261] ✔ Success: https://www.realestate.com.kh/208724/
# [263] ✔ Success: https://www.realestate.com.kh/222653/
# [266] ✔ Success: https://www.realestate.com.kh/223444/
# [267] ✔ Success: https://www.realestate.com.kh/209746/
# [264] ✔ Success: https://www.realestate.com.kh/224152/
# [269] ✔ Success: https://www.realestate.com.kh/208731/
# [268] ✔ Success: https://www.realestate.com.kh/210735/
# [265] ✔ Success: https://www.realestate.com.kh/223209/
# [270] ✔ Success: https://www.realestate.com.kh/210167/
# [271] ✔ Success: https://www.realestate.com.kh/235421/
# [272] ✔ Success: https://www.realestate.com.kh/235950/
# [276] ✔ Success: https://www.realestate.com.kh/207009/
# [275] ✔ Success: https://www.realestate.com.kh/207016/
# [274] ✔ Success: https://www.realestate.com.kh/190214/
# [273] ✔ Success: https://www.realestate.com.kh/73333/
# [277] ✔ Success: https://www.realestate.com.kh/207010/
# [278] ✔ Success: https://www.realestate.com.kh/207891/
# [279] ✔ Success: https://www.realestate.com.kh/207900/
# [280] ✔ Success: https://www.realestate.com.kh/207910/
# [281] ✔ Success: https://www.realestate.com.kh/210087/
# [284] ✔ Success: https://www.realestate.com.kh/223699/
# [285] ✔ Success: https://www.realestate.com.kh/220756/
# [283] ✔ Success: https://www.realestate.com.kh/223724/
# [287] ✔ Success: https://www.realestate.com.kh/201715/
# [282] ✔ Success: https://www.realestate.com.kh/219247/
# [286] ✔ Success: https://www.realestate.com.kh/199788/
# [296] ✔ Success: https://www.realestate.com.kh/207775/
# [295] ✔ Success: https://www.realestate.com.kh/208361/
# [292] ✔ Success: https://www.realestate.com.kh/208621/
# [289] ✔ Success: https://www.realestate.com.kh/209707/[290] ✔ Success: https://www.realestate.com.kh/210234/
#
# [288] ✔ Success: https://www.realestate.com.kh/152262/
# [293] ✔ Success: https://www.realestate.com.kh/210324/
# [294] ✔ Success: https://www.realestate.com.kh/208053/
# [291] ✔ Success: https://www.realestate.com.kh/207754/
# [299] ✔ Success: https://www.realestate.com.kh/207897/
# [297] ✔ Success: https://www.realestate.com.kh/211030/
# [298] ✔ Success: https://www.realestate.com.kh/208730/
# [304] ✔ Success: https://www.realestate.com.kh/214067/
# [300] ✔ Success: https://www.realestate.com.kh/235645/
# [302] ✔ Success: https://www.realestate.com.kh/217965/
# [301] ✔ Success: https://www.realestate.com.kh/170964/
# [306] ✔ Success: https://www.realestate.com.kh/213414/
# [303] ✔ Success: https://www.realestate.com.kh/214080/
# [305] ✔ Success: https://www.realestate.com.kh/213022/
# [311] ✔ Success: https://www.realestate.com.kh/207328/
# [309] ✔ Success: https://www.realestate.com.kh/206941/
# [310] ✔ Success: https://www.realestate.com.kh/207324/
# [308] ✔ Success: https://www.realestate.com.kh/206958/
# [307] ✔ Success: https://www.realestate.com.kh/163235/
# [312] ✔ Success: https://www.realestate.com.kh/220212/
# [313] ✔ Success: https://www.realestate.com.kh/220210/
# [314] ✔ Success: https://www.realestate.com.kh/220211/
# [317] ✔ Success: https://www.realestate.com.kh/223362/
# [316] ✔ Success: https://www.realestate.com.kh/223815/
# [315] ✔ Success: https://www.realestate.com.kh/224085/
# [320] ✔ Success: https://www.realestate.com.kh/223775/
# [319] ✔ Success: https://www.realestate.com.kh/223774/
# [318] ✔ Success: https://www.realestate.com.kh/223783/
# [321] ✔ Success: https://www.realestate.com.kh/223752/
# [324] ✔ Success: https://www.realestate.com.kh/223751/
# [323] ✔ Success: https://www.realestate.com.kh/220661/
# [322] ✔ Success: https://www.realestate.com.kh/221467/
# [325] ✔ Success: https://www.realestate.com.kh/200134/
# [328] ✔ Success: https://www.realestate.com.kh/201947/
# [330] ✔ Success: https://www.realestate.com.kh/208630/
# [329] ✔ Success: https://www.realestate.com.kh/151859/
# [326] ✔ Success: https://www.realestate.com.kh/199799/
# [327] ✔ Success: https://www.realestate.com.kh/201180/
# [331] ✔ Success: https://www.realestate.com.kh/208363/
# [334] ✔ Success: https://www.realestate.com.kh/207785/
# [333] ✔ Success: https://www.realestate.com.kh/208351/
# [335] ✔ Success: https://www.realestate.com.kh/211088/
# [332] ✔ Success: https://www.realestate.com.kh/210919/
# [336] ✔ Success: https://www.realestate.com.kh/234327/
# [338] ✔ Success: https://www.realestate.com.kh/148079/
# [337] ✔ Success: https://www.realestate.com.kh/235347/
# [339] ✔ Success: https://www.realestate.com.kh/168427/
# [343] ✔ Success: https://www.realestate.com.kh/217970/
# [344] ✔ Success: https://www.realestate.com.kh/217115/
# [342] ✔ Success: https://www.realestate.com.kh/216161/
# [345] ✔ Success: https://www.realestate.com.kh/213409/
# [341] ✔ Success: https://www.realestate.com.kh/217494/
# [340] ✔ Success: https://www.realestate.com.kh/171017/
# [349] ✔ Success: https://www.realestate.com.kh/224178/
# [346] ✔ Success: https://www.realestate.com.kh/214705/
# [347] ✔ Success: https://www.realestate.com.kh/216028/
# [350] ✔ Success: https://www.realestate.com.kh/221701/
# [348] ✔ Success: https://www.realestate.com.kh/209873/
# [351] ✔ Success: https://www.realestate.com.kh/199822/
# [352] ✔ Success: https://www.realestate.com.kh/150293/
# [353] ✔ Success: https://www.realestate.com.kh/208042/
# [355] ✔ Success: https://www.realestate.com.kh/235368/
# [354] ✔ Success: https://www.realestate.com.kh/207683/
# [356] ✔ Success: https://www.realestate.com.kh/235637/
# [358] ✔ Success: https://www.realestate.com.kh/215153/
# [357] ✔ Success: https://www.realestate.com.kh/216035/
# [359] ✔ Success: https://www.realestate.com.kh/213905/
# [360] ✔ Success: https://www.realestate.com.kh/213823/
# [363] ✔ Success: https://www.realestate.com.kh/217752/
# [361] ✔ Success: https://www.realestate.com.kh/215538/
# [362] ✔ Success: https://www.realestate.com.kh/215696/
# [364] ✔ Success: https://www.realestate.com.kh/217751/
# [365] ✔ Success: https://www.realestate.com.kh/215546/
# [367] ✔ Success: https://www.realestate.com.kh/215441/
# [368] ✔ Success: https://www.realestate.com.kh/215547/
# [369] ✔ Success: https://www.realestate.com.kh/216072/
# [375] ✔ Success: https://www.realestate.com.kh/217550/
# [374] ✔ Success: https://www.realestate.com.kh/216995/
# [370] ✔ Success: https://www.realestate.com.kh/215483/
# [366] ✔ Success: https://www.realestate.com.kh/213102/
# [376] ✔ Success: https://www.realestate.com.kh/163233/
# [371] ✔ Success: https://www.realestate.com.kh/217637/
# [372] ✔ Success: https://www.realestate.com.kh/217907/
# [377] ✔ Success: https://www.realestate.com.kh/207183/
# [373] ✔ Success: https://www.realestate.com.kh/214416/
# [378] ✔ Success: https://www.realestate.com.kh/207177/
# [380] ✔ Success: https://www.realestate.com.kh/208641/
# [383] ✔ Success: https://www.realestate.com.kh/209742/
# [379] ✔ Success: https://www.realestate.com.kh/208638/
# [382] ✔ Success: https://www.realestate.com.kh/209739/
# [384] ✔ Success: https://www.realestate.com.kh/209744/
# [381] ✔ Success: https://www.realestate.com.kh/209784/
# [385] ✔ Success: https://www.realestate.com.kh/209758/
# [387] ✔ Success: https://www.realestate.com.kh/224210/
# [388] ✔ Success: https://www.realestate.com.kh/220215/
# [386] ✔ Success: https://www.realestate.com.kh/223492/
# [393] ✔ Success: https://www.realestate.com.kh/235093/
# [390] ✔ Success: https://www.realestate.com.kh/201952/
# [389] ✔ Success: https://www.realestate.com.kh/224055/
# [391] ✔ Success: https://www.realestate.com.kh/209752/
# [392] ✔ Success: https://www.realestate.com.kh/210732/
# [395] ✔ Success: https://www.realestate.com.kh/235073/
# [396] ✔ Success: https://www.realestate.com.kh/168638/
# [398] ✔ Success: https://www.realestate.com.kh/197395/
# [397] ✔ Success: https://www.realestate.com.kh/216630/
# [401] ✔ Success: https://www.realestate.com.kh/235988/
# [402] ✔ Success: https://www.realestate.com.kh/158296/
# [394] ✔ Success: https://www.realestate.com.kh/235092/
# [400] ✔ Success: https://www.realestate.com.kh/209750/
# [403] ✔ Success: https://www.realestate.com.kh/158299/
# [404] ✔ Success: https://www.realestate.com.kh/213511/
# [399] ✔ Success: https://www.realestate.com.kh/152691/
# [405] ✔ Success: https://www.realestate.com.kh/224984/
# [409] ✔ Success: https://www.realestate.com.kh/148130/
# [410] ✔ Success: https://www.realestate.com.kh/227750/
# [407] ✔ Success: https://www.realestate.com.kh/211993/
# [406] ✔ Success: https://www.realestate.com.kh/188144/
# [408] ✔ Success: https://www.realestate.com.kh/191449/
# [412] ✔ Success: https://www.realestate.com.kh/211915/[413] ✔ Success: https://www.realestate.com.kh/234387/
#
# [411] ✔ Success: https://www.realestate.com.kh/231417/
# [417] ✔ Success: https://www.realestate.com.kh/227743/
# [415] ✔ Success: https://www.realestate.com.kh/142374/
# [416] ✔ Success: https://www.realestate.com.kh/227038/
# [414] ✔ Success: https://www.realestate.com.kh/142364/
# [419] ✔ Success: https://www.realestate.com.kh/234082/
# [420] ✔ Success: https://www.realestate.com.kh/230128/
# [423] ✔ Success: https://www.realestate.com.kh/145784/
# [424] ✔ Success: https://www.realestate.com.kh/150446/
# [422] ✔ Success: https://www.realestate.com.kh/148115/
# [418] ✔ Success: https://www.realestate.com.kh/230379/
# [421] ✔ Success: https://www.realestate.com.kh/142375/
# [426] ✔ Success: https://www.realestate.com.kh/184968/
# [425] ✔ Success: https://www.realestate.com.kh/146883/
# [427] ✔ Success: https://www.realestate.com.kh/226480/
# [433] ✔ Success: https://www.realestate.com.kh/229620/
# [435] ✔ Success: https://www.realestate.com.kh/157856/
# [431] ✔ Success: https://www.realestate.com.kh/229989/
# [430] ✔ Success: https://www.realestate.com.kh/231468/
# [428] ✔ Success: https://www.realestate.com.kh/227040/
# [432] ✔ Success: https://www.realestate.com.kh/230020/
# [434] ✔ Success: https://www.realestate.com.kh/232148/
# [429] ✔ Success: https://www.realestate.com.kh/142199/
# [437] ✔ Success: https://www.realestate.com.kh/204651/
# [436] ✔ Success: https://www.realestate.com.kh/203793/
# [438] ✔ Success: https://www.realestate.com.kh/203009/
# [439] ✔ Success: https://www.realestate.com.kh/202901/
# [440] ✔ Success: https://www.realestate.com.kh/204957/
# [441] ✔ Success: https://www.realestate.com.kh/204397/
# [443] ✔ Success: https://www.realestate.com.kh/218870/
# [442] ✔ Success: https://www.realestate.com.kh/204914/
# [444] ✔ Success: https://www.realestate.com.kh/219790/
# [446] ✔ Success: https://www.realestate.com.kh/221215/
# [445] ✔ Success: https://www.realestate.com.kh/219672/
# [448] ✔ Success: https://www.realestate.com.kh/224450/
# [447] ✔ Success: https://www.realestate.com.kh/224386/
# [449] ✔ Success: https://www.realestate.com.kh/228345/
# [450] ✔ Success: https://www.realestate.com.kh/224466/
# [451] ✔ Success: https://www.realestate.com.kh/228255/
# [453] ✔ Success: https://www.realestate.com.kh/224837/
# [452] ✔ Success: https://www.realestate.com.kh/224838/
# [459] ✔ Success: https://www.realestate.com.kh/230223/
# [455] ✔ Success: https://www.realestate.com.kh/224800/
# [458] ✔ Success: https://www.realestate.com.kh/207423/
# [460] ✔ Success: https://www.realestate.com.kh/143666/
# [454] ✔ Success: https://www.realestate.com.kh/224527/
# [456] ✔ Success: https://www.realestate.com.kh/228551/
# [461] ✔ Success: https://www.realestate.com.kh/145781/
# [457] ✔ Success: https://www.realestate.com.kh/199456/
# [462] ✔ Success: https://www.realestate.com.kh/231403/
# [463] ✔ Success: https://www.realestate.com.kh/229963/
# [464] ✔ Success: https://www.realestate.com.kh/229744/
# [466] ✔ Success: https://www.realestate.com.kh/231460/
# [467] ✔ Success: https://www.realestate.com.kh/229683/
# [465] ✔ Success: https://www.realestate.com.kh/231461/
# [468] ✔ Success: https://www.realestate.com.kh/229666/
# [469] ✔ Success: https://www.realestate.com.kh/229980/
# [471] ✔ Success: https://www.realestate.com.kh/229818/
# [472] ✔ Success: https://www.realestate.com.kh/229780/
# [470] ✔ Success: https://www.realestate.com.kh/230149/
# [478] ✔ Success: https://www.realestate.com.kh/219767/
# [474] ✔ Success: https://www.realestate.com.kh/232285/
# [475] ✔ Success: https://www.realestate.com.kh/232726/
# [473] ✔ Success: https://www.realestate.com.kh/232462/
# [481] ✔ Success: https://www.realestate.com.kh/223801/
# [476] ✔ Success: https://www.realestate.com.kh/233476/
# [480] ✔ Success: https://www.realestate.com.kh/228485/
# [477] ✔ Success: https://www.realestate.com.kh/157846/
# [479] ✔ Success: https://www.realestate.com.kh/220767/
# [483] ✔ Success: https://www.realestate.com.kh/207031/
# [487] ✔ Success: https://www.realestate.com.kh/231453/
# [482] ✔ Success: https://www.realestate.com.kh/226624/
# [486] ✔ Success: https://www.realestate.com.kh/178624/
# [485] ✔ Success: https://www.realestate.com.kh/145782/
# [484] ✔ Success: https://www.realestate.com.kh/189835/
# [488] ✔ Success: https://www.realestate.com.kh/232948/
# [491] ✔ Success: https://www.realestate.com.kh/229692/
# [490] ✔ Success: https://www.realestate.com.kh/231578/
# [492] ✔ Success: https://www.realestate.com.kh/232970/
# [489] ✔ Success: https://www.realestate.com.kh/230990/
# [496] ✔ Success: https://www.realestate.com.kh/230600/
# [495] ✔ Success: https://www.realestate.com.kh/229853/
# [494] ✔ Success: https://www.realestate.com.kh/229976/
# [500] ✔ Success: https://www.realestate.com.kh/233157/
# [497] ✔ Success: https://www.realestate.com.kh/230593/
# [498] ✔ Success: https://www.realestate.com.kh/231377/
# [499] ✔ Success: https://www.realestate.com.kh/229929/
# [493] ✔ Success: https://www.realestate.com.kh/229917/
# [501] ✔ Success: https://www.realestate.com.kh/232191/
# [505] ✔ Success: https://www.realestate.com.kh/219656/
# [507] ✔ Success: https://www.realestate.com.kh/224373/
# [502] ✔ Success: https://www.realestate.com.kh/231385/
# [508] ✔ Success: https://www.realestate.com.kh/228474/
# [506] ✔ Success: https://www.realestate.com.kh/219459/
# [504] ✔ Success: https://www.realestate.com.kh/220634/
# [503] ✔ Success: https://www.realestate.com.kh/230132/
# [512] ✔ Success: https://www.realestate.com.kh/224850/
# [509] ✔ Success: https://www.realestate.com.kh/224413/
# [510] ✔ Success: https://www.realestate.com.kh/224455/
# [513] ✔ Success: https://www.realestate.com.kh/224833/
# [511] ✔ Success: https://www.realestate.com.kh/228323/
# [515] ✔ Success: https://www.realestate.com.kh/143405/
# [517] ✔ Success: https://www.realestate.com.kh/162489/
# [518] ✔ Success: https://www.realestate.com.kh/181707/
# [514] ✔ Success: https://www.realestate.com.kh/156343/
# [516] ✔ Success: https://www.realestate.com.kh/182945/
# [519] ✔ Success: https://www.realestate.com.kh/181709/
# [523] ✔ Success: https://www.realestate.com.kh/230220/
# [521] ✔ Success: https://www.realestate.com.kh/230952/
# [526] ✔ Success: https://www.realestate.com.kh/231443/
# [522] ✔ Success: https://www.realestate.com.kh/231416/
# [524] ✔ Success: https://www.realestate.com.kh/231138/
# [525] ✔ Success: https://www.realestate.com.kh/231136/
# [520] ✔ Success: https://www.realestate.com.kh/181595/
# [531] ✔ Success: https://www.realestate.com.kh/229836/
# [532] ✔ Success: https://www.realestate.com.kh/232288/
# [527] ✔ Success: https://www.realestate.com.kh/232607/
# [529] ✔ Success: https://www.realestate.com.kh/229686/
# [534] ✔ Success: https://www.realestate.com.kh/155457/
# [528] ✔ Success: https://www.realestate.com.kh/229825/
# [536] ✔ Success: https://www.realestate.com.kh/219937/
# [530] ✔ Success: https://www.realestate.com.kh/231634/
# [537] ✔ Success: https://www.realestate.com.kh/223339/
# [535] ✔ Success: https://www.realestate.com.kh/223146/
# [533] ✔ Success: https://www.realestate.com.kh/231371/
# [538] ✔ Success: https://www.realestate.com.kh/219675/
# [539] ✔ Success: https://www.realestate.com.kh/221810/
# [541] ✔ Success: https://www.realestate.com.kh/224456/
# [542] ✔ Success: https://www.realestate.com.kh/224471/
# [550] ✔ Success: https://www.realestate.com.kh/198139/
# [540] ✔ Success: https://www.realestate.com.kh/227938/
# [544] ✔ Success: https://www.realestate.com.kh/224516/
# [551] ✔ Success: https://www.realestate.com.kh/219270/
# [547] ✔ Success: https://www.realestate.com.kh/224729/
# [545] ✔ Success: https://www.realestate.com.kh/224534/
# [543] ✔ Success: https://www.realestate.com.kh/224842/
# [548] ✔ Success: https://www.realestate.com.kh/224713/
# [546] ✔ Success: https://www.realestate.com.kh/224788/
# [549] ✔ Success: https://www.realestate.com.kh/198159/
# [552] ✔ Success: https://www.realestate.com.kh/232656/
# [554] ✔ Success: https://www.realestate.com.kh/232421/
# [558] ✔ Success: https://www.realestate.com.kh/231563/
# [560] ✔ Success: https://www.realestate.com.kh/229834/
# [553] ✔ Success: https://www.realestate.com.kh/231526/
# [561] ✔ Success: https://www.realestate.com.kh/229687/
# [557] ✔ Success: https://www.realestate.com.kh/233324/
# [559] ✔ Success: https://www.realestate.com.kh/229905/
# [555] ✔ Success: https://www.realestate.com.kh/178564/
# [562] ✔ Success: https://www.realestate.com.kh/188311/
# [556] ✔ Success: https://www.realestate.com.kh/160280/
# [563] ✔ Success: https://www.realestate.com.kh/221595/
# [564] ✔ Success: https://www.realestate.com.kh/219944/
# [565] ✔ Success: https://www.realestate.com.kh/219927/
# [570] ✔ Success: https://www.realestate.com.kh/224479/[569] ✔ Success: https://www.realestate.com.kh/224412/
#
# [566] ✔ Success: https://www.realestate.com.kh/219461/
# [568] ✔ Success: https://www.realestate.com.kh/228483/
# [567] ✔ Success: https://www.realestate.com.kh/227967/
# [571] ✔ Success: https://www.realestate.com.kh/224519/
# [575] ✔ Success: https://www.realestate.com.kh/224626/
# [572] ✔ Success: https://www.realestate.com.kh/224544/
# [574] ✔ Success: https://www.realestate.com.kh/224725/
# [573] ✔ Success: https://www.realestate.com.kh/224590/
# [576] ✔ Success: https://www.realestate.com.kh/153278/
# [577] ✔ Success: https://www.realestate.com.kh/140569/
# [580] ✔ Success: https://www.realestate.com.kh/230095/
# [581] ✔ Success: https://www.realestate.com.kh/155908/
# [579] ✔ Success: https://www.realestate.com.kh/231606/
# [583] ✔ Success: https://www.realestate.com.kh/204337/
# [578] ✔ Success: https://www.realestate.com.kh/230023/
# [582] ✔ Success: https://www.realestate.com.kh/155907/
# [584] ✔ Success: https://www.realestate.com.kh/203966/
# [586] ✔ Success: https://www.realestate.com.kh/222689/
# [587] ✔ Success: https://www.realestate.com.kh/220768/
# [588] ✔ Success: https://www.realestate.com.kh/219349/
# [585] ✔ Success: https://www.realestate.com.kh/203784/
# [595] ✔ Success: https://www.realestate.com.kh/224495/
# [590] ✔ Success: https://www.realestate.com.kh/226472/
# [599] ✔ Success: https://www.realestate.com.kh/224812/
# [591] ✔ Success: https://www.realestate.com.kh/228477/
# [597] ✔ Success: https://www.realestate.com.kh/224498/
# [589] ✔ Success: https://www.realestate.com.kh/226207/
# [596] ✔ Success: https://www.realestate.com.kh/224860/
# [594] ✔ Success: https://www.realestate.com.kh/224484/
# [593] ✔ Success: https://www.realestate.com.kh/224395/
# [592] ✔ Success: https://www.realestate.com.kh/210166/
# [600] ✔ Success: https://www.realestate.com.kh/224806/
# [598] ✔ Success: https://www.realestate.com.kh/226905/
# [601] ✔ Success: https://www.realestate.com.kh/224565/
# [602] ✔ Success: https://www.realestate.com.kh/224745/
# [604] ✔ Success: https://www.realestate.com.kh/224744/
# [603] ✔ Success: https://www.realestate.com.kh/224739/
# [608] ✔ Success: https://www.realestate.com.kh/229875/
# [606] ✔ Success: https://www.realestate.com.kh/141866/
# [605] ✔ Success: https://www.realestate.com.kh/145173/
# [607] ✔ Success: https://www.realestate.com.kh/231452/
# [612] ✔ Success: https://www.realestate.com.kh/232459/
# [613] ✔ Success: https://www.realestate.com.kh/230106/
# [609] ✔ Success: https://www.realestate.com.kh/229759/
# [611] ✔ Success: https://www.realestate.com.kh/231361/
# [610] ✔ Success: https://www.realestate.com.kh/229858/
# [620] ✔ Success: https://www.realestate.com.kh/224409/
# [617] ✔ Success: https://www.realestate.com.kh/219463/
# [621] ✔ Success: https://www.realestate.com.kh/224420/
# [615] ✔ Success: https://www.realestate.com.kh/160146/
# [614] ✔ Success: https://www.realestate.com.kh/233536/
# [618] ✔ Success: https://www.realestate.com.kh/224370/
# [623] ✔ Success: https://www.realestate.com.kh/224475/
# [624] ✔ Success: https://www.realestate.com.kh/224530/
# [625] ✔ Success: https://www.realestate.com.kh/224786/
# [616] ✔ Success: https://www.realestate.com.kh/223147/
# [619] ✔ Success: https://www.realestate.com.kh/224407/
# [622] ✔ Success: https://www.realestate.com.kh/224458/
# [626] ✔ Success: https://www.realestate.com.kh/223542/
# [627] ✔ Success: https://www.realestate.com.kh/228120/
# [630] ✔ Success: https://www.realestate.com.kh/219857/
# [628] ✔ Success: https://www.realestate.com.kh/207318/
# [629] ✔ Success: https://www.realestate.com.kh/232289/
# [632] ✔ Success: https://www.realestate.com.kh/223165/
# [631] ✔ Success: https://www.realestate.com.kh/219277/
# [633] ✔ Success: https://www.realestate.com.kh/230332/
# [638] ✔ Success: https://www.realestate.com.kh/234421/
# [635] ✔ Success: https://www.realestate.com.kh/200362/
# [637] ✔ Success: https://www.realestate.com.kh/230793/
# [636] ✔ Success: https://www.realestate.com.kh/186977/
# [634] ✔ Success: https://www.realestate.com.kh/142504/
# [640] ✔ Success: https://www.realestate.com.kh/212281/
# [639] ✔ Success: https://www.realestate.com.kh/230124/
# [641] ✔ Success: https://www.realestate.com.kh/218906/
# [642] ✔ Success: https://www.realestate.com.kh/222668/
# [647] ✔ Success: https://www.realestate.com.kh/199865/
# [646] ✔ Success: https://www.realestate.com.kh/200069/
# [643] ✔ Success: https://www.realestate.com.kh/218674/
# [648] ✔ Success: https://www.realestate.com.kh/147934/
# [644] ✔ Success: https://www.realestate.com.kh/146234/
# [649] ✔ Success: https://www.realestate.com.kh/230122/
# [645] ✔ Success: https://www.realestate.com.kh/231080/
# [650] ✔ Success: https://www.realestate.com.kh/148864/
# [652] ✔ Success: https://www.realestate.com.kh/218672/
# [651] ✔ Success: https://www.realestate.com.kh/230146/
# [656] ✔ Success: https://www.realestate.com.kh/190229/
# [653] ✔ Success: https://www.realestate.com.kh/152486/
# [655] ✔ Success: https://www.realestate.com.kh/228148/
# [654] ✔ Success: https://www.realestate.com.kh/230574/
# [657] ✔ Success: https://www.realestate.com.kh/231087/
# [658] ✔ Success: https://www.realestate.com.kh/203812/
# [659] ✔ Success: https://www.realestate.com.kh/224790/
# [660] ✔ Success: https://www.realestate.com.kh/203062/
# [664] ✔ Success: https://www.realestate.com.kh/224736/
# [661] ✔ Success: https://www.realestate.com.kh/218198/
# [665] ✔ Success: https://www.realestate.com.kh/221212/
# [667] ✔ Success: https://www.realestate.com.kh/228384/
# [666] ✔ Success: https://www.realestate.com.kh/190222/
# [662] ✔ Success: https://www.realestate.com.kh/228549/
# [663] ✔ Success: https://www.realestate.com.kh/224548/
# [669] ✔ Success: https://www.realestate.com.kh/224388/
# [675] ✔ Success: https://www.realestate.com.kh/231550/
# [668] ✔ Success: https://www.realestate.com.kh/227976/
# [673] ✔ Success: https://www.realestate.com.kh/231386/
# [670] ✔ Success: https://www.realestate.com.kh/158848/
# [672] ✔ Success: https://www.realestate.com.kh/220437/
# [671] ✔ Success: https://www.realestate.com.kh/182953/
# [674] ✔ Success: https://www.realestate.com.kh/231388/
# [676] ✔ Success: https://www.realestate.com.kh/229930/
# [680] ✔ Success: https://www.realestate.com.kh/188617/
# [678] ✔ Success: https://www.realestate.com.kh/228544/
# [682] ✔ Success: https://www.realestate.com.kh/207779/
# [677] ✔ Success: https://www.realestate.com.kh/224820/
# [683] ✔ Success: https://www.realestate.com.kh/157918/
# [681] ✔ Success: https://www.realestate.com.kh/207764/
# [679] ✔ Success: https://www.realestate.com.kh/186910/
# [684] ✔ Success: https://www.realestate.com.kh/215482/
# [686] ✔ Success: https://www.realestate.com.kh/208704/
# [685] ✔ Success: https://www.realestate.com.kh/206544/
# [687] ✔ Success: https://www.realestate.com.kh/123429/
# [689] ✔ Success: https://www.realestate.com.kh/234383/
# [691] ✔ Success: https://www.realestate.com.kh/219254/
# [688] ✔ Success: https://www.realestate.com.kh/234539/
# [692] ✔ Success: https://www.realestate.com.kh/193716/
# [694] ✔ Success: https://www.realestate.com.kh/212986/
# [701] ✔ Success: https://www.realestate.com.kh/235565/
# [690] ✔ Success: https://www.realestate.com.kh/219512/
# [699] ✔ Success: https://www.realestate.com.kh/188300/
# [697] ✔ Success: https://www.realestate.com.kh/157961/
# [695] ✔ Success: https://www.realestate.com.kh/215142/
# [698] ✔ Success: https://www.realestate.com.kh/155905/
# [696] ✔ Success: https://www.realestate.com.kh/215990/
# [693] ✔ Success: https://www.realestate.com.kh/188145/
# [700] ✔ Success: https://www.realestate.com.kh/234307/
# [702] ✔ Success: https://www.realestate.com.kh/234301/
# [704] ✔ Success: https://www.realestate.com.kh/234540/
# [705] ✔ Success: https://www.realestate.com.kh/217947/
# [703] ✔ Success: https://www.realestate.com.kh/234720/
# [706] ✔ Success: https://www.realestate.com.kh/207940/
# [709] ✔ Success: https://www.realestate.com.kh/235346/
# [708] ✔ Success: https://www.realestate.com.kh/235035/
# [707] ✔ Success: https://www.realestate.com.kh/210024/
# [710] ✔ Success: https://www.realestate.com.kh/215436/
# [711] ✔ Success: https://www.realestate.com.kh/210557/
# [714] ✔ Success: https://www.realestate.com.kh/188147/
# [713] ✔ Success: https://www.realestate.com.kh/223157/
# [712] ✔ Success: https://www.realestate.com.kh/223150/
# [715] ✔ Success: https://www.realestate.com.kh/151856/
# [716] ✔ Success: https://www.realestate.com.kh/208362/
# [718] ✔ Success: https://www.realestate.com.kh/226477/
# [721] ✔ Success: https://www.realestate.com.kh/185620/
# [727] ✔ Success: https://www.realestate.com.kh/160087/
# [722] ✔ Success: https://www.realestate.com.kh/229027/
# [719] ✔ Success: https://www.realestate.com.kh/226464/
# [720] ✔ Success: https://www.realestate.com.kh/219753/
# [725] ✔ Success: https://www.realestate.com.kh/228903/
# [723] ✔ Success: https://www.realestate.com.kh/202801/
# [724] ✔ Success: https://www.realestate.com.kh/220945/
# [728] ✔ Success: https://www.realestate.com.kh/202794/
# [726] ✔ Success: https://www.realestate.com.kh/179537/
# [729] ✔ Success: https://www.realestate.com.kh/223812/
# [731] ✔ Success: https://www.realestate.com.kh/212387/
# [730] ✔ Success: https://www.realestate.com.kh/223759/
# [734] ✔ Success: https://www.realestate.com.kh/152440/
# [733] ✔ Success: https://www.realestate.com.kh/206576/
# [737] ✔ Success: https://www.realestate.com.kh/206715/
# [735] ✔ Success: https://www.realestate.com.kh/212326/
# [732] ✔ Success: https://www.realestate.com.kh/158303/
# [736] ✔ Success: https://www.realestate.com.kh/197513/
# [738] ✔ Success: https://www.realestate.com.kh/205824/
# [739] ✔ Success: https://www.realestate.com.kh/206552/
# [740] ✔ Success: https://www.realestate.com.kh/235820/
# [743] ✔ Success: https://www.realestate.com.kh/215624/[744] ✔ Success: https://www.realestate.com.kh/215893/
#
# [745] ✔ Success: https://www.realestate.com.kh/217001/
# [748] ✔ Success: https://www.realestate.com.kh/199540/
# [742] ✔ Success: https://www.realestate.com.kh/216362/
# [749] ✔ Success: https://www.realestate.com.kh/212951/[750] ✔ Success: https://www.realestate.com.kh/212820/
#
# [717] ✘ No span found: https://www.realestate.com.kh/134063/
# [741] ✔ Success: https://www.realestate.com.kh/222842/
# [746] ✔ Success: https://www.realestate.com.kh/150510/
# [753] ✔ Success: https://www.realestate.com.kh/217009/
# [755] ✔ Success: https://www.realestate.com.kh/219052/
# [751] ✔ Success: https://www.realestate.com.kh/149861/
# [754] ✔ Success: https://www.realestate.com.kh/216631/
# [752] ✔ Success: https://www.realestate.com.kh/210602/
# [747] ✔ Success: https://www.realestate.com.kh/149429/
# [762] ✔ Success: https://www.realestate.com.kh/223143/
# [760] ✔ Success: https://www.realestate.com.kh/212803/
# [758] ✔ Success: https://www.realestate.com.kh/212909/
# [757] ✔ Success: https://www.realestate.com.kh/217405/
# [759] ✔ Success: https://www.realestate.com.kh/212260/
# [761] ✔ Success: https://www.realestate.com.kh/219058/
# [756] ✔ Success: https://www.realestate.com.kh/218780/
# [763] ✔ Success: https://www.realestate.com.kh/218596/
# [764] ✔ Success: https://www.realestate.com.kh/222502/
# [771] ✔ Success: https://www.realestate.com.kh/212800/
# [770] ✔ Success: https://www.realestate.com.kh/146462/
# [765] ✔ Success: https://www.realestate.com.kh/215905/
# [768] ✔ Success: https://www.realestate.com.kh/218681/
# [767] ✔ Success: https://www.realestate.com.kh/213343/
# [772] ✔ Success: https://www.realestate.com.kh/212818/
# [769] ✔ Success: https://www.realestate.com.kh/218676/
# [773] ✔ Success: https://www.realestate.com.kh/199404/
# [775] ✔ Success: https://www.realestate.com.kh/197859/
# [777] ✔ Success: https://www.realestate.com.kh/229095/
# [776] ✔ Success: https://www.realestate.com.kh/224925/
# [774] ✔ Success: https://www.realestate.com.kh/198842/
# [766] ✔ Success: https://www.realestate.com.kh/148077/
# [778] ✔ Success: https://www.realestate.com.kh/229623/
# [782] ✔ Success: https://www.realestate.com.kh/232706/
# [784] ✔ Success: https://www.realestate.com.kh/234324/
# [785] ✔ Success: https://www.realestate.com.kh/224905/
# [780] ✔ Success: https://www.realestate.com.kh/144405/
# [788] ✔ Success: https://www.realestate.com.kh/229099/
# [787] ✔ Success: https://www.realestate.com.kh/229107/
# [781] ✔ Success: https://www.realestate.com.kh/147292/
# [783] ✔ Success: https://www.realestate.com.kh/235266/
# [786] ✔ Success: https://www.realestate.com.kh/200238/
# [779] ✔ Success: https://www.realestate.com.kh/229622/
# [789] ✔ Success: https://www.realestate.com.kh/229189/
# [791] ✔ Success: https://www.realestate.com.kh/229527/
# [794] ✔ Success: https://www.realestate.com.kh/231208/
# [792] ✔ Success: https://www.realestate.com.kh/141246/
# [795] ✔ Success: https://www.realestate.com.kh/201857/
# [790] ✔ Success: https://www.realestate.com.kh/229266/
# [796] ✔ Success: https://www.realestate.com.kh/228704/
# [793] ✔ Success: https://www.realestate.com.kh/141247/
# [797] ✔ Success: https://www.realestate.com.kh/228776/
# [799] ✔ Success: https://www.realestate.com.kh/228853/
# [801] ✔ Success: https://www.realestate.com.kh/229080/
# [798] ✔ Success: https://www.realestate.com.kh/228779/
# [802] ✔ Success: https://www.realestate.com.kh/235113/
# [800] ✔ Success: https://www.realestate.com.kh/228942/
# [803] ✔ Success: https://www.realestate.com.kh/230550/
# [804] ✔ Success: https://www.realestate.com.kh/231245/
# [806] ✔ Success: https://www.realestate.com.kh/164236/
# [805] ✔ Success: https://www.realestate.com.kh/235231/
# [809] ✔ Success: https://www.realestate.com.kh/208845/[807] ✔ Success: https://www.realestate.com.kh/208615/
#
# [810] ✔ Success: https://www.realestate.com.kh/235239/
# [813] ✔ Success: https://www.realestate.com.kh/187229/
# [811] ✔ Success: https://www.realestate.com.kh/235340/
# [808] ✔ Success: https://www.realestate.com.kh/208359/
# [812] ✔ Success: https://www.realestate.com.kh/233615/
# [814] ✔ Success: https://www.realestate.com.kh/207620/
# [815] ✔ Success: https://www.realestate.com.kh/234411/
# [821] ✔ Success: https://www.realestate.com.kh/182040/
# [816] ✔ Success: https://www.realestate.com.kh/233611/
# [818] ✔ Success: https://www.realestate.com.kh/207621/
# [823] ✔ Success: https://www.realestate.com.kh/182067/
# [824] ✔ Success: https://www.realestate.com.kh/182068/
# [819] ✔ Success: https://www.realestate.com.kh/207096/
# [817] ✔ Success: https://www.realestate.com.kh/157963/
# [822] ✔ Success: https://www.realestate.com.kh/228206/
# [820] ✔ Success: https://www.realestate.com.kh/185465/
# [828] ✔ Success: https://www.realestate.com.kh/184575/
# [826] ✔ Success: https://www.realestate.com.kh/210022/
# [825] ✔ Success: https://www.realestate.com.kh/207011/
# [827] ✔ Success: https://www.realestate.com.kh/208609/
# [829] ✔ Success: https://www.realestate.com.kh/224049/
# [830] ✔ Success: https://www.realestate.com.kh/223151/
# [831] ✔ Success: https://www.realestate.com.kh/224212/
# [832] ✔ Success: https://www.realestate.com.kh/223792/
# [837] ✔ Success: https://www.realestate.com.kh/224202/
# [833] ✔ Success: https://www.realestate.com.kh/210090/
# [836] ✔ Success: https://www.realestate.com.kh/210020/
# [834] ✔ Success: https://www.realestate.com.kh/207155/
# [835] ✔ Success: https://www.realestate.com.kh/206922/
# [838] ✔ Success: https://www.realestate.com.kh/202335/
# [839] ✔ Success: https://www.realestate.com.kh/202853/
# [840] ✔ Success: https://www.realestate.com.kh/215503/
# [841] ✔ Success: https://www.realestate.com.kh/215942/
# [842] ✔ Success: https://www.realestate.com.kh/216360/
# [843] ✔ Success: https://www.realestate.com.kh/223771/
# [847] ✔ Success: https://www.realestate.com.kh/236030/
# [845] ✔ Success: https://www.realestate.com.kh/236022/
# [846] ✔ Success: https://www.realestate.com.kh/236004/
# [848] ✔ Success: https://www.realestate.com.kh/236003/
# [849] ✔ Success: https://www.realestate.com.kh/235999/
# [844] ✔ Success: https://www.realestate.com.kh/135722/
# [850] ✔ Success: https://www.realestate.com.kh/235989/
# [852] ✔ Success: https://www.realestate.com.kh/207790/
# [851] ✔ Success: https://www.realestate.com.kh/205243/
# [854] ✔ Success: https://www.realestate.com.kh/207636/[853] ✔ Success: https://www.realestate.com.kh/206580/
#
# [855] ✔ Success: https://www.realestate.com.kh/207635/
# [856] ✔ Success: https://www.realestate.com.kh/206962/
# [858] ✔ Success: https://www.realestate.com.kh/206722/
# [857] ✔ Success: https://www.realestate.com.kh/207164/
# [860] ✔ Success: https://www.realestate.com.kh/152715/
# [859] ✔ Success: https://www.realestate.com.kh/199284/
# [861] ✔ Success: https://www.realestate.com.kh/162344/
# [864] ✔ Success: https://www.realestate.com.kh/219257/
# [866] ✔ Success: https://www.realestate.com.kh/207624/
# [863] ✔ Success: https://www.realestate.com.kh/217121/
# [869] ✔ Success: https://www.realestate.com.kh/206760/
# [862] ✔ Success: https://www.realestate.com.kh/213820/
# [868] ✔ Success: https://www.realestate.com.kh/207131/[867] ✔ Success: https://www.realestate.com.kh/206925/
#
# [865] ✔ Success: https://www.realestate.com.kh/207242/
# [871] ✔ Success: https://www.realestate.com.kh/219451/
# [870] ✔ Success: https://www.realestate.com.kh/210636/
# [872] ✔ Success: https://www.realestate.com.kh/218572/
# [873] ✔ Success: https://www.realestate.com.kh/219011/
# ...
# [6082] ✔ Success: https://www.realestate.com.kh/237451/
# [6086] ✔ Success: https://www.realestate.com.kh/237921/
# [6085] ✔ Success: https://www.realestate.com.kh/237657/
# [6087] ✔ Success: https://www.realestate.com.kh/237924/
# [6088] ✔ Success: https://www.realestate.com.kh/237940/
# [6089] ✔ Success: https://www.realestate.com.kh/237917/
# [6091] ✔ Success: https://www.realestate.com.kh/238046/
# [6090] ✔ Success: https://www.realestate.com.kh/238048/
# [6094] ✔ Success: https://www.realestate.com.kh/149265/
# [6095] ✔ Success: https://www.realestate.com.kh/238095/
# [6092] ✔ Success: https://www.realestate.com.kh/145991/
# [6093] ✔ Success: https://www.realestate.com.kh/147381/
# [6097] ✔ Success: https://www.realestate.com.kh/238422/
# [6098] ✔ Success: https://www.realestate.com.kh/239569/
# [6096] ✔ Success: https://www.realestate.com.kh/238047/
# [6099] ✔ Success: https://www.realestate.com.kh/239650/
# [6100] ✔ Success: https://www.realestate.com.kh/239128/[6101] ✔ Success: https://www.realestate.com.kh/229959/
#
# [6104] ✔ Success: https://www.realestate.com.kh/223826/
# [6102] ✔ Success: https://www.realestate.com.kh/192318/
# [6103] ✔ Success: https://www.realestate.com.kh/192190/
# [6105] ✔ Success: https://www.realestate.com.kh/234228/
# [6106] ✔ Success: https://www.realestate.com.kh/165096/[6108] ✔ Success: https://www.realestate.com.kh/188939/
#
# [6109] ✔ Success: https://www.realestate.com.kh/122540/
# [6110] ✔ Success: https://www.realestate.com.kh/122689/[6111] ✔ Success: https://www.realestate.com.kh/223098/
# [6113] ✔ Success: https://www.realestate.com.kh/122410/
#
# [6114] ✔ Success: https://www.realestate.com.kh/145921/
# [6112] ✔ Success: https://www.realestate.com.kh/220537/
# [6116] ✔ Success: https://www.realestate.com.kh/124750/
# [6115] ✔ Success: https://www.realestate.com.kh/199000/
# [6107] ✔ Success: https://www.realestate.com.kh/188941/
# [6119] ✔ Success: https://www.realestate.com.kh/202527/
# [6122] ✔ Success: https://www.realestate.com.kh/228956/
# [6118] ✔ Success: https://www.realestate.com.kh/202261/
# [6117] ✔ Success: https://www.realestate.com.kh/221373/
# [6121] ✔ Success: https://www.realestate.com.kh/217614/
# [6120] ✔ Success: https://www.realestate.com.kh/192167/
# [6124] ✔ Success: https://www.realestate.com.kh/201578/
# [6123] ✔ Success: https://www.realestate.com.kh/229001/
# [6126] ✔ Success: https://www.realestate.com.kh/229618/
# [6125] ✔ Success: https://www.realestate.com.kh/103473/
# [6127] ✔ Success: https://www.realestate.com.kh/215015/
# [6128] ✔ Success: https://www.realestate.com.kh/201539/
# [6129] ✔ Success: https://www.realestate.com.kh/200308/
# [6132] ✔ Success: https://www.realestate.com.kh/226976/
# [6131] ✔ Success: https://www.realestate.com.kh/120993/
# [6130] ✔ Success: https://www.realestate.com.kh/121196/
# [6137] ✔ Success: https://www.realestate.com.kh/178490/
# [6134] ✔ Success: https://www.realestate.com.kh/121200/[6140] ✔ Success: https://www.realestate.com.kh/242418/
#
# [6139] ✔ Success: https://www.realestate.com.kh/197036/
# [6135] ✔ Success: https://www.realestate.com.kh/121198/
# [6141] ✔ Success: https://www.realestate.com.kh/227926/
# [6138] ✔ Success: https://www.realestate.com.kh/146921/
# [6133] ✔ Success: https://www.realestate.com.kh/215254/
# [6136] ✔ Success: https://www.realestate.com.kh/121197/
# [6144] ✔ Success: https://www.realestate.com.kh/243299/
# [6143] ✔ Success: https://www.realestate.com.kh/243297/
# [6142] ✔ Success: https://www.realestate.com.kh/243301/
# [6146] ✔ Success: https://www.realestate.com.kh/243502/
# [6145] ✔ Success: https://www.realestate.com.kh/243505/
# [6147] ✔ Success: https://www.realestate.com.kh/243378/
# [6149] ✔ Success: https://www.realestate.com.kh/243277/
# [6152] ✔ Success: https://www.realestate.com.kh/243554/
# [6148] ✔ Success: https://www.realestate.com.kh/228187/
# [6151] ✔ Success: https://www.realestate.com.kh/243302/
# [6150] ✔ Success: https://www.realestate.com.kh/138611/
# [6154] ✔ Success: https://www.realestate.com.kh/172111/
# [6153] ✔ Success: https://www.realestate.com.kh/245608/
# [6155] ✔ Success: https://www.realestate.com.kh/246159/
# [6156] ✔ Success: https://www.realestate.com.kh/246146/
# [6162] ✔ Success: https://www.realestate.com.kh/243278/[6158] ✔ Success: https://www.realestate.com.kh/246708/
#
# [6157] ✔ Success: https://www.realestate.com.kh/246709/
# [6160] ✔ Success: https://www.realestate.com.kh/246990/[6164] ✔ Success: https://www.realestate.com.kh/248765/
#
# [6163] ✔ Success: https://www.realestate.com.kh/249740/
# [6166] ✔ Success: https://www.realestate.com.kh/230048/
# [6165] ✔ Success: https://www.realestate.com.kh/192205/
# [6159] ✔ Success: https://www.realestate.com.kh/232352/
# [6167] ✔ Success: https://www.realestate.com.kh/249384/
# [6170] ✔ Success: https://www.realestate.com.kh/246123/
# [6161] ✔ Success: https://www.realestate.com.kh/236264/
# [6169] ✔ Success: https://www.realestate.com.kh/249392/
# [6171] ✔ Success: https://www.realestate.com.kh/249570/
# [6168] ✔ Success: https://www.realestate.com.kh/249386/
# [6174] ✔ Success: https://www.realestate.com.kh/249455/
# [6172] ✔ Success: https://www.realestate.com.kh/249486/
# [6176] ✔ Success: https://www.realestate.com.kh/249736/
# [6175] ✔ Success: https://www.realestate.com.kh/249516/
# [6173] ✔ Success: https://www.realestate.com.kh/249482/
# [6177] ✔ Success: https://www.realestate.com.kh/229643/
# [6178] ✔ Success: https://www.realestate.com.kh/245453/
# [6179] ✔ Success: https://www.realestate.com.kh/120718/
# [6180] ✔ Success: https://www.realestate.com.kh/220923/
# [6185] ✔ Success: https://www.realestate.com.kh/234777/[6183] ✔ Success: https://www.realestate.com.kh/233154/
#
# [6181] ✔ Success: https://www.realestate.com.kh/222258/
# [6182] ✔ Success: https://www.realestate.com.kh/252011/
# [6186] ✔ Success: https://www.realestate.com.kh/235659/
# [6184] ✔ Success: https://www.realestate.com.kh/235526/
# [6187] ✔ Success: https://www.realestate.com.kh/234896/
# [6190] ✔ Success: https://www.realestate.com.kh/230396/
# [6189] ✔ Success: https://www.realestate.com.kh/234710/
# [6191] ✔ Success: https://www.realestate.com.kh/231324/
# [6188] ✔ Success: https://www.realestate.com.kh/223422/
# [6192] ✔ Success: https://www.realestate.com.kh/227935/
# [6194] ✔ Success: https://www.realestate.com.kh/231404/
# [6195] ✔ Success: https://www.realestate.com.kh/222173/
# [6202] ✔ Success: https://www.realestate.com.kh/230213/
# [6200] ✔ Success: https://www.realestate.com.kh/232745/
# [6198] ✔ Success: https://www.realestate.com.kh/201845/
# [6199] ✔ Success: https://www.realestate.com.kh/230393/
# [6197] ✔ Success: https://www.realestate.com.kh/229850/
# [6201] ✔ Success: https://www.realestate.com.kh/233163/
# [6204] ✔ Success: https://www.realestate.com.kh/222320/
# [6205] ✔ Success: https://www.realestate.com.kh/229584/
# [6196] ✔ Success: https://www.realestate.com.kh/146497/
# [6193] ✔ Success: https://www.realestate.com.kh/160073/
# [6203] ✔ Success: https://www.realestate.com.kh/160074/
# [6206] ✔ Success: https://www.realestate.com.kh/229583/
# [6208] ✔ Success: https://www.realestate.com.kh/231176/
# [6207] ✔ Success: https://www.realestate.com.kh/231117/
# [6209] ✔ Success: https://www.realestate.com.kh/231063/
# [6213] ✔ Success: https://www.realestate.com.kh/209949/
# [6212] ✔ Success: https://www.realestate.com.kh/102975/
# [6210] ✔ Success: https://www.realestate.com.kh/160077/
# [6211] ✔ Success: https://www.realestate.com.kh/154974/
# [6217] ✔ Success: https://www.realestate.com.kh/139728/
# [6218] ✔ Success: https://www.realestate.com.kh/228571/
# [6216] ✔ Success: https://www.realestate.com.kh/235868/
# [6214] ✔ Success: https://www.realestate.com.kh/227601/
# [6215] ✔ Success: https://www.realestate.com.kh/236420/
# [6219] ✔ Success: https://www.realestate.com.kh/232326/
# [6220] ✔ Success: https://www.realestate.com.kh/230399/
# [6225] ✔ Success: https://www.realestate.com.kh/230944/
# [6223] ✔ Success: https://www.realestate.com.kh/231227/
# [6228] ✔ Success: https://www.realestate.com.kh/232846/[6226] ✔ Success: https://www.realestate.com.kh/216741/
#
# [6224] ✔ Success: https://www.realestate.com.kh/231210/
# [6227] ✔ Success: https://www.realestate.com.kh/234542/
# [6221] ✔ Success: https://www.realestate.com.kh/231325/
# [6222] ✔ Success: https://www.realestate.com.kh/231536/
# [6229] ✔ Success: https://www.realestate.com.kh/229922/
# [6230] ✔ Success: https://www.realestate.com.kh/236295/
# [6232] ✔ Success: https://www.realestate.com.kh/237375/
# [6231] ✔ Success: https://www.realestate.com.kh/237048/
# [6234] ✔ Success: https://www.realestate.com.kh/236672/
# [6236] ✔ Success: https://www.realestate.com.kh/237876/
# [6237] ✔ Success: https://www.realestate.com.kh/238104/
# [6235] ✔ Success: https://www.realestate.com.kh/236342/
# [6239] ✔ Success: https://www.realestate.com.kh/239453/
# [6233] ✔ Success: https://www.realestate.com.kh/237664/
# [6238] ✔ Success: https://www.realestate.com.kh/238595/
# [6243] ✔ Success: https://www.realestate.com.kh/238159/
# [6242] ✔ Success: https://www.realestate.com.kh/238801/
# [6240] ✔ Success: https://www.realestate.com.kh/239488/
# [6244] ✔ Success: https://www.realestate.com.kh/238764/
# [6241] ✔ Success: https://www.realestate.com.kh/239564/
# [6245] ✔ Success: https://www.realestate.com.kh/238765/
# [6246] ✔ Success: https://www.realestate.com.kh/237304/
# [6249] ✔ Success: https://www.realestate.com.kh/240211/
# [6248] ✔ Success: https://www.realestate.com.kh/237295/
# [6252] ✔ Success: https://www.realestate.com.kh/240603/
# [6253] ✔ Success: https://www.realestate.com.kh/240601/
# [6250] ✔ Success: https://www.realestate.com.kh/240105/
# [6251] ✔ Success: https://www.realestate.com.kh/237794/
# [6254] ✔ Success: https://www.realestate.com.kh/240674/
# [6255] ✔ Success: https://www.realestate.com.kh/240722/
# [6247] ✔ Success: https://www.realestate.com.kh/153134/
# [6256] ✔ Success: https://www.realestate.com.kh/240796/
# [6257] ✔ Success: https://www.realestate.com.kh/240798/
# [6260] ✔ Success: https://www.realestate.com.kh/240324/
# [6262] ✔ Success: https://www.realestate.com.kh/240940/
# [6261] ✔ Success: https://www.realestate.com.kh/240837/
# [6259] ✔ Success: https://www.realestate.com.kh/240104/
# [6258] ✔ Success: https://www.realestate.com.kh/239868/
# [6264] ✔ Success: https://www.realestate.com.kh/241180/
# [6266] ✔ Success: https://www.realestate.com.kh/241182/
# [6263] ✔ Success: https://www.realestate.com.kh/240949/
# [6265] ✔ Success: https://www.realestate.com.kh/241189/
# [6268] ✔ Success: https://www.realestate.com.kh/239881/
# [6267] ✔ Success: https://www.realestate.com.kh/241183/
# [6269] ✔ Success: https://www.realestate.com.kh/231081/
# [6270] ✔ Success: https://www.realestate.com.kh/231328/
# [6271] ✔ Success: https://www.realestate.com.kh/231118/
# [6273] ✔ Success: https://www.realestate.com.kh/193841/
# [6272] ✔ Success: https://www.realestate.com.kh/232610/
# [6279] ✔ Success: https://www.realestate.com.kh/233035/
# [6276] ✔ Success: https://www.realestate.com.kh/229626/
# [6280] ✔ Success: https://www.realestate.com.kh/241480/
# [6277] ✔ Success: https://www.realestate.com.kh/241385/[6274] ✔ Success: https://www.realestate.com.kh/229296/
# [6275] ✔ Success: https://www.realestate.com.kh/226301/
#
# [6278] ✔ Success: https://www.realestate.com.kh/241419/
# [6281] ✔ Success: https://www.realestate.com.kh/241569/
# [6282] ✔ Success: https://www.realestate.com.kh/241620/
# [6284] ✔ Success: https://www.realestate.com.kh/242131/
# [6283] ✔ Success: https://www.realestate.com.kh/242132/
# [6286] ✔ Success: https://www.realestate.com.kh/242350/
# [6285] ✔ Success: https://www.realestate.com.kh/214850/
# [6291] ✔ Success: https://www.realestate.com.kh/243575/
# [6290] ✔ Success: https://www.realestate.com.kh/243567/
# [6288] ✔ Success: https://www.realestate.com.kh/242908/
# [6287] ✔ Success: https://www.realestate.com.kh/241731/
# [6294] ✔ Success: https://www.realestate.com.kh/246264/
# [6292] ✔ Success: https://www.realestate.com.kh/243614/
# [6293] ✔ Success: https://www.realestate.com.kh/246114/
# [6289] ✔ Success: https://www.realestate.com.kh/111478/
# [6296] ✔ Success: https://www.realestate.com.kh/245923/
# [6295] ✔ Success: https://www.realestate.com.kh/246177/
# [6298] ✔ Success: https://www.realestate.com.kh/111238/
# [6303] ✔ Success: https://www.realestate.com.kh/247474/
# [6301] ✔ Success: https://www.realestate.com.kh/244355/
# [6304] ✔ Success: https://www.realestate.com.kh/247473/
# [6300] ✔ Success: https://www.realestate.com.kh/195287/
# [6307] ✔ Success: https://www.realestate.com.kh/235172/
# [6306] ✔ Success: https://www.realestate.com.kh/195289/
# [6297] ✔ Success: https://www.realestate.com.kh/162434/
# [6305] ✔ Success: https://www.realestate.com.kh/247472/
# [6302] ✔ Success: https://www.realestate.com.kh/244090/
# [6299] ✔ Success: https://www.realestate.com.kh/246794/
# [6313] ✔ Success: https://www.realestate.com.kh/248890/
# [6308] ✔ Success: https://www.realestate.com.kh/249978/
# [6311] ✔ Success: https://www.realestate.com.kh/249747/
# [6314] ✔ Success: https://www.realestate.com.kh/247668/
# [6312] ✔ Success: https://www.realestate.com.kh/248681/
# [6315] ✔ Success: https://www.realestate.com.kh/222294/
# [6309] ✔ Success: https://www.realestate.com.kh/108048/
# [6310] ✔ Success: https://www.realestate.com.kh/53969/
# [6316] ✔ Success: https://www.realestate.com.kh/248061/
# [6319] ✔ Success: https://www.realestate.com.kh/248396/
# [6318] ✔ Success: https://www.realestate.com.kh/99158/
# [6317] ✔ Success: https://www.realestate.com.kh/51329/
# [6321] ✔ Success: https://www.realestate.com.kh/211192/
# [6329] ✔ Success: https://www.realestate.com.kh/147234/
# [6325] ✔ Success: https://www.realestate.com.kh/212036/
# [6330] ✔ Success: https://www.realestate.com.kh/147236/
# [6327] ✔ Success: https://www.realestate.com.kh/224394/
# [6324] ✔ Success: https://www.realestate.com.kh/216163/
# [6323] ✔ Success: https://www.realestate.com.kh/223696/
# [6322] ✔ Success: https://www.realestate.com.kh/235842/
# [6320] ✔ Success: https://www.realestate.com.kh/252488/
# [6331] ✔ Success: https://www.realestate.com.kh/224385/
# [6326] ✔ Success: https://www.realestate.com.kh/231329/
# [6332] ✔ Success: https://www.realestate.com.kh/238534/
# [6328] ✔ Success: https://www.realestate.com.kh/231423/
# [6333] ✔ Success: https://www.realestate.com.kh/236107/
# [6334] ✔ Success: https://www.realestate.com.kh/240699/
# [6338] ✔ Success: https://www.realestate.com.kh/245623/
# [6335] ✔ Success: https://www.realestate.com.kh/240869/
# [6336] ✔ Success: https://www.realestate.com.kh/229499/
# [6337] ✔ Success: https://www.realestate.com.kh/226479/
# [6340] ✔ Success: https://www.realestate.com.kh/204108/
# [6339] ✔ Success: https://www.realestate.com.kh/229766/
# [6344] ✔ Success: https://www.realestate.com.kh/222866/
# [6341] ✔ Success: https://www.realestate.com.kh/247667/
# [6342] ✔ Success: https://www.realestate.com.kh/247669/[6343] ✔ Success: https://www.realestate.com.kh/229816/
#
# [6345] ✔ Success: https://www.realestate.com.kh/250010/
# [6352] ✔ Success: https://www.realestate.com.kh/217653/[6347] ✔ Success: https://www.realestate.com.kh/236033/
#
# [6353] ✔ Success: https://www.realestate.com.kh/221010/
# [6346] ✔ Success: https://www.realestate.com.kh/247284/
# [6354] ✔ Success: https://www.realestate.com.kh/236032/
# [6351] ✔ Success: https://www.realestate.com.kh/235379/
# [6349] ✔ Success: https://www.realestate.com.kh/223956/
# [6357] ✔ Success: https://www.realestate.com.kh/224369/
# [6348] ✔ Success: https://www.realestate.com.kh/224384/
# [6350] ✔ Success: https://www.realestate.com.kh/232921/
# [6355] ✔ Success: https://www.realestate.com.kh/206261/
# [6356] ✔ Success: https://www.realestate.com.kh/222493/
# [6358] ✔ Success: https://www.realestate.com.kh/209172/
# [6360] ✔ Success: https://www.realestate.com.kh/231472/
# [6359] ✔ Success: https://www.realestate.com.kh/209888/
# [6362] ✔ Success: https://www.realestate.com.kh/241358/
# [6363] ✔ Success: https://www.realestate.com.kh/245998/
# [6361] ✔ Success: https://www.realestate.com.kh/232292/
# [6364] ✔ Success: https://www.realestate.com.kh/246364/
# [6368] ✔ Success: https://www.realestate.com.kh/231160/
# [6367] ✔ Success: https://www.realestate.com.kh/246457/
# [6365] ✔ Success: https://www.realestate.com.kh/217364/
# [6366] ✔ Success: https://www.realestate.com.kh/231535/

# %%
df_all
# Out:
#       Unnamed: 0      id                                           headline  \
# 0              0  204942  A flat (2 floors) near Hengly market and near ...
# 1              1  211997  Twin Villa (Twin Villa) in Borey Highland 2005...
# 2              2  212595                                     house for sale
# 3              3  211987                    House for sale in Meanchey Area
# 4              4  212653  House for Sale Urgently | Extra Space and Stai...
# ...          ...     ...                                                ...
# 6364        6364  246364  Land in Phnom Tamao | Selling 60% below market...
# 6365        6365  217364                               ផ្ទះសំណាក់លក់បន្ទាន់
# 6366        6366  231535         ដី ចំការធូរ៉េន លក់ | Durian Farm For Sale
# 6367        6367  246457                                      Land For Sale
# 6368        6368  231160  The land location is about 800 meters from Mem...
#
#      price_display rent_display  bedrooms  bathrooms  land_area  \
# 0         $150,000          NaN       6.0        4.0        NaN
# 1         $269,000          NaN       4.0        7.0        NaN
# 2          $85,000          NaN       2.0        2.0        NaN
# 3         $450,000          NaN       8.0        6.0        0.0
# 4          $85,000          NaN       2.0        2.0        NaN
# ...            ...          ...       ...        ...        ...
# 6364    $1,440,000          NaN       NaN        NaN    80000.0
# 6365           POA          NaN      18.0       18.0        NaN
# 6366   $100,000/m²          NaN       NaN        NaN        NaN
# 6367      $147,000          NaN       NaN        NaN    22317.0
# 6368      $100,000          NaN       NaN        NaN      530.0
#
#                                           thumbnail_url  \
# 0     https://images.realestate.com.kh/__sized__/lis...
# 1     https://images.realestate.com.kh/__sized__/lis...
# 2     https://images.realestate.com.kh/__sized__/lis...
# 3     https://images.realestate.com.kh/__sized__/lis...
# 4     https://images.realestate.com.kh/__sized__/lis...
# ...                                                 ...
# 6364  https://images.realestate.com.kh/__sized__/lis...
# 6365  https://images.realestate.com.kh/__sized__/lis...
# 6366  https://images.realestate.com.kh/__sized__/lis...
# 6367  https://images.realestate.com.kh/__sized__/lis...
# 6368  https://images.realestate.com.kh/__sized__/lis...
#
#                                          thumbnail_urls  ...  \
# 0     ['https://images.realestate.com.kh/__sized__/l...  ...
# 1     ['https://images.realestate.com.kh/__sized__/l...  ...
# 2     ['https://images.realestate.com.kh/__sized__/l...  ...
# 3     ['https://images.realestate.com.kh/__sized__/l...  ...
# 4     ['https://images.realestate.com.kh/__sized__/l...  ...
# ...                                                 ...  ...
# 6364  ['https://images.realestate.com.kh/__sized__/l...  ...
# 6365  ['https://images.realestate.com.kh/__sized__/l...  ...
# 6366  ['https://images.realestate.com.kh/__sized__/l...  ...
# 6367  ['https://images.realestate.com.kh/__sized__/l...  ...
# 6368  ['https://images.realestate.com.kh/__sized__/l...  ...
#
#          category_name is_parent         type  \
# 0                 Flat     False  residential
# 1           Twin Villa     False  residential
# 2                House     False  residential
# 3                 Flat     False  residential
# 4                 Flat     False  residential
# ...                ...       ...          ...
# 6364              Land     False   commercial
# 6365             House     False  residential
# 6366  Land/Development     False  residential
# 6367  Land/Development     False  residential
# 6368          Business     False   commercial
#
#                                             information  \
# 0     A flat (2 floors) near Hengly market and near ...
# 1     Twin Villa (Twin Villa) in Borey Highland 2005...
# 2     មាន3ជាន់ 2បន្ទប់ទឹក បន្ទប់គេង2 អាចដាក់ម៉ូតូបាន...
# 3     I have a business house, I want to sell a hous...
# 4     ផ្ទះល្វែងលក់បន្ទាន់ 4m * 15.5m មានជណ្ដើរកៀន ចង...
# ...                                                 ...
# 6364  Land in Phnom Tamao | Selling 60% below market...
# 6365  លក់ផ្ទះសំណាក់បន្ទាន់ តម្លៃសមរម្យដែលអាចចរចាបាន ...
# 6366  ដី ចំការធូរ៉េន លក់ | Durian Farm For Sale ទីតា...
# 6367  This Land area is located the middle of thaila...
# 6368  Lot near Memot market, big town, best for buil...
#
#                                  source_url language   latitude   longitude  \
# 0     https://www.realestate.com.kh/204942/       en  11.530000  104.910000
# 1     https://www.realestate.com.kh/211997/       en  11.550000  104.890000
# 2     https://www.realestate.com.kh/212595/       km  11.554793  104.917136
# 3     https://www.realestate.com.kh/211987/       en  11.539648  104.886328
# 4     https://www.realestate.com.kh/212653/       km  11.550000  104.930000
# ...                                     ...      ...        ...         ...
# 6364  https://www.realestate.com.kh/246364/       en  11.297113  104.822738
# 6365  https://www.realestate.com.kh/217364/       km  11.761335  105.944320
# 6366  https://www.realestate.com.kh/231535/       km  11.709971  105.956464
# 6367  https://www.realestate.com.kh/246457/       en  12.042240  105.680894
# 6368  https://www.realestate.com.kh/231160/       en  11.824865  106.182672
#
#         land_size house_size
# 0      4m x 22.5m   4m x 16m
# 1            2005   6m x 12m
# 2            None       None
# 3            None       5x18
# 4            None       None
# ...           ...        ...
# 6364   8 hectares       None
# 6365         None       None
# 6366  50 Hectares       None
# 6367         None       None
# 6368         None       None
#
# [6369 rows x 26 columns]

# %%
# --- Define reverse geocoding function ---
def reverse_geocode(lat, lon):
    """
    Reverse geocodes latitude and longitude using Nominatim API to get administrative divisions.
    Adheres to Nominatim usage policy by including a User-Agent and sleeping after each request.
    """
    url = f"https://nominatim.openstreetmap.org/reverse?format=json&lat={lat}&lon={lon}&zoom=18&addressdetails=1"
    nominatim_headers = {
        "User-Agent": "RealEstateScraperForCambodia/1.0 (zinhour10@gmail.com)"  # Replace with your real email
    }
    try:
        response = requests.get(url, headers=nominatim_headers, timeout=10)
        response.raise_for_status()
        data = response.json()
        address = data.get('address', {})

        province = address.get('state')
        district = address.get('city_district') or address.get('county') or address.get('suburb')
        commune = address.get('suburb') or address.get('village') or address.get('town') or address.get('neighbourhood')

        if province == "Phnom Penh":
            if 'city_district' in address:
                district = address['city_district']
            if 'suburb' in address:
                commune = address['suburb']
            elif 'neighbourhood' in address:
                commune = address['neighbourhood']

        return province, district, commune

    except requests.exceptions.RequestException as e:
        print(f"Reverse geocoding failed for {lat}, {lon} (HTTP/Network error): {e}")
        return None, None, None
    except Exception as e:
        print(f"An unexpected error during reverse geocoding for {lat}, {lon}: {e}")
        return None, None, None
    finally:
        time.sleep(1.1)  # Rate limit: max 1 request/sec per Nominatim policy


# --- Prepare DataFrame ---
# (You should load or define your df_all here)
# Example placeholder if needed:
# df_all = pd.DataFrame({
#     'location': ['Loc1', 'Loc2'],
#     'latitude': [11.55, 13.37],
#     'longitude': [104.92, 103.85],
#     'address_subdivision': ['Some Address', 'Another Address']
# })

# Add geocode columns
df_all['province_geocoded'] = None
df_all['district_geocoded'] = None
df_all['commune_geocoded'] = None

print("\nStarting reverse geocoding for location data...")

# Filter only rows with valid coordinates
rows_to_geocode = df_all[df_all['latitude'].notna() & df_all['longitude'].notna()]

# Perform geocoding with rate-limited concurrency
with ThreadPoolExecutor(max_workers=2) as executor:
    futures = {
        executor.submit(reverse_geocode, row['latitude'], row['longitude']): idx
        for idx, row in rows_to_geocode.iterrows()
    }

    for i, future in enumerate(as_completed(futures)):
        original_idx = futures[future]
        province, district, commune = future.result()
        df_all.at[original_idx, 'province_geocoded'] = province
        df_all.at[original_idx, 'district_geocoded'] = district
        df_all.at[original_idx, 'commune_geocoded'] = commune

        if (i + 1) % 10 == 0:
            print(f"Geocoded {i + 1} of {len(futures)} locations...")

print("Reverse geocoding complete.")
print("\nDataFrame with geocoded location details (first 5 rows):")
print(df_all[['location', 'latitude', 'longitude', 'address_subdivision',
              'province_geocoded', 'district_geocoded', 'commune_geocoded']].head())
# Out:
# Starting reverse geocoding for location data...
# Geocoded 10 of 6369 locations...
# Geocoded 20 of 6369 locations...
# Geocoded 30 of 6369 locations...
# Geocoded 40 of 6369 locations...
# Geocoded 50 of 6369 locations...
# Geocoded 60 of 6369 locations...
# Geocoded 70 of 6369 locations...
# Geocoded 80 of 6369 locations...
# Geocoded 90 of 6369 locations...
# Geocoded 100 of 6369 locations...
# Geocoded 110 of 6369 locations...
# Geocoded 120 of 6369 locations...
# Geocoded 130 of 6369 locations...
# Geocoded 140 of 6369 locations...
# Geocoded 150 of 6369 locations...
# Geocoded 160 of 6369 locations...
# Geocoded 170 of 6369 locations...
# Geocoded 180 of 6369 locations...
# Geocoded 190 of 6369 locations...
# Geocoded 200 of 6369 locations...
# Geocoded 210 of 6369 locations...
# Geocoded 220 of 6369 locations...
# Geocoded 230 of 6369 locations...
# Geocoded 240 of 6369 locations...
# Geocoded 250 of 6369 locations...
# Geocoded 260 of 6369 locations...
# Geocoded 270 of 6369 locations...
# Geocoded 280 of 6369 locations...
# Geocoded 290 of 6369 locations...
# Geocoded 300 of 6369 locations...
# Geocoded 310 of 6369 locations...
# Geocoded 320 of 6369 locations...
# Geocoded 330 of 6369 locations...
# Geocoded 340 of 6369 locations...
# Geocoded 350 of 6369 locations...
# Geocoded 360 of 6369 locations...
# Geocoded 370 of 6369 locations...
# Geocoded 380 of 6369 locations...
# Geocoded 390 of 6369 locations...
# Geocoded 400 of 6369 locations...
# Geocoded 410 of 6369 locations...
# Geocoded 420 of 6369 locations...
# Geocoded 430 of 6369 locations...
# Geocoded 440 of 6369 locations...
# Geocoded 450 of 6369 locations...
# Geocoded 460 of 6369 locations...
# Geocoded 470 of 6369 locations...
# Geocoded 480 of 6369 locations...
# Geocoded 490 of 6369 locations...
# Geocoded 500 of 6369 locations...
# Geocoded 510 of 6369 locations...
# Geocoded 520 of 6369 locations...
# Geocoded 530 of 6369 locations...
# Geocoded 540 of 6369 locations...
# Geocoded 550 of 6369 locations...
# Geocoded 560 of 6369 locations...
# Geocoded 570 of 6369 locations...
# Geocoded 580 of 6369 locations...
# Geocoded 590 of 6369 locations...
# Geocoded 600 of 6369 locations...
# Geocoded 610 of 6369 locations...
# Geocoded 620 of 6369 locations...
# Geocoded 630 of 6369 locations...
# Geocoded 640 of 6369 locations...
# Geocoded 650 of 6369 locations...
# Geocoded 660 of 6369 locations...
# Geocoded 670 of 6369 locations...
# Geocoded 680 of 6369 locations...
# Geocoded 690 of 6369 locations...
# Geocoded 700 of 6369 locations...
# Geocoded 710 of 6369 locations...
# Geocoded 720 of 6369 locations...
# Geocoded 730 of 6369 locations...
# Geocoded 740 of 6369 locations...
# Geocoded 750 of 6369 locations...
# Geocoded 760 of 6369 locations...
# Geocoded 770 of 6369 locations...
# Geocoded 780 of 6369 locations...
# Geocoded 790 of 6369 locations...
# Geocoded 800 of 6369 locations...
# Geocoded 810 of 6369 locations...
# Geocoded 820 of 6369 locations...
# Geocoded 830 of 6369 locations...
# Geocoded 840 of 6369 locations...
# Geocoded 850 of 6369 locations...
# Geocoded 860 of 6369 locations...
# Geocoded 870 of 6369 locations...
# Geocoded 880 of 6369 locations...
# Geocoded 890 of 6369 locations...
# Geocoded 900 of 6369 locations...
# Geocoded 910 of 6369 locations...
# Geocoded 920 of 6369 locations...
# Geocoded 930 of 6369 locations...
# Geocoded 940 of 6369 locations...
# Geocoded 950 of 6369 locations...
# Geocoded 960 of 6369 locations...
# Geocoded 970 of 6369 locations...
# Geocoded 980 of 6369 locations...
# Geocoded 990 of 6369 locations...
# Geocoded 1000 of 6369 locations...
# Geocoded 1010 of 6369 locations...
# Geocoded 1020 of 6369 locations...
# Geocoded 1030 of 6369 locations...
# Geocoded 1040 of 6369 locations...
# Geocoded 1050 of 6369 locations...
# Geocoded 1060 of 6369 locations...
# Geocoded 1070 of 6369 locations...
# Geocoded 1080 of 6369 locations...
# Geocoded 1090 of 6369 locations...
# Geocoded 1100 of 6369 locations...
# Geocoded 1110 of 6369 locations...
# Geocoded 1120 of 6369 locations...
# Geocoded 1130 of 6369 locations...
# Geocoded 1140 of 6369 locations...
# Geocoded 1150 of 6369 locations...
# Geocoded 1160 of 6369 locations...
# Geocoded 1170 of 6369 locations...
# Geocoded 1180 of 6369 locations...
# Geocoded 1190 of 6369 locations...
# Geocoded 1200 of 6369 locations...
# Geocoded 1210 of 6369 locations...
# Geocoded 1220 of 6369 locations...
# Geocoded 1230 of 6369 locations...
# Geocoded 1240 of 6369 locations...
# Geocoded 1250 of 6369 locations...
# Geocoded 1260 of 6369 locations...
# Geocoded 1270 of 6369 locations...
# Geocoded 1280 of 6369 locations...
# Geocoded 1290 of 6369 locations...
# Geocoded 1300 of 6369 locations...
# Geocoded 1310 of 6369 locations...
# Geocoded 1320 of 6369 locations...
# Geocoded 1330 of 6369 locations...
# Geocoded 1340 of 6369 locations...
# Geocoded 1350 of 6369 locations...
# Geocoded 1360 of 6369 locations...
# Geocoded 1370 of 6369 locations...
# Geocoded 1380 of 6369 locations...
# Geocoded 1390 of 6369 locations...
# Geocoded 1400 of 6369 locations...
# Geocoded 1410 of 6369 locations...
# Geocoded 1420 of 6369 locations...
# Geocoded 1430 of 6369 locations...
# Geocoded 1440 of 6369 locations...
# Geocoded 1450 of 6369 locations...
# Geocoded 1460 of 6369 locations...
# Geocoded 1470 of 6369 locations...
# Reverse geocoding failed for 11.554667, 104.82684 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.82684&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.82684 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.82684&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.82684 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.82684&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.82684 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.82684&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.82684 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.82684&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.560144467764232, 104.80629471804622 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.560144467764232&lon=104.80629471804622&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.82684 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.82684&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.82684 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.82684&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.551303621969666, 104.80967304938764 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.551303621969666&lon=104.80967304938764&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.82684 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.82684&zoom=18&addressdetails=1
# Geocoded 1480 of 6369 locations...
# Reverse geocoding failed for 11.506268176074855, 104.8844904074731 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.506268176074855&lon=104.8844904074731&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.552013631736951, 104.82142255635154 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.552013631736951&lon=104.82142255635154&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.52169261547148, 104.87159526634571 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.52169261547148&lon=104.87159526634571&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.519802477482031, 104.83747873343657 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.519802477482031&lon=104.83747873343657&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.502497957124945, 104.85275042740244 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.502497957124945&lon=104.85275042740244&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.505945253864255, 104.81928549285374 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.505945253864255&lon=104.81928549285374&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.501445226356921, 104.84168291970917 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.501445226356921&lon=104.84168291970917&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.538743036366839, 104.87199920123254 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.538743036366839&lon=104.87199920123254&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.826843 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.826843&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.559422483307358, 104.87092556004507 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.559422483307358&lon=104.87092556004507&zoom=18&addressdetails=1
# Geocoded 1490 of 6369 locations...
# Reverse geocoding failed for 11.497237801948714, 104.87371635653625 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.497237801948714&lon=104.87371635653625&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.507607012833162, 104.8872852400853 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.507607012833162&lon=104.8872852400853&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.826843 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.826843&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.826843 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.826843&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.826843 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.826843&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.826843 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.826843&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.552516728434043, 104.8126617000595 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.552516728434043&lon=104.8126617000595&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.542890689831609, 104.8319281689121 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.542890689831609&lon=104.8319281689121&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.54912037829429, 104.82117870151319 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.54912037829429&lon=104.82117870151319&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.532036478729195, 104.84802899899228 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.532036478729195&lon=104.84802899899228&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.55766795501189, 104.8255330930483 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.55766795501189&lon=104.8255330930483&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.82684 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.82684&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.499203242942414, 104.8867197252743 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.499203242942414&lon=104.8867197252743&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554742752100992, 104.84152116091047 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554742752100992&lon=104.84152116091047&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.49684801509244, 104.88620469780142 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.49684801509244&lon=104.88620469780142&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.82684 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.82684&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.82684 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.82684&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.826843 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.826843&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.82684 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.82684&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.521877535634601, 104.8573595696102 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.521877535634601&lon=104.8573595696102&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.54881788991834, 104.8615881696685 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.54881788991834&lon=104.8615881696685&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.553658936426686, 104.8254681150853 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.553658936426686&lon=104.8254681150853&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.548569096999188, 104.87050888251423 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.548569096999188&lon=104.87050888251423&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.554667, 104.82684 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.554667&lon=104.82684&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.525512734224975, 104.82251769503529 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.525512734224975&lon=104.82251769503529&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.523827265917005, 104.8522730621678 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.523827265917005&lon=104.8522730621678&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.5516133, 104.8711028 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.5516133&lon=104.8711028&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.5344226, 104.8804893 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.5344226&lon=104.8804893&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.551113049707572, 104.88354614421434 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.551113049707572&lon=104.88354614421434&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.51817920507682, 104.88637507349097 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.51817920507682&lon=104.88637507349097&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.535582599692969, 104.82373795213181 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.535582599692969&lon=104.82373795213181&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.5516133, 104.8711028 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.5516133&lon=104.8711028&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.535806809188161, 104.82381609377455 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.535806809188161&lon=104.82381609377455&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.549281995472924, 104.86464893847966 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.549281995472924&lon=104.86464893847966&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.549034289012852, 104.86491251821019 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.549034289012852&lon=104.86491251821019&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.5493847468, 104.864727123 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.5493847468&lon=104.864727123&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.55913101249402, 104.88059043560509 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.55913101249402&lon=104.88059043560509&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.475391632582243, 104.85939115296065 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.475391632582243&lon=104.85939115296065&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.460373419201877, 104.8718766092199 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.460373419201877&lon=104.8718766092199&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.468328796023401, 104.86076630736369 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.468328796023401&lon=104.86076630736369&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.46556070953198, 104.8571739592362 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.46556070953198&lon=104.8571739592362&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.460373419201877, 104.8718766092199 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.460373419201877&lon=104.8718766092199&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.479751, 104.8688126 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.479751&lon=104.8688126&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.469427477513563, 104.84221358619686 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.469427477513563&lon=104.84221358619686&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.430122213970037, 104.87016095683845 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.430122213970037&lon=104.87016095683845&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.439340318923243, 104.84906397167725 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.439340318923243&lon=104.84906397167725&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.426053907569738, 104.88582763203578 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.426053907569738&lon=104.88582763203578&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.460593017354341, 104.88408051852412 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.460593017354341&lon=104.88408051852412&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.465196900030989, 104.84466619895875 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.465196900030989&lon=104.84466619895875&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.467339453321387, 104.88656363731923 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.467339453321387&lon=104.88656363731923&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.476315808821411, 104.86646086248521 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.476315808821411&lon=104.86646086248521&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.462184327553118, 104.83579771978282 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.462184327553118&lon=104.83579771978282&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.474006578221355, 104.84466537649922 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.474006578221355&lon=104.84466537649922&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.470994331584762, 104.88716691945336 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.470994331584762&lon=104.88716691945336&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.48, 104.9 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.48&lon=104.9&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.48, 104.9 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.48&lon=104.9&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.48, 104.9 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.48&lon=104.9&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.48, 104.9 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.48&lon=104.9&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.48, 104.9 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.48&lon=104.9&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.48, 104.9 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.48&lon=104.9&zoom=18&addressdetails=1
# Reverse geocoding failed for 11.483096069345635, 104.91973170452712 (HTTP/Network error): 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/reverse?format=json&lat=11.483096069345635&lon=104.91973170452712&zoom=18&addressdetails=1
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
